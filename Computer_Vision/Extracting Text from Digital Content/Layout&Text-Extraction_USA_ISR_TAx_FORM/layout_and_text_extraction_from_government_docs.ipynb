# %% [markdown]
# ## Layout and Text Extraction from government documents
# #### the document used is the US government, ISR, Form 1040.

# %% [markdown]
# ### Importing Azure Form Recognizer Python modules

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import FormRecognizerClient

# %% [markdown]
# ####  Azure Form Recognizer Endpoint and Key

# %%
AZURE_FORM_RECOGNIZER_ENDPOINT = "https://formrecogforgovdocs.cognitiveservices.azure.com/"
AZURE_FORM_RECOGNIZER_KEY = "5d1616b361494a08af6884223c2abb13"

# %%
endpoint = AZURE_FORM_RECOGNIZER_ENDPOINT
key = AZURE_FORM_RECOGNIZER_KEY

# %% [markdown]
# ####  Instantiate object

# %%
form_recognizer_client = FormRecognizerClient(endpoint=endpoint, credential=AzureKeyCredential(key))

# %% [markdown]
# #### Input source document and extract results

# %%
content_url = "https://www.irs.gov/pub/irs-pdf/f1040.pdf"

# %%
# Fill in the code to begin extracting info from the document
result_from_url = form_recognizer_client.begin_recognize_content_from_url(content_url)

# %%
type(result_from_url)
# Out:
# azure.core.polling._poller.LROPoller

# %%
result_data = result_from_url.result()

# %%
type(result_data)
# Out:
# list

# %% [markdown]
# #### Process raw data

# %%
result_data
# Out:
# [FormPage(page_number=1, text_angle=0.0, width=8.5, height=11.0, unit=inch, tables=[FormTable(page_number=1, cells=[FormTableCell(text=Age/Blindness, row_index=0, column_index=0, row_span=1, column_span=1, bounding_box=[Point(x=0.4464, y=3.9195), Point(x=1.2812, y=3.9195), Point(x=1.2812, y=4.0812), Point(x=0.4386, y=4.0812)], confidence=1.0, is_header=True, is_footer=False, page_number=1, field_elements=[FormWord(text=Age/Blindness, bounding_box=[Point(x=0.4994, y=3.9564), Point(x=1.2335, y=3.9564), Point(x=1.2335, y=4.0593), Point(x=0.4994, y=4.0593)], confidence=1.0, page_number=1, kind=word)]), FormTableCell(text=You: Were born before January 2, 1958, row_index=0, column_index=1, row_span=1, column_span=3, bounding_box=[Point(x=1.2812, y=3.9195), Point(x=3.6685, y=3.9195), Point(x=3.6607, y=4.0812), Point(x=1.2812, y=4.0812)], confidence=1.0, is_header=True, is_footer=False, page_number=1, field_elements=[FormWord(text=You:, bounding_box=[Point(x=1.2991, y=3.9583), Point(x=1.5321, y=3.9583), Point(x=1.5321,
#  FormPage(page_number=2, text_angle=0.0, width=8.5, height=11.0, unit=inch, tables=[FormTable(page_number=2, cells=[FormTableCell(text=Form 1040 (2022), row_index=0, column_index=0, row_span=1, column_span=1, bounding_box=[Point(x=0.3963, y=0.3196), Point(x=1.2555, y=0.3196), Point(x=1.2555, y=0.4911), Point(x=0.3963, y=0.4989)], confidence=1.0, is_header=True, is_footer=False, page_number=2, field_elements=[FormWord(text=Form, bounding_box=[Point(x=0.5076, y=0.3689), Point(x=0.7207, y=0.3689), Point(x=0.7207, y=0.4394), Point(x=0.5076, y=0.4394)], confidence=1.0, page_number=2, kind=word), FormWord(text=1040, bounding_box=[Point(x=0.7624, y=0.3694), Point(x=0.9661, y=0.3694), Point(x=0.9661, y=0.4394), Point(x=0.7624, y=0.4394)], confidence=1.0, page_number=2, kind=word), FormWord(text=(2022), bounding_box=[Point(x=1.0018, y=0.3672), Point(x=1.2592, y=0.3672), Point(x=1.2592, y=0.4575), Point(x=1.0018, y=0.4575)], confidence=1.0, page_number=2, kind=word)]), FormTableCell(text=, row_index=0, column_index=1, r]

# %%
len(result_data)
# Out:
# 2

# %%
# Page 1
content = result_data[0]

# %%
type(content)
# Out:
# azure.ai.formrecognizer._models.FormPage

# %%
# Page 2: fill in your code here
pageTwoContent = result_data[1]

# %%
# Page 1 content
content.to_dict()
# Out:
# {'page_number': 1,
#  'text_angle': 0.0,
#  'width': 8.5,
#  'height': 11.0,
#  'unit': 'inch',
#  'tables': [{'page_number': 1,
#    'row_count': 31,
#    'column_count': 10,
#    'cells': [{'text': 'Age/Blindness',
#      'row_index': 0,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4464, 'y': 3.9195},
#       {'x': 1.2812, 'y': 3.9195},
#       {'x': 1.2812, 'y': 4.0812},
#       {'x': 0.4386, 'y': 4.0812}],
#      'field_elements': [{'text': 'Age/Blindness',
#        'bounding_box': [{'x': 0.4994, 'y': 3.9564},
#         {'x': 1.2335, 'y': 3.9564},
#         {'x': 1.2335, 'y': 4.0593},
#         {'x': 0.4994, 'y': 4.0593}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'You: Were born before January 2, 1958',
#      'row_index': 0,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2812, 'y': 3.9195},
#       {'x': 3.6685, 'y': 3.9195},
#       {'x': 3.6607, 'y': 4.0812},
#       {'x': 1.2812, 'y': 4.0812}],
#      'field_elements': [{'text': 'You:',
#        'bounding_box': [{'x': 1.2991, 'y': 3.9583},
#         {'x': 1.5321, 'y': 3.9583},
#         {'x': 1.5321, 'y': 4.0391},
#         {'x': 1.2991, 'y': 4.0391}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Were',
#        'bounding_box': [{'x': 1.8013, 'y': 3.9583},
#         {'x': 2.0545, 'y': 3.9583},
#         {'x': 2.0545, 'y': 4.0389},
#         {'x': 1.8013, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'born',
#        'bounding_box': [{'x': 2.0946, 'y': 3.9583},
#         {'x': 2.3063, 'y': 3.9583},
#         {'x': 2.3063, 'y': 4.0389},
#         {'x': 2.0946, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'before',
#        'bounding_box': [{'x': 2.3513, 'y': 3.9574},
#         {'x': 2.6576, 'y': 3.9574},
#         {'x': 2.6576, 'y': 4.0389},
#         {'x': 2.3513, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'January',
#        'bounding_box': [{'x': 2.6926, 'y': 3.9583},
#         {'x': 3.0785, 'y': 3.9583},
#         {'x': 3.0785, 'y': 4.0605},
#         {'x': 2.6926, 'y': 4.0605}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '2,',
#        'bounding_box': [{'x': 3.1126, 'y': 3.9589},
#         {'x': 3.1925, 'y': 3.9589},
#         {'x': 3.1925, 'y': 4.0539},
#         {'x': 3.1126, 'y': 4.0539}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '1958',
#        'bounding_box': [{'x': 3.2419, 'y': 3.9589},
#         {'x': 3.4726, 'y': 3.9589},
#         {'x': 3.4726, 'y': 4.0389},
#         {'x': 3.2419, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 1.6278, 'y': 3.9375},
#         {'x': 1.7389, 'y': 3.9375},
#         {'x': 1.7389, 'y': 4.0486},
#         {'x': 1.6278, 'y': 4.0486}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Are blind',
#      'row_index': 0,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6685, 'y': 3.9195},
#       {'x': 4.2225, 'y': 3.9195},
#       {'x': 4.2225, 'y': 4.0812},
#       {'x': 3.6607, 'y': 4.0812}],
#      'field_elements': [{'text': 'Are',
#        'bounding_box': [{'x': 3.7993, 'y': 3.9583},
#         {'x': 3.9666, 'y': 3.9583},
#         {'x': 3.9666, 'y': 4.0389},
#         {'x': 3.7993, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'blind',
#        'bounding_box': [{'x': 4.007, 'y': 3.9583},
#         {'x': 4.235, 'y': 3.9583},
#         {'x': 4.235, 'y': 4.0389},
#         {'x': 4.007, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 3.6278, 'y': 3.9375},
#         {'x': 3.7389, 'y': 3.9375},
#         {'x': 3.7389, 'y': 4.0486},
#         {'x': 3.6278, 'y': 4.0486}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Spouse:',
#      'row_index': 0,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2225, 'y': 3.9195},
#       {'x': 4.8856, 'y': 3.9195},
#       {'x': 4.8856, 'y': 4.0812},
#       {'x': 4.2225, 'y': 4.0812}],
#      'field_elements': [{'text': 'Spouse:',
#        'bounding_box': [{'x': 4.5024, 'y': 3.9564},
#         {'x': 4.9214, 'y': 3.9564},
#         {'x': 4.9214, 'y': 4.0578},
#         {'x': 4.5024, 'y': 4.0578}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Was born before January 2, 1958',
#      'row_index': 0,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 3.9195},
#       {'x': 6.9765, 'y': 3.9195},
#       {'x': 6.9765, 'y': 4.0812},
#       {'x': 4.8856, 'y': 4.0812}],
#      'field_elements': [{'text': 'Was',
#        'bounding_box': [{'x': 5.2013, 'y': 3.9583},
#         {'x': 5.4126, 'y': 3.9583},
#         {'x': 5.4126, 'y': 4.0389},
#         {'x': 5.2013, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'born',
#        'bounding_box': [{'x': 5.4539, 'y': 3.9583},
#         {'x': 5.6656, 'y': 3.9583},
#         {'x': 5.6656, 'y': 4.0389},
#         {'x': 5.4539, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'before',
#        'bounding_box': [{'x': 5.7106, 'y': 3.9574},
#         {'x': 6.0169, 'y': 3.9574},
#         {'x': 6.0169, 'y': 4.0389},
#         {'x': 5.7106, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'January',
#        'bounding_box': [{'x': 6.052, 'y': 3.9583},
#         {'x': 6.4378, 'y': 3.9583},
#         {'x': 6.4378, 'y': 4.0605},
#         {'x': 6.052, 'y': 4.0605}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '2,',
#        'bounding_box': [{'x': 6.4719, 'y': 3.9589},
#         {'x': 6.5518, 'y': 3.9589},
#         {'x': 6.5518, 'y': 4.0539},
#         {'x': 6.4719, 'y': 4.0539}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '1958',
#        'bounding_box': [{'x': 6.6012, 'y': 3.9589},
#         {'x': 6.8318, 'y': 3.9589},
#         {'x': 6.8318, 'y': 4.0389},
#         {'x': 6.6012, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 5.0278, 'y': 3.9375},
#         {'x': 5.1389, 'y': 3.9375},
#         {'x': 5.1389, 'y': 4.0486},
#         {'x': 5.0278, 'y': 4.0486}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Is blind',
#      'row_index': 0,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9765, 'y': 3.9195},
#       {'x': 7.9985, 'y': 3.9195},
#       {'x': 7.9985, 'y': 4.0812},
#       {'x': 6.9765, 'y': 4.0812}],
#      'field_elements': [{'text': 'Is',
#        'bounding_box': [{'x': 7.2091, 'y': 3.9583},
#         {'x': 7.281, 'y': 3.9583},
#         {'x': 7.281, 'y': 4.0389},
#         {'x': 7.2091, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'blind',
#        'bounding_box': [{'x': 7.3227, 'y': 3.9583},
#         {'x': 7.5507, 'y': 3.9583},
#         {'x': 7.5507, 'y': 4.0389},
#         {'x': 7.3227, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 7.0278, 'y': 3.9375},
#         {'x': 7.1389, 'y': 3.9375},
#         {'x': 7.1389, 'y': 4.0486},
#         {'x': 7.0278, 'y': 4.0486}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Dependents If more',
#      'row_index': 1,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4386, 'y': 4.0812},
#       {'x': 1.2812, 'y': 4.0812},
#       {'x': 1.2734, 'y': 4.4123},
#       {'x': 0.4386, 'y': 4.42}],
#      'field_elements': [{'text': 'Dependents',
#        'bounding_box': [{'x': 0.509, 'y': 4.1389},
#         {'x': 1.2486, 'y': 4.1389},
#         {'x': 1.2486, 'y': 4.257},
#         {'x': 0.509, 'y': 4.257}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'If',
#        'bounding_box': [{'x': 0.5091, 'y': 4.3338},
#         {'x': 0.5618, 'y': 4.3338},
#         {'x': 0.5618, 'y': 4.4141},
#         {'x': 0.5091, 'y': 4.4141}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'more',
#        'bounding_box': [{'x': 0.5997, 'y': 4.355},
#         {'x': 0.8457, 'y': 4.355},
#         {'x': 0.8457, 'y': 4.4153},
#         {'x': 0.5997, 'y': 4.4153}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '(see instructions): (1) First name Last name',
#      'row_index': 1,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2812, 'y': 4.0812},
#       {'x': 3.6607, 'y': 4.0812},
#       {'x': 3.6607, 'y': 4.4123},
#       {'x': 1.2734, 'y': 4.4123}],
#      'field_elements': [{'text': '(see',
#        'bounding_box': [{'x': 1.3052, 'y': 4.1453},
#         {'x': 1.5016, 'y': 4.1453},
#         {'x': 1.5016, 'y': 4.2484},
#         {'x': 1.3052, 'y': 4.2484}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'instructions):',
#        'bounding_box': [{'x': 1.5422, 'y': 4.1453},
#         {'x': 2.1611, 'y': 4.1453},
#         {'x': 2.1611, 'y': 4.2484},
#         {'x': 1.5422, 'y': 4.2484}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '(1)',
#        'bounding_box': [{'x': 1.3328, 'y': 4.2969},
#         {'x': 1.4343, 'y': 4.2969},
#         {'x': 1.4343, 'y': 4.3856},
#         {'x': 1.3328, 'y': 4.3856}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'First',
#        'bounding_box': [{'x': 1.474, 'y': 4.2986},
#         {'x': 1.6525, 'y': 4.2986},
#         {'x': 1.6525, 'y': 4.3691},
#         {'x': 1.474, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'name',
#        'bounding_box': [{'x': 1.6887, 'y': 4.3166},
#         {'x': 1.922, 'y': 4.3166},
#         {'x': 1.922, 'y': 4.3691},
#         {'x': 1.6887, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Last',
#        'bounding_box': [{'x': 2.4656, 'y': 4.2986},
#         {'x': 2.6406, 'y': 4.2986},
#         {'x': 2.6406, 'y': 4.3691},
#         {'x': 2.4656, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'name',
#        'bounding_box': [{'x': 2.6767, 'y': 4.3166},
#         {'x': 2.9101, 'y': 4.3166},
#         {'x': 2.9101, 'y': 4.3691},
#         {'x': 2.6767, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '(2) Social security number',
#      'row_index': 1,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6607, 'y': 4.0812},
#       {'x': 4.8856, 'y': 4.0812},
#       {'x': 4.8856, 'y': 4.4123},
#       {'x': 3.6607, 'y': 4.4123}],
#      'field_elements': [{'text': '(2)',
#        'bounding_box': [{'x': 3.9189, 'y': 4.1553},
#         {'x': 4.0204, 'y': 4.1553},
#         {'x': 4.0204, 'y': 4.244},
#         {'x': 3.9189, 'y': 4.244}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Social',
#        'bounding_box': [{'x': 4.0561, 'y': 4.1553},
#         {'x': 4.3123, 'y': 4.1553},
#         {'x': 4.3123, 'y': 4.2279},
#         {'x': 4.0561, 'y': 4.2279}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'security',
#        'bounding_box': [{'x': 4.3489, 'y': 4.157},
#         {'x': 4.6854, 'y': 4.157},
#         {'x': 4.6854, 'y': 4.2464},
#         {'x': 4.3489, 'y': 4.2464}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'number',
#        'bounding_box': [{'x': 4.1396, 'y': 4.2736},
#         {'x': 4.4667, 'y': 4.2736},
#         {'x': 4.4667, 'y': 4.3441},
#         {'x': 4.1396, 'y': 4.3441}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 3.9153, 'y': 4.1506},
#         {'x': 4.022, 'y': 4.1506},
#         {'x': 4.022, 'y': 4.2379},
#         {'x': 3.9153, 'y': 4.2379}],
#        'confidence': 0.223,
#        'state': 'selected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '(3) Relationship to you',
#      'row_index': 1,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.0812},
#       {'x': 5.775, 'y': 4.0812},
#       {'x': 5.775, 'y': 4.4123},
#       {'x': 4.8856, 'y': 4.4123}],
#      'field_elements': [{'text': '(3)',
#        'bounding_box': [{'x': 5.0175, 'y': 4.1553},
#         {'x': 5.119, 'y': 4.1553},
#         {'x': 5.119, 'y': 4.244},
#         {'x': 5.0175, 'y': 4.244}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Relationship',
#        'bounding_box': [{'x': 5.1586, 'y': 4.157},
#         {'x': 5.6841, 'y': 4.157},
#         {'x': 5.6841, 'y': 4.2455},
#         {'x': 5.1586, 'y': 4.2455}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'to',
#        'bounding_box': [{'x': 5.2149, 'y': 4.2777},
#         {'x': 5.297, 'y': 4.2777},
#         {'x': 5.297, 'y': 4.3441},
#         {'x': 5.2149, 'y': 4.3441}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'you',
#        'bounding_box': [{'x': 5.3283, 'y': 4.2916},
#         {'x': 5.4798, 'y': 4.2916},
#         {'x': 5.4798, 'y': 4.3631},
#         {'x': 5.3283, 'y': 4.3631}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '(4) Check the box if qualifies Child tax credit',
#      'row_index': 1,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.775, 'y': 4.0812},
#       {'x': 6.9765, 'y': 4.0812},
#       {'x': 6.9765, 'y': 4.4123},
#       {'x': 5.775, 'y': 4.4123}],
#      'field_elements': [{'text': '(4)',
#        'bounding_box': [{'x': 5.8313, 'y': 4.1234},
#         {'x': 5.9328, 'y': 4.1234},
#         {'x': 5.9328, 'y': 4.212},
#         {'x': 5.8313, 'y': 4.212}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Check',
#        'bounding_box': [{'x': 5.969, 'y': 4.1234},
#         {'x': 6.2412, 'y': 4.1234},
#         {'x': 6.2412, 'y': 4.196},
#         {'x': 5.969, 'y': 4.196}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'the',
#        'bounding_box': [{'x': 6.2688, 'y': 4.125},
#         {'x': 6.4017, 'y': 4.125},
#         {'x': 6.4017, 'y': 4.1955},
#         {'x': 6.2688, 'y': 4.1955}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'box',
#        'bounding_box': [{'x': 6.4367, 'y': 4.125},
#         {'x': 6.5916, 'y': 4.125},
#         {'x': 6.5916, 'y': 4.1955},
#         {'x': 6.4367, 'y': 4.1955}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'if',
#        'bounding_box': [{'x': 6.6258, 'y': 4.1242},
#         {'x': 6.6691, 'y': 4.1242},
#         {'x': 6.6691, 'y': 4.1944},
#         {'x': 6.6258, 'y': 4.1944}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'qualifies',
#        'bounding_box': [{'x': 6.6993, 'y': 4.1242},
#         {'x': 7.0476, 'y': 4.1242},
#         {'x': 7.0476, 'y': 4.2136},
#         {'x': 6.6993, 'y': 4.2136}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Child',
#        'bounding_box': [{'x': 6.0247, 'y': 4.2969},
#         {'x': 6.2391, 'y': 4.2969},
#         {'x': 6.2391, 'y': 4.3696},
#         {'x': 6.0247, 'y': 4.3696}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'tax',
#        'bounding_box': [{'x': 6.2735, 'y': 4.3027},
#         {'x': 6.4049, 'y': 4.3027},
#         {'x': 6.4049, 'y': 4.3691},
#         {'x': 6.2735, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'credit',
#        'bounding_box': [{'x': 6.4363, 'y': 4.2986},
#         {'x': 6.6766, 'y': 4.2986},
#         {'x': 6.6766, 'y': 4.3691},
#         {'x': 6.4363, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'for (see instructions): Credit for other dependents',
#      'row_index': 1,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9765, 'y': 4.0812},
#       {'x': 7.9985, 'y': 4.0812},
#       {'x': 7.9985, 'y': 4.4123},
#       {'x': 6.9765, 'y': 4.4123}],
#      'field_elements': [{'text': 'for',
#        'bounding_box': [{'x': 7.0784, 'y': 4.1242},
#         {'x': 7.193, 'y': 4.1242},
#         {'x': 7.193, 'y': 4.1955},
#         {'x': 7.0784, 'y': 4.1955}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '(see',
#        'bounding_box': [{'x': 7.2243, 'y': 4.1234},
#         {'x': 7.3944, 'y': 4.1234},
#         {'x': 7.3944, 'y': 4.2136},
#         {'x': 7.2243, 'y': 4.2136}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'instructions):',
#        'bounding_box': [{'x': 7.4296, 'y': 4.1234},
#         {'x': 7.9657, 'y': 4.1234},
#         {'x': 7.9657, 'y': 4.2136},
#         {'x': 7.4296, 'y': 4.2136}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Credit',
#        'bounding_box': [{'x': 6.9315, 'y': 4.2969},
#         {'x': 7.162, 'y': 4.2969},
#         {'x': 7.162, 'y': 4.3696},
#         {'x': 6.9315, 'y': 4.3696}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'for',
#        'bounding_box': [{'x': 7.1899, 'y': 4.2978},
#         {'x': 7.2935, 'y': 4.2978},
#         {'x': 7.2935, 'y': 4.3691},
#         {'x': 7.1899, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'other',
#        'bounding_box': [{'x': 7.3208, 'y': 4.2986},
#         {'x': 7.5191, 'y': 4.2986},
#         {'x': 7.5191, 'y': 4.3691},
#         {'x': 7.3208, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'dependents',
#        'bounding_box': [{'x': 7.5464, 'y': 4.2986},
#         {'x': 8.0034, 'y': 4.2986},
#         {'x': 8.0034, 'y': 4.3872},
#         {'x': 7.5464, 'y': 4.3872}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'than four',
#      'row_index': 2,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4386, 'y': 4.42},
#       {'x': 1.2734, 'y': 4.4123},
#       {'x': 1.2656, 'y': 4.574},
#       {'x': 0.4386, 'y': 4.574}],
#      'field_elements': [{'text': 'than',
#        'bounding_box': [{'x': 0.501, 'y': 4.4563},
#         {'x': 0.7111, 'y': 4.4563},
#         {'x': 0.7111, 'y': 4.5368},
#         {'x': 0.501, 'y': 4.5368}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'four',
#        'bounding_box': [{'x': 0.7504, 'y': 4.4554},
#         {'x': 0.9446, 'y': 4.4554},
#         {'x': 0.9446, 'y': 4.5368},
#         {'x': 0.7504, 'y': 4.5368}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2734, 'y': 4.4123},
#       {'x': 3.6607, 'y': 4.4123},
#       {'x': 3.6607, 'y': 4.5817},
#       {'x': 1.2656, 'y': 4.574}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6607, 'y': 4.4123},
#       {'x': 4.2225, 'y': 4.4123},
#       {'x': 4.2303, 'y': 4.5817},
#       {'x': 3.6607, 'y': 4.5817}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2225, 'y': 4.4123},
#       {'x': 4.8856, 'y': 4.4123},
#       {'x': 4.8856, 'y': 4.5817},
#       {'x': 4.2303, 'y': 4.5817}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.4123},
#       {'x': 5.775, 'y': 4.4123},
#       {'x': 5.775, 'y': 4.5817},
#       {'x': 4.8856, 'y': 4.5817}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.775, 'y': 4.4123},
#       {'x': 6.9765, 'y': 4.4123},
#       {'x': 6.9843, 'y': 4.5817},
#       {'x': 5.775, 'y': 4.5817}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 6.2944, 'y': 4.4444},
#         {'x': 6.4056, 'y': 4.4444},
#         {'x': 6.4056, 'y': 4.5555},
#         {'x': 6.2944, 'y': 4.5555}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9765, 'y': 4.4123},
#       {'x': 7.9985, 'y': 4.4123},
#       {'x': 7.9985, 'y': 4.5817},
#       {'x': 6.9843, 'y': 4.5817}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 7.3944, 'y': 4.4444},
#         {'x': 7.5056, 'y': 4.4444},
#         {'x': 7.5056, 'y': 4.5555},
#         {'x': 7.3944, 'y': 4.5555}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'dependents,',
#      'row_index': 3,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4386, 'y': 4.574},
#       {'x': 1.2656, 'y': 4.574},
#       {'x': 1.2656, 'y': 4.7203},
#       {'x': 0.4386, 'y': 4.7203}],
#      'field_elements': [{'text': 'dependents,',
#        'bounding_box': [{'x': 0.504, 'y': 4.5778},
#         {'x': 1.1123, 'y': 4.5778},
#         {'x': 1.1123, 'y': 4.6791},
#         {'x': 0.504, 'y': 4.6791}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2656, 'y': 4.574},
#       {'x': 3.6607, 'y': 4.5817},
#       {'x': 3.6607, 'y': 4.7434},
#       {'x': 1.2656, 'y': 4.7203}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6607, 'y': 4.5817},
#       {'x': 4.2303, 'y': 4.5817},
#       {'x': 4.2303, 'y': 4.7434},
#       {'x': 3.6607, 'y': 4.7434}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2303, 'y': 4.5817},
#       {'x': 4.8856, 'y': 4.5817},
#       {'x': 4.8856, 'y': 4.7434},
#       {'x': 4.2303, 'y': 4.7434}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.5817},
#       {'x': 5.775, 'y': 4.5817},
#       {'x': 5.775, 'y': 4.7434},
#       {'x': 4.8856, 'y': 4.7434}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.775, 'y': 4.5817},
#       {'x': 6.9843, 'y': 4.5817},
#       {'x': 6.9843, 'y': 4.7434},
#       {'x': 5.775, 'y': 4.7434}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 6.2944, 'y': 4.6111},
#         {'x': 6.4056, 'y': 4.6111},
#         {'x': 6.4056, 'y': 4.7222},
#         {'x': 6.2944, 'y': 4.7222}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9843, 'y': 4.5817},
#       {'x': 7.9985, 'y': 4.5817},
#       {'x': 7.9985, 'y': 4.7434},
#       {'x': 6.9843, 'y': 4.7434}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 7.3944, 'y': 4.6111},
#         {'x': 7.5056, 'y': 4.6111},
#         {'x': 7.5056, 'y': 4.7222},
#         {'x': 7.3944, 'y': 4.7222}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'see instructions and check',
#      'row_index': 4,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4386, 'y': 4.7203},
#       {'x': 1.2656, 'y': 4.7203},
#       {'x': 1.2656, 'y': 4.9205},
#       {'x': 0.4308, 'y': 4.9282}],
#      'field_elements': [{'text': 'see',
#        'bounding_box': [{'x': 0.5033, 'y': 4.7199},
#         {'x': 0.6659, 'y': 4.7199},
#         {'x': 0.6659, 'y': 4.7799},
#         {'x': 0.5033, 'y': 4.7799}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'instructions',
#        'bounding_box': [{'x': 0.7049, 'y': 4.6993},
#         {'x': 1.2475, 'y': 4.6993},
#         {'x': 1.2475, 'y': 4.7799},
#         {'x': 0.7049, 'y': 4.7799}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'and',
#        'bounding_box': [{'x': 0.504, 'y': 4.8208},
#         {'x': 0.6799, 'y': 4.8208},
#         {'x': 0.6799, 'y': 4.9014},
#         {'x': 0.504, 'y': 4.9014}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'check',
#        'bounding_box': [{'x': 0.7222, 'y': 4.8208},
#         {'x': 1.0167, 'y': 4.8208},
#         {'x': 1.0167, 'y': 4.9014},
#         {'x': 0.7222, 'y': 4.9014}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2656, 'y': 4.7203},
#       {'x': 1.4528, 'y': 4.7203},
#       {'x': 1.4528, 'y': 4.9205},
#       {'x': 1.2656, 'y': 4.9205}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.4528, 'y': 4.7203},
#       {'x': 3.6607, 'y': 4.7434},
#       {'x': 3.6529, 'y': 4.9128},
#       {'x': 1.4528, 'y': 4.9205}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6607, 'y': 4.7434},
#       {'x': 4.2303, 'y': 4.7434},
#       {'x': 4.2303, 'y': 4.9128},
#       {'x': 3.6529, 'y': 4.9128}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2303, 'y': 4.7434},
#       {'x': 4.8856, 'y': 4.7434},
#       {'x': 4.8856, 'y': 4.9128},
#       {'x': 4.2303, 'y': 4.9128}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.7434},
#       {'x': 5.775, 'y': 4.7434},
#       {'x': 5.7672, 'y': 4.9128},
#       {'x': 4.8856, 'y': 4.9128}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.775, 'y': 4.7434},
#       {'x': 6.7112, 'y': 4.7434},
#       {'x': 6.7034, 'y': 4.9128},
#       {'x': 5.7672, 'y': 4.9128}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 6.2944, 'y': 4.7777},
#         {'x': 6.4056, 'y': 4.7777},
#         {'x': 6.4056, 'y': 4.8888},
#         {'x': 6.2944, 'y': 4.8888}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.7112, 'y': 4.7434},
#       {'x': 6.9843, 'y': 4.7434},
#       {'x': 6.9843, 'y': 4.9128},
#       {'x': 6.7034, 'y': 4.9128}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9843, 'y': 4.7434},
#       {'x': 7.9985, 'y': 4.7434},
#       {'x': 7.9985, 'y': 4.9128},
#       {'x': 6.9843, 'y': 4.9128}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 7.3944, 'y': 4.7777},
#         {'x': 7.5056, 'y': 4.7777},
#         {'x': 7.5056, 'y': 4.8888},
#         {'x': 7.3944, 'y': 4.8888}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'here . .',
#      'row_index': 5,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4308, 'y': 4.9282},
#       {'x': 1.2656, 'y': 4.9205},
#       {'x': 1.2578, 'y': 5.0745},
#       {'x': 0.4308, 'y': 5.0745}],
#      'field_elements': [{'text': 'here',
#        'bounding_box': [{'x': 0.5071, 'y': 4.9424},
#         {'x': 0.716, 'y': 4.9424},
#         {'x': 0.716, 'y': 5.023},
#         {'x': 0.5071, 'y': 5.023}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 0.8426, 'y': 5.0094},
#         {'x': 0.8549, 'y': 5.0094},
#         {'x': 0.8549, 'y': 5.0217},
#         {'x': 0.8426, 'y': 5.0217}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 1.0092, 'y': 5.0094},
#         {'x': 1.0216, 'y': 5.0094},
#         {'x': 1.0216, 'y': 5.0217},
#         {'x': 1.0092, 'y': 5.0217}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 1.1069, 'y': 4.9271},
#         {'x': 1.218, 'y': 4.9271},
#         {'x': 1.218, 'y': 5.0382},
#         {'x': 1.1069, 'y': 5.0382}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2656, 'y': 4.9205},
#       {'x': 1.4528, 'y': 4.9205},
#       {'x': 1.4528, 'y': 5.0745},
#       {'x': 1.2578, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.4528, 'y': 4.9205},
#       {'x': 3.6529, 'y': 4.9128},
#       {'x': 3.6529, 'y': 5.0745},
#       {'x': 1.4528, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6529, 'y': 4.9128},
#       {'x': 4.2303, 'y': 4.9128},
#       {'x': 4.2303, 'y': 5.0745},
#       {'x': 3.6529, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2303, 'y': 4.9128},
#       {'x': 4.8856, 'y': 4.9128},
#       {'x': 4.8856, 'y': 5.0745},
#       {'x': 4.2303, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.9128},
#       {'x': 5.7672, 'y': 4.9128},
#       {'x': 5.7672, 'y': 5.0745},
#       {'x': 4.8856, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.7672, 'y': 4.9128},
#       {'x': 6.7034, 'y': 4.9128},
#       {'x': 6.7034, 'y': 5.0745},
#       {'x': 5.7672, 'y': 5.0745}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 6.2944, 'y': 4.9444},
#         {'x': 6.4056, 'y': 4.9444},
#         {'x': 6.4056, 'y': 5.0555},
#         {'x': 6.2944, 'y': 5.0555}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.7034, 'y': 4.9128},
#       {'x': 6.9843, 'y': 4.9128},
#       {'x': 6.9843, 'y': 5.0745},
#       {'x': 6.7034, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9843, 'y': 4.9128},
#       {'x': 7.9985, 'y': 4.9128},
#       {'x': 7.9985, 'y': 5.0745},
#       {'x': 6.9843, 'y': 5.0745}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 7.3944, 'y': 4.9444},
#         {'x': 7.5056, 'y': 4.9444},
#         {'x': 7.5056, 'y': 5.0555},
#         {'x': 7.3944, 'y': 5.0555}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Income',
#      'row_index': 6,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4308, 'y': 5.0745},
#       {'x': 1.2578, 'y': 5.0745},
#       {'x': 1.2578, 'y': 5.2824},
#       {'x': 0.4308, 'y': 5.2824}],
#      'field_elements': [{'text': 'Income',
#        'bounding_box': [{'x': 0.5115, 'y': 5.1667},
#         {'x': 1.0888, 'y': 5.1667},
#         {'x': 1.0888, 'y': 5.2878},
#         {'x': 0.5115, 'y': 5.2878}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1 a',
#      'row_index': 6,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2578, 'y': 5.0745},
#       {'x': 1.4528, 'y': 5.0745},
#       {'x': 1.4528, 'y': 5.2824},
#       {'x': 1.2578, 'y': 5.2824}],
#      'field_elements': [{'text': '1',
#        'bounding_box': [{'x': 1.3464, 'y': 5.1404},
#         {'x': 1.3818, 'y': 5.1404},
#         {'x': 1.3818, 'y': 5.2182},
#         {'x': 1.3464, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'a',
#        'bounding_box': [{'x': 1.4036, 'y': 5.1592},
#         {'x': 1.4596, 'y': 5.1592},
#         {'x': 1.4596, 'y': 5.2197},
#         {'x': 1.4036, 'y': 5.2197}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Total amount from Form(s) W-2, box 1 (see instructions)',
#      'row_index': 6,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.4528, 'y': 5.0745},
#       {'x': 4.2303, 'y': 5.0745},
#       {'x': 4.2381, 'y': 5.267},
#       {'x': 1.4528, 'y': 5.2824}],
#      'field_elements': [{'text': 'Total',
#        'bounding_box': [{'x': 1.6002, 'y': 5.1389},
#         {'x': 1.8393, 'y': 5.1389},
#         {'x': 1.8393, 'y': 5.2194},
#         {'x': 1.6002, 'y': 5.2194}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'amount',
#        'bounding_box': [{'x': 1.8818, 'y': 5.1436},
#         {'x': 2.2512, 'y': 5.1436},
#         {'x': 2.2512, 'y': 5.2194},
#         {'x': 1.8818, 'y': 5.2194}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'from',
#        'bounding_box': [{'x': 2.2868, 'y': 5.138},
#         {'x': 2.5068, 'y': 5.138},
#         {'x': 2.5068, 'y': 5.2194},
#         {'x': 2.2868, 'y': 5.2194}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Form(s)',
#        'bounding_box': [{'x': 2.5534, 'y': 5.137},
#         {'x': 2.912, 'y': 5.137},
#         {'x': 2.912, 'y': 5.2401},
#         {'x': 2.5534, 'y': 5.2401}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'W-2,',
#        'bounding_box': [{'x': 2.9494, 'y': 5.1389},
#         {'x': 3.1776, 'y': 5.1389},
#         {'x': 3.1776, 'y': 5.2344},
#         {'x': 2.9494, 'y': 5.2344}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'box',
#        'bounding_box': [{'x': 3.2252, 'y': 5.1389},
#         {'x': 3.404, 'y': 5.1389},
#         {'x': 3.404, 'y': 5.2194},
#         {'x': 3.2252, 'y': 5.2194}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '1',
#        'bounding_box': [{'x': 3.4456, 'y': 5.1394},
#         {'x': 3.4754, 'y': 5.1394},
#         {'x': 3.4754, 'y': 5.2182},
#         {'x': 3.4456, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '(see',
#        'bounding_box': [{'x': 3.5338, 'y': 5.137},
#         {'x': 3.7301, 'y': 5.137},
#         {'x': 3.7301, 'y': 5.2401},
#         {'x': 3.5338, 'y': 5.2401}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'instructions)',
#        'bounding_box': [{'x': 3.7708, 'y': 5.137},
#         {'x': 4.3629, 'y': 5.137},
#         {'x': 4.3629, 'y': 5.2401},
#         {'x': 3.7708, 'y': 5.2401}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '. . .',
#      'row_index': 6,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2303, 'y': 5.0745},
#       {'x': 4.8856, 'y': 5.0745},
#       {'x': 4.8856, 'y': 5.267},
#       {'x': 4.2381, 'y': 5.267}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.5092, 'y': 5.2059},
#         {'x': 4.5216, 'y': 5.2059},
#         {'x': 4.5216, 'y': 5.2182},
#         {'x': 4.5092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 4.6759, 'y': 5.2059},
#         {'x': 4.6882, 'y': 5.2059},
#         {'x': 4.6882, 'y': 5.2182},
#         {'x': 4.6759, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 4.8426, 'y': 5.2059},
#         {'x': 4.8549, 'y': 5.2059},
#         {'x': 4.8549, 'y': 5.2182},
#         {'x': 4.8426, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '. . . . .',
#      'row_index': 6,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 5.0745},
#       {'x': 5.7672, 'y': 5.0745},
#       {'x': 5.7672, 'y': 5.2593},
#       {'x': 4.8856, 'y': 5.267}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 5.0092, 'y': 5.2059},
#         {'x': 5.0216, 'y': 5.2059},
#         {'x': 5.0216, 'y': 5.2182},
#         {'x': 5.0092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.1759, 'y': 5.2059},
#         {'x': 5.1882, 'y': 5.2059},
#         {'x': 5.1882, 'y': 5.2182},
#         {'x': 5.1759, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.3426, 'y': 5.2059},
#         {'x': 5.3549, 'y': 5.2059},
#         {'x': 5.3549, 'y': 5.2182},
#         {'x': 5.3426, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.5092, 'y': 5.2059},
#         {'x': 5.5216, 'y': 5.2059},
#         {'x': 5.5216, 'y': 5.2182},
#         {'x': 5.5092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.6759, 'y': 5.2059},
#         {'x': 5.6882, 'y': 5.2059},
#         {'x': 5.6882, 'y': 5.2182},
#         {'x': 5.6759, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '. . . . .',
#      'row_index': 6,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.7672, 'y': 5.0745},
#       {'x': 6.7034, 'y': 5.0745},
#       {'x': 6.7034, 'y': 5.2516},
#       {'x': 5.7672, 'y': 5.2593}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 5.8426, 'y': 5.2059},
#         {'x': 5.8549, 'y': 5.2059},
#         {'x': 5.8549, 'y': 5.2182},
#         {'x': 5.8426, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.0092, 'y': 5.2059},
#         {'x': 6.0216, 'y': 5.2059},
#         {'x': 6.0216, 'y': 5.2182},
#         {'x': 6.0092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.1759, 'y': 5.2059},
#         {'x': 6.1882, 'y': 5.2059},
#         {'x': 6.1882, 'y': 5.2182},
#         {'x': 6.1759, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.3426, 'y': 5.2059},
#         {'x': 6.3549, 'y': 5.2059},
#         {'x': 6.3549, 'y': 5.2182},
#         {'x': 6.3426, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.5092, 'y': 5.2059},
#         {'x': 6.5216, 'y': 5.2059},
#         {'x': 6.5216, 'y': 5.2182},
#         {'x': 6.5092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1a',
#      'row_index': 6,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.7034, 'y': 5.0745},
#       {'x': 6.9843, 'y': 5.0745},
#       {'x': 6.9843, 'y': 5.2516},
#       {'x': 6.7034, 'y': 5.2516}],
#      'field_elements': [{'text': '1a',
#        'bounding_box': [{'x': 6.7954, 'y': 5.1404},
#         {'x': 6.9086, 'y': 5.1404},
#         {'x': 6.9086, 'y': 5.2197},
#         {'x': 6.7954, 'y': 5.2197}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 6,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9843, 'y': 5.0745},
#       {'x': 7.9985, 'y': 5.0745},
#       {'x': 7.9985, 'y': 5.2516},
#       {'x': 6.9843, 'y': 5.2516}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 7,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4308, 'y': 5.2824},
#       {'x': 1.2578, 'y': 5.2824},
#       {'x': 1.2578, 'y': 5.421},
#       {'x': 0.4308, 'y': 5.421}],
#      'field_elements': []},
#     {'text': 'b',
#      'row_index': 7,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
# ...
#       {'x': 6.9098, 'y': 9.22},
#       {'x': 6.7964, 'y': 9.22}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 5.8426, 'y': 9.1989},
#     {'x': 5.8549, 'y': 9.1989},
#     {'x': 5.8549, 'y': 9.2113},
#     {'x': 5.8426, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 5.8426, 'y': 9.1989},
#       {'x': 5.8549, 'y': 9.1989},
#       {'x': 5.8549, 'y': 9.2113},
#       {'x': 5.8426, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 6.0092, 'y': 9.1989},
#     {'x': 6.0216, 'y': 9.1989},
#     {'x': 6.0216, 'y': 9.2113},
#     {'x': 6.0092, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 6.0092, 'y': 9.1989},
#       {'x': 6.0216, 'y': 9.1989},
#       {'x': 6.0216, 'y': 9.2113},
#       {'x': 6.0092, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 6.1759, 'y': 9.1989},
#     {'x': 6.1882, 'y': 9.1989},
#     {'x': 6.1882, 'y': 9.2113},
#     {'x': 6.1759, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 6.1759, 'y': 9.1989},
#       {'x': 6.1882, 'y': 9.1989},
#       {'x': 6.1882, 'y': 9.2113},
#       {'x': 6.1759, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 6.3426, 'y': 9.1989},
#     {'x': 6.3549, 'y': 9.1989},
#     {'x': 6.3549, 'y': 9.2113},
#     {'x': 6.3426, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 6.3426, 'y': 9.1989},
#       {'x': 6.3549, 'y': 9.1989},
#       {'x': 6.3549, 'y': 9.2113},
#       {'x': 6.3426, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 6.5092, 'y': 9.1989},
#     {'x': 6.5216, 'y': 9.1989},
#     {'x': 6.5216, 'y': 9.2113},
#     {'x': 6.5092, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 6.5092, 'y': 9.1989},
#       {'x': 6.5216, 'y': 9.1989},
#       {'x': 6.5216, 'y': 9.2113},
#       {'x': 6.5092, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'For Disclosure, Privacy Act, and Paperwork Reduction Act Notice, see separate instructions.',
#    'bounding_box': [{'x': 0.5067, 'y': 9.4861},
#     {'x': 4.7771, 'y': 9.4861},
#     {'x': 4.7771, 'y': 9.5731},
#     {'x': 0.5067, 'y': 9.5731}],
#    'words': [{'text': 'For',
#      'bounding_box': [{'x': 0.5067, 'y': 9.4861},
#       {'x': 0.6547, 'y': 9.4861},
#       {'x': 0.6547, 'y': 9.5568},
#       {'x': 0.5067, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Disclosure,',
#      'bounding_box': [{'x': 0.6886, 'y': 9.4861},
#       {'x': 1.1962, 'y': 9.4861},
#       {'x': 1.1962, 'y': 9.5715},
#       {'x': 0.6886, 'y': 9.5715}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Privacy',
#      'bounding_box': [{'x': 1.2358, 'y': 9.4861},
#       {'x': 1.57, 'y': 9.4861},
#       {'x': 1.57, 'y': 9.5731},
#       {'x': 1.2358, 'y': 9.5731}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Act,',
#      'bounding_box': [{'x': 1.5959, 'y': 9.4861},
#       {'x': 1.7743, 'y': 9.4861},
#       {'x': 1.7743, 'y': 9.5715},
#       {'x': 1.5959, 'y': 9.5715}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'and',
#      'bounding_box': [{'x': 1.8103, 'y': 9.4861},
#       {'x': 1.9749, 'y': 9.4861},
#       {'x': 1.9749, 'y': 9.5568},
#       {'x': 1.8103, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Paperwork',
#      'bounding_box': [{'x': 2.0138, 'y': 9.4861},
#       {'x': 2.5133, 'y': 9.4861},
#       {'x': 2.5133, 'y': 9.5731},
#       {'x': 2.0138, 'y': 9.5731}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Reduction',
#      'bounding_box': [{'x': 2.5466, 'y': 9.4861},
#       {'x': 3.0099, 'y': 9.4861},
#       {'x': 3.0099, 'y': 9.5568},
#       {'x': 2.5466, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Act',
#      'bounding_box': [{'x': 3.0416, 'y': 9.4861},
#       {'x': 3.1974, 'y': 9.4861},
#       {'x': 3.1974, 'y': 9.5568},
#       {'x': 3.0416, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Notice,',
#      'bounding_box': [{'x': 3.2325, 'y': 9.4861},
#       {'x': 3.5494, 'y': 9.4861},
#       {'x': 3.5494, 'y': 9.5715},
#       {'x': 3.2325, 'y': 9.5715}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'see',
#      'bounding_box': [{'x': 3.5851, 'y': 9.5039},
#       {'x': 3.7441, 'y': 9.5039},
#       {'x': 3.7441, 'y': 9.5568},
#       {'x': 3.5851, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'separate',
#      'bounding_box': [{'x': 3.7759, 'y': 9.4902},
#       {'x': 4.178, 'y': 9.4902},
#       {'x': 4.178, 'y': 9.5731},
#       {'x': 3.7759, 'y': 9.5731}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'instructions.',
#      'bounding_box': [{'x': 4.2126, 'y': 9.4861},
#       {'x': 4.7771, 'y': 9.4861},
#       {'x': 4.7771, 'y': 9.5568},
#       {'x': 4.2126, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Cat. No. 11320B',
#    'bounding_box': [{'x': 5.6933, 'y': 9.4916},
#     {'x': 6.3065, 'y': 9.4916},
#     {'x': 6.3065, 'y': 9.5539},
#     {'x': 5.6933, 'y': 9.5539}],
#    'words': [{'text': 'Cat.',
#      'bounding_box': [{'x': 5.6933, 'y': 9.4916},
#       {'x': 5.837, 'y': 9.4916},
#       {'x': 5.837, 'y': 9.5539},
#       {'x': 5.6933, 'y': 9.5539}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'No.',
#      'bounding_box': [{'x': 5.8736, 'y': 9.493},
#       {'x': 5.9914, 'y': 9.493},
#       {'x': 5.9914, 'y': 9.5534},
#       {'x': 5.8736, 'y': 9.5534}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '11320B',
#      'bounding_box': [{'x': 6.0288, 'y': 9.493},
#       {'x': 6.3065, 'y': 9.493},
#       {'x': 6.3065, 'y': 9.5534},
#       {'x': 6.0288, 'y': 9.5534}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Form 1040 (2022)',
#    'bounding_box': [{'x': 7.2324, 'y': 9.4625},
#     {'x': 7.9954, 'y': 9.4625},
#     {'x': 7.9954, 'y': 9.5709},
#     {'x': 7.2324, 'y': 9.5709}],
#    'words': [{'text': 'Form',
#      'bounding_box': [{'x': 7.2324, 'y': 9.4922},
#       {'x': 7.4151, 'y': 9.4922},
#       {'x': 7.4151, 'y': 9.5526},
#       {'x': 7.2324, 'y': 9.5526}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '1040',
#      'bounding_box': [{'x': 7.4644, 'y': 9.4625},
#       {'x': 7.7305, 'y': 9.4625},
#       {'x': 7.7305, 'y': 9.5533},
#       {'x': 7.4644, 'y': 9.5533}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '(2022)',
#      'bounding_box': [{'x': 7.7718, 'y': 9.4807},
#       {'x': 7.9954, 'y': 9.4807},
#       {'x': 7.9954, 'y': 9.5709},
#       {'x': 7.7718, 'y': 9.5709}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}}],
#  'selection_marks': [{'text': None,
#    'bounding_box': [{'x': 1.3278, 'y': 0.9375},
#     {'x': 1.4389, 'y': 0.9375},
#     {'x': 1.4389, 'y': 1.0486},
#     {'x': 1.3278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.9278, 'y': 0.9375},
#     {'x': 2.0389, 'y': 0.9375},
#     {'x': 2.0389, 'y': 1.0486},
#     {'x': 1.9278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 3.2278, 'y': 0.9375},
#     {'x': 3.3389, 'y': 0.9375},
#     {'x': 3.3389, 'y': 1.0486},
#     {'x': 3.2278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 5.0278, 'y': 0.9375},
#     {'x': 5.1389, 'y': 0.9375},
#     {'x': 5.1389, 'y': 1.0486},
#     {'x': 5.0278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.5278, 'y': 0.9375},
#     {'x': 6.6389, 'y': 0.9375},
#     {'x': 6.6389, 'y': 1.0486},
#     {'x': 6.5278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.0, 'y': 3.0069},
#     {'x': 7.1111, 'y': 3.0069},
#     {'x': 7.1111, 'y': 3.118},
#     {'x': 7.0, 'y': 3.118}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.5, 'y': 3.0069},
#     {'x': 7.6111, 'y': 3.0069},
#     {'x': 7.6111, 'y': 3.118},
#     {'x': 7.5, 'y': 3.118}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.0, 'y': 3.3472},
#     {'x': 7.1111, 'y': 3.3472},
#     {'x': 7.1111, 'y': 3.4583},
#     {'x': 7.0, 'y': 3.4583}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.5, 'y': 3.3472},
#     {'x': 7.6111, 'y': 3.3472},
#     {'x': 7.6111, 'y': 3.4583},
#     {'x': 7.5, 'y': 3.4583}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 2.5278, 'y': 3.5278},
#     {'x': 2.6389, 'y': 3.5278},
#     {'x': 2.6389, 'y': 3.6389},
#     {'x': 2.5278, 'y': 3.6389}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 3.9278, 'y': 3.5278},
#     {'x': 4.0389, 'y': 3.5278},
#     {'x': 4.0389, 'y': 3.6389},
#     {'x': 3.9278, 'y': 3.6389}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.3278, 'y': 3.6944},
#     {'x': 1.4389, 'y': 3.6944},
#     {'x': 1.4389, 'y': 3.8055},
#     {'x': 1.3278, 'y': 3.8055}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.6278, 'y': 3.9375},
#     {'x': 1.7389, 'y': 3.9375},
#     {'x': 1.7389, 'y': 4.0486},
#     {'x': 1.6278, 'y': 4.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 3.6278, 'y': 3.9375},
#     {'x': 3.7389, 'y': 3.9375},
#     {'x': 3.7389, 'y': 4.0486},
#     {'x': 3.6278, 'y': 4.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 5.0278, 'y': 3.9375},
#     {'x': 5.1389, 'y': 3.9375},
#     {'x': 5.1389, 'y': 4.0486},
#     {'x': 5.0278, 'y': 4.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.0278, 'y': 3.9375},
#     {'x': 7.1389, 'y': 3.9375},
#     {'x': 7.1389, 'y': 4.0486},
#     {'x': 7.0278, 'y': 4.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 3.9153, 'y': 4.1506},
#     {'x': 4.022, 'y': 4.1506},
#     {'x': 4.022, 'y': 4.2379},
#     {'x': 3.9153, 'y': 4.2379}],
#    'confidence': 0.223,
#    'state': 'selected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.2944, 'y': 4.4444},
#     {'x': 6.4056, 'y': 4.4444},
#     {'x': 6.4056, 'y': 4.5555},
#     {'x': 6.2944, 'y': 4.5555}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.3944, 'y': 4.4444},
#     {'x': 7.5056, 'y': 4.4444},
#     {'x': 7.5056, 'y': 4.5555},
#     {'x': 7.3944, 'y': 4.5555}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.2944, 'y': 4.6111},
#     {'x': 6.4056, 'y': 4.6111},
#     {'x': 6.4056, 'y': 4.7222},
#     {'x': 6.2944, 'y': 4.7222}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.3944, 'y': 4.6111},
#     {'x': 7.5056, 'y': 4.6111},
#     {'x': 7.5056, 'y': 4.7222},
#     {'x': 7.3944, 'y': 4.7222}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.2944, 'y': 4.7777},
#     {'x': 6.4056, 'y': 4.7777},
#     {'x': 6.4056, 'y': 4.8888},
#     {'x': 6.2944, 'y': 4.8888}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.3944, 'y': 4.7777},
#     {'x': 7.5056, 'y': 4.7777},
#     {'x': 7.5056, 'y': 4.8888},
#     {'x': 7.3944, 'y': 4.8888}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.1069, 'y': 4.9271},
#     {'x': 1.218, 'y': 4.9271},
#     {'x': 1.218, 'y': 5.0382},
#     {'x': 1.1069, 'y': 5.0382}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.2944, 'y': 4.9444},
#     {'x': 6.4056, 'y': 4.9444},
#     {'x': 6.4056, 'y': 5.0555},
#     {'x': 6.2944, 'y': 5.0555}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.3944, 'y': 4.9444},
#     {'x': 7.5056, 'y': 4.9444},
#     {'x': 7.5056, 'y': 5.0555},
#     {'x': 7.3944, 'y': 5.0555}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 0.4977, 'y': 5.554},
#     {'x': 0.5796, 'y': 5.554},
#     {'x': 0.5796, 'y': 5.624},
#     {'x': 0.4977, 'y': 5.624}],
#    'confidence': 0.223,
#    'state': 'selected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.3983, 'y': 5.6511},
#     {'x': 1.4681, 'y': 5.6511},
#     {'x': 1.4681, 'y': 5.7202},
#     {'x': 1.3983, 'y': 5.7202}],
#    'confidence': 0.223,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.4611, 'y': 7.6111},
#     {'x': 6.5722, 'y': 7.6111},
#     {'x': 6.5722, 'y': 7.7222},
#     {'x': 6.4611, 'y': 7.7222}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.4611, 'y': 7.7778},
#     {'x': 6.5722, 'y': 7.7778},
#     {'x': 6.5722, 'y': 7.8889},
#     {'x': 6.4611, 'y': 7.8889}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'}]}

# %%
# Page 2 content: fill in your code here
pageTwoContent.to_dict()
# Out:
# {'page_number': 2,
#  'text_angle': 0.0,
#  'width': 8.5,
#  'height': 11.0,
#  'unit': 'inch',
#  'tables': [{'page_number': 2,
#    'row_count': 41,
#    'column_count': 17,
#    'cells': [{'text': 'Form 1040 (2022)',
#      'row_index': 0,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 0.3963, 'y': 0.3196},
#       {'x': 1.2555, 'y': 0.3196},
#       {'x': 1.2555, 'y': 0.4911},
#       {'x': 0.3963, 'y': 0.4989}],
#      'field_elements': [{'text': 'Form',
#        'bounding_box': [{'x': 0.5076, 'y': 0.3689},
#         {'x': 0.7207, 'y': 0.3689},
#         {'x': 0.7207, 'y': 0.4394},
#         {'x': 0.5076, 'y': 0.4394}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '1040',
#        'bounding_box': [{'x': 0.7624, 'y': 0.3694},
#         {'x': 0.9661, 'y': 0.3694},
#         {'x': 0.9661, 'y': 0.4394},
#         {'x': 0.7624, 'y': 0.4394}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '(2022)',
#        'bounding_box': [{'x': 1.0018, 'y': 0.3672},
#         {'x': 1.2592, 'y': 0.3672},
#         {'x': 1.2592, 'y': 0.4575},
#         {'x': 1.0018, 'y': 0.4575}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 0,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.2555, 'y': 0.3196},
#       {'x': 1.5289, 'y': 0.3196},
#       {'x': 1.5289, 'y': 0.4911},
#       {'x': 1.2555, 'y': 0.4911}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 0,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.5289, 'y': 0.3196},
#       {'x': 2.6537, 'y': 0.3274},
#       {'x': 2.6537, 'y': 0.4911},
#       {'x': 1.5289, 'y': 0.4911}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 0,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 2.6537, 'y': 0.3274},
#       {'x': 3.9582, 'y': 0.3274},
#       {'x': 3.9582, 'y': 0.4911},
#       {'x': 2.6537, 'y': 0.4911}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 0,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 3.9582, 'y': 0.3274},
#       {'x': 4.2003, 'y': 0.3274},
#       {'x': 4.2003, 'y': 0.4911},
#       {'x': 3.9582, 'y': 0.4911}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 0,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.2003, 'y': 0.3274},
#       {'x': 4.6065, 'y': 0.3274},
#       {'x': 4.6065, 'y': 0.4911},
#       {'x': 4.2003, 'y': 0.4911}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 0,
#      'column_index': 10,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.6065, 'y': 0.3274},
#       {'x': 4.7939, 'y': 0.3274},
#       {'x': 4.7939, 'y': 0.4911},
#       {'x': 4.6065, 'y': 0.4911}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 0,
#      'column_index': 11,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.7939, 'y': 0.3274},
#       {'x': 6.6999, 'y': 0.3274},
#       {'x': 6.6999, 'y': 0.4911},
#       {'x': 4.7939, 'y': 0.4911}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 0,
#      'column_index': 14,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 6.6999, 'y': 0.3274},
#       {'x': 6.9967, 'y': 0.3274},
#       {'x': 6.9967, 'y': 0.4911},
#       {'x': 6.6999, 'y': 0.4911}],
#      'field_elements': []},
#     {'text': 'Page 2',
#      'row_index': 0,
#      'column_index': 15,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 6.9967, 'y': 0.3274},
#       {'x': 7.9965, 'y': 0.3274},
#       {'x': 7.9965, 'y': 0.4989},
#       {'x': 6.9967, 'y': 0.4911}],
#      'field_elements': [{'text': 'Page',
#        'bounding_box': [{'x': 7.6801, 'y': 0.377},
#         {'x': 7.8939, 'y': 0.377},
#         {'x': 7.8939, 'y': 0.4667},
#         {'x': 7.6801, 'y': 0.4667}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '2',
#        'bounding_box': [{'x': 7.9257, 'y': 0.3472},
#         {'x': 7.9971, 'y': 0.3472},
#         {'x': 7.9971, 'y': 0.4464},
#         {'x': 7.9257, 'y': 0.4464}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': 'Tax and',
#      'row_index': 1,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 0.3963, 'y': 0.4989},
#       {'x': 1.2555, 'y': 0.4911},
#       {'x': 1.2555, 'y': 0.686},
#       {'x': 0.3963, 'y': 0.686}],
#      'field_elements': [{'text': 'Tax',
#        'bounding_box': [{'x': 0.5018, 'y': 0.5556},
#         {'x': 0.7392, 'y': 0.5556},
#         {'x': 0.7392, 'y': 0.6565},
#         {'x': 0.5018, 'y': 0.6565}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'and',
#        'bounding_box': [{'x': 0.7822, 'y': 0.5556},
#         {'x': 1.0174, 'y': 0.5556},
#         {'x': 1.0174, 'y': 0.6565},
#         {'x': 0.7822, 'y': 0.6565}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '16',
#      'row_index': 1,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.2555, 'y': 0.4911},
#       {'x': 1.5289, 'y': 0.4911},
#       {'x': 1.5289, 'y': 0.686},
#       {'x': 1.2555, 'y': 0.686}],
#      'field_elements': [{'text': '16',
#        'bounding_box': [{'x': 1.2847, 'y': 0.5555},
#         {'x': 1.3977, 'y': 0.5555},
#         {'x': 1.3977, 'y': 0.6363},
#         {'x': 1.2847, 'y': 0.6363}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': 'Tax (see instructions). Check if any from Form(s):',
#      'row_index': 1,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 5,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.5289, 'y': 0.4911},
#       {'x': 3.9582, 'y': 0.4911},
#       {'x': 3.9582, 'y': 0.686},
#       {'x': 1.5289, 'y': 0.686}],
#      'field_elements': [{'text': 'Tax',
#        'bounding_box': [{'x': 1.6014, 'y': 0.5555},
#         {'x': 1.7837, 'y': 0.5555},
#         {'x': 1.7837, 'y': 0.6363},
#         {'x': 1.6014, 'y': 0.6363}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '(see',
#        'bounding_box': [{'x': 1.8183, 'y': 0.5537},
#         {'x': 2.0068, 'y': 0.5537},
#         {'x': 2.0068, 'y': 0.6568},
#         {'x': 1.8183, 'y': 0.6568}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'instructions).',
#        'bounding_box': [{'x': 2.0459, 'y': 0.5537},
#         {'x': 2.64, 'y': 0.5537},
#         {'x': 2.64, 'y': 0.6568},
#         {'x': 2.0459, 'y': 0.6568}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'Check',
#        'bounding_box': [{'x': 2.6832, 'y': 0.5537},
#         {'x': 2.9849, 'y': 0.5537},
#         {'x': 2.9849, 'y': 0.6367},
#         {'x': 2.6832, 'y': 0.6367}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'if',
#        'bounding_box': [{'x': 3.0219, 'y': 0.5547},
#         {'x': 3.0699, 'y': 0.5547},
#         {'x': 3.0699, 'y': 0.6349},
#         {'x': 3.0219, 'y': 0.6349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'any',
#        'bounding_box': [{'x': 3.1033, 'y': 0.5761},
#         {'x': 3.2685, 'y': 0.5761},
#         {'x': 3.2685, 'y': 0.6578},
#         {'x': 3.1033, 'y': 0.6578}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'from',
#        'bounding_box': [{'x': 3.3003, 'y': 0.5547},
#         {'x': 3.5115, 'y': 0.5547},
#         {'x': 3.5115, 'y': 0.6361},
#         {'x': 3.3003, 'y': 0.6361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'Form(s):',
#        'bounding_box': [{'x': 3.5563, 'y': 0.5537},
#         {'x': 3.9262, 'y': 0.5537},
#         {'x': 3.9262, 'y': 0.6568},
#         {'x': 3.5563, 'y': 0.6568}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '1',
#      'row_index': 1,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 3.9582, 'y': 0.4911},
#       {'x': 4.2003, 'y': 0.4911},
#       {'x': 4.2003, 'y': 0.6782},
#       {'x': 3.9582, 'y': 0.686}],
#      'field_elements': [{'text': '1',
#        'bounding_box': [{'x': 4.0082, 'y': 0.5571},
#         {'x': 4.0436, 'y': 0.5571},
#         {'x': 4.0436, 'y': 0.6349},
#         {'x': 4.0082, 'y': 0.6349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 4.1278, 'y': 0.5417},
#         {'x': 4.2389, 'y': 0.5417},
#         {'x': 4.2389, 'y': 0.6528},
#         {'x': 4.1278, 'y': 0.6528}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 2,
#        'kind': 'selectionMark'}]},
#     {'text': '8814',
#      'row_index': 1,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.2003, 'y': 0.4911},
#       {'x': 4.4346, 'y': 0.4911},
#       {'x': 4.4346, 'y': 0.6782},
#       {'x': 4.2003, 'y': 0.6782}],
#      'field_elements': [{'text': '8814',
#        'bounding_box': [{'x': 4.3044, 'y': 0.5561},
#         {'x': 4.5426, 'y': 0.5561},
#         {'x': 4.5426, 'y': 0.6361},
#         {'x': 4.3044, 'y': 0.6361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 1,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.4346, 'y': 0.4911},
#       {'x': 4.6065, 'y': 0.4911},
#       {'x': 4.6065, 'y': 0.6782},
#       {'x': 4.4346, 'y': 0.6782}],
#      'field_elements': []},
#     {'text': '2',
#      'row_index': 1,
#      'column_index': 10,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.6065, 'y': 0.4911},
#       {'x': 4.7939, 'y': 0.4911},
#       {'x': 4.7939, 'y': 0.6782},
#       {'x': 4.6065, 'y': 0.6782}],
#      'field_elements': [{'text': '2',
#        'bounding_box': [{'x': 4.7023, 'y': 0.5555},
#         {'x': 4.7594, 'y': 0.5555},
#         {'x': 4.7594, 'y': 0.6349},
#         {'x': 4.7023, 'y': 0.6349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '4972',
#      'row_index': 1,
#      'column_index': 11,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.7939, 'y': 0.4911},
#       {'x': 5.3329, 'y': 0.4911},
#       {'x': 5.3329, 'y': 0.6782},
#       {'x': 4.7939, 'y': 0.6782}],
#      'field_elements': [{'text': '4972',
#        'bounding_box': [{'x': 5.0031, 'y': 0.5561},
#         {'x': 5.2402, 'y': 0.5561},
#         {'x': 5.2402, 'y': 0.6361},
#         {'x': 5.0031, 'y': 0.6361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 4.8278, 'y': 0.5417},
#         {'x': 4.9389, 'y': 0.5417},
#         {'x': 4.9389, 'y': 0.6528},
#         {'x': 4.8278, 'y': 0.6528}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 2,
#        'kind': 'selectionMark'}]},
#     {'text': '3',
#      'row_index': 1,
#      'column_index': 12,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 5.3329, 'y': 0.4911},
#       {'x': 5.7391, 'y': 0.4911},
#       {'x': 5.7391, 'y': 0.6782},
#       {'x': 5.3329, 'y': 0.6782}],
#      'field_elements': [{'text': '3',
#        'bounding_box': [{'x': 5.4017, 'y': 0.5555},
#         {'x': 5.4598, 'y': 0.5555},
#         {'x': 5.4598, 'y': 0.6363},
#         {'x': 5.4017, 'y': 0.6363}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 5.5278, 'y': 0.5417},
#         {'x': 5.6389, 'y': 0.5417},
#         {'x': 5.6389, 'y': 0.6528},
#         {'x': 5.5278, 'y': 0.6528}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 2,
#        'kind': 'selectionMark'}]},
#     {'text': '. .',
#      'row_index': 1,
#      'column_index': 13,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 5.7391, 'y': 0.4911},
#       {'x': 6.6999, 'y': 0.4911},
#       {'x': 6.6999, 'y': 0.6782},
#       {'x': 5.7391, 'y': 0.6782}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 6.3414, 'y': 0.6281},
#         {'x': 6.3522, 'y': 0.6281},
#         {'x': 6.3522, 'y': 0.6388},
#         {'x': 6.3414, 'y': 0.6388}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.508, 'y': 0.6281},
#         {'x': 6.5188, 'y': 0.6281},
#         {'x': 6.5188, 'y': 0.6388},
#         {'x': 6.508, 'y': 0.6388}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '16',
#      'row_index': 1,
#      'column_index': 14,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 6.6999, 'y': 0.4911},
#       {'x': 6.9967, 'y': 0.4911},
#       {'x': 6.9967, 'y': 0.6704},
#       {'x': 6.6999, 'y': 0.6782}],
#      'field_elements': [{'text': '16',
#        'bounding_box': [{'x': 6.7964, 'y': 0.5555},
#         {'x': 6.9094, 'y': 0.5555},
#         {'x': 6.9094, 'y': 0.6363},
#         {'x': 6.7964, 'y': 0.6363}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 1,
#      'column_index': 15,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 6.9967, 'y': 0.4911},
#       {'x': 7.9965, 'y': 0.4989},
#       {'x': 7.9965, 'y': 0.6782},
#       {'x': 6.9967, 'y': 0.6704}],
#      'field_elements': []},
#     {'text': 'Credits',
#      'row_index': 2,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 0.3963, 'y': 0.686},
#       {'x': 1.2555, 'y': 0.686},
#       {'x': 1.2555, 'y': 0.8497},
#       {'x': 0.3963, 'y': 0.8575}],
#      'field_elements': [{'text': 'Credits',
#        'bounding_box': [{'x': 0.5053, 'y': 0.7199},
#         {'x': 0.9768, 'y': 0.7199},
#         {'x': 0.9768, 'y': 0.8236},
#         {'x': 0.5053, 'y': 0.8236}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '17',
#      'row_index': 2,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.2555, 'y': 0.686},
#       {'x': 1.5289, 'y': 0.686},
#       {'x': 1.5289, 'y': 0.8497},
#       {'x': 1.2555, 'y': 0.8497}],
#      'field_elements': [{'text': '17',
#        'bounding_box': [{'x': 1.2847, 'y': 0.7238},
#         {'x': 1.3957, 'y': 0.7238},
#         {'x': 1.3957, 'y': 0.8015},
#         {'x': 1.2847, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': 'Amount from Schedule 2, line 3 . . . .',
#      'row_index': 2,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 5,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.5289, 'y': 0.686},
#       {'x': 3.9582, 'y': 0.686},
#       {'x': 3.9582, 'y': 0.8497},
#       {'x': 1.5289, 'y': 0.8497}],
#      'field_elements': [{'text': 'Amount',
#        'bounding_box': [{'x': 1.5993, 'y': 0.7222},
#         {'x': 1.9858, 'y': 0.7222},
#         {'x': 1.9858, 'y': 0.8027},
#         {'x': 1.5993, 'y': 0.8027}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'from',
#        'bounding_box': [{'x': 2.0213, 'y': 0.7213},
#         {'x': 2.2413, 'y': 0.7213},
#         {'x': 2.2413, 'y': 0.8027},
#         {'x': 2.0213, 'y': 0.8027}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'Schedule',
#        'bounding_box': [{'x': 2.2834, 'y': 0.7203},
#         {'x': 2.7423, 'y': 0.7203},
#         {'x': 2.7423, 'y': 0.8033},
#         {'x': 2.2834, 'y': 0.8033}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '2,',
#        'bounding_box': [{'x': 2.778, 'y': 0.7227},
#         {'x': 2.8587, 'y': 0.7227},
#         {'x': 2.8587, 'y': 0.8178},
#         {'x': 2.778, 'y': 0.8178}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'line',
#        'bounding_box': [{'x': 2.9066, 'y': 0.7222},
#         {'x': 3.0676, 'y': 0.7222},
#         {'x': 3.0676, 'y': 0.8027},
#         {'x': 2.9066, 'y': 0.8027}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '3',
#        'bounding_box': [{'x': 3.1036, 'y': 0.7227},
#         {'x': 3.1572, 'y': 0.7227},
#         {'x': 3.1572, 'y': 0.8027},
#         {'x': 3.1036, 'y': 0.8027}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 3.3426, 'y': 0.7892},
#         {'x': 3.3549, 'y': 0.7892},
#         {'x': 3.3549, 'y': 0.8015},
#         {'x': 3.3426, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 3.5092, 'y': 0.7892},
#         {'x': 3.5216, 'y': 0.7892},
#         {'x': 3.5216, 'y': 0.8015},
#         {'x': 3.5092, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 3.6759, 'y': 0.7892},
#         {'x': 3.6882, 'y': 0.7892},
#         {'x': 3.6882, 'y': 0.8015},
#         {'x': 3.6759, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 3.8426, 'y': 0.7892},
#         {'x': 3.8549, 'y': 0.7892},
#         {'x': 3.8549, 'y': 0.8015},
#         {'x': 3.8426, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '. .',
#      'row_index': 2,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 3.9582, 'y': 0.686},
#       {'x': 4.2003, 'y': 0.6782},
#       {'x': 4.2003, 'y': 0.8497},
#       {'x': 3.9582, 'y': 0.8497}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.0092, 'y': 0.7892},
#         {'x': 4.0216, 'y': 0.7892},
#         {'x': 4.0216, 'y': 0.8015},
#         {'x': 4.0092, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 4.1759, 'y': 0.7892},
#         {'x': 4.1882, 'y': 0.7892},
#         {'x': 4.1882, 'y': 0.8015},
#         {'x': 4.1759, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '.',
#      'row_index': 2,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.2003, 'y': 0.6782},
#       {'x': 4.4346, 'y': 0.6782},
#       {'x': 4.4346, 'y': 0.8419},
#       {'x': 4.2003, 'y': 0.8497}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.3426, 'y': 0.7892},
#         {'x': 4.3549, 'y': 0.7892},
#         {'x': 4.3549, 'y': 0.8015},
#         {'x': 4.3426, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '.',
#      'row_index': 2,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.4346, 'y': 0.6782},
#       {'x': 4.6065, 'y': 0.6782},
#       {'x': 4.6065, 'y': 0.8419},
#       {'x': 4.4346, 'y': 0.8419}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.5092, 'y': 0.7892},
#         {'x': 4.5216, 'y': 0.7892},
#         {'x': 4.5216, 'y': 0.8015},
#         {'x': 4.5092, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '.',
#      'row_index': 2,
#      'column_index': 10,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.6065, 'y': 0.6782},
#       {'x': 4.7939, 'y': 0.6782},
#       {'x': 4.7939, 'y': 0.8419},
#       {'x': 4.6065, 'y': 0.8419}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.6759, 'y': 0.7892},
#         {'x': 4.6882, 'y': 0.7892},
#         {'x': 4.6882, 'y': 0.8015},
#         {'x': 4.6759, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '. . .',
#      'row_index': 2,
#      'column_index': 11,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.7939, 'y': 0.6782},
#       {'x': 5.3329, 'y': 0.6782},
#       {'x': 5.3329, 'y': 0.8419},
#       {'x': 4.7939, 'y': 0.8419}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.8426, 'y': 0.7892},
#         {'x': 4.8549, 'y': 0.7892},
#         {'x': 4.8549, 'y': 0.8015},
#         {'x': 4.8426, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.0092, 'y': 0.7892},
#         {'x': 5.0216, 'y': 0.7892},
#         {'x': 5.0216, 'y': 0.8015},
#         {'x': 5.0092, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.1759, 'y': 0.7892},
#         {'x': 5.1882, 'y': 0.7892},
#         {'x': 5.1882, 'y': 0.8015},
#         {'x': 5.1759, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '. . . . . . . .',
#      'row_index': 2,
#      'column_index': 12,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 5.3329, 'y': 0.6782},
#       {'x': 6.6999, 'y': 0.6782},
#       {'x': 6.6999, 'y': 0.8419},
#       {'x': 5.3329, 'y': 0.8419}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 5.3426, 'y': 0.7892},
#         {'x': 5.3549, 'y': 0.7892},
#         {'x': 5.3549, 'y': 0.8015},
#         {'x': 5.3426, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.5092, 'y': 0.7892},
#         {'x': 5.5216, 'y': 0.7892},
#         {'x': 5.5216, 'y': 0.8015},
#         {'x': 5.5092, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.6759, 'y': 0.7892},
#         {'x': 5.6882, 'y': 0.7892},
#         {'x': 5.6882, 'y': 0.8015},
#         {'x': 5.6759, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.8426, 'y': 0.7892},
#         {'x': 5.8549, 'y': 0.7892},
#         {'x': 5.8549, 'y': 0.8015},
#         {'x': 5.8426, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.0092, 'y': 0.7892},
#         {'x': 6.0216, 'y': 0.7892},
#         {'x': 6.0216, 'y': 0.8015},
#         {'x': 6.0092, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.1759, 'y': 0.7892},
#         {'x': 6.1882, 'y': 0.7892},
#         {'x': 6.1882, 'y': 0.8015},
#         {'x': 6.1759, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.3426, 'y': 0.7892},
#         {'x': 6.3549, 'y': 0.7892},
#         {'x': 6.3549, 'y': 0.8015},
#         {'x': 6.3426, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.5092, 'y': 0.7892},
#         {'x': 6.5216, 'y': 0.7892},
#         {'x': 6.5216, 'y': 0.8015},
#         {'x': 6.5092, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '17',
#      'row_index': 2,
#      'column_index': 14,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 6.6999, 'y': 0.6782},
#       {'x': 6.9967, 'y': 0.6704},
#       {'x': 6.9967, 'y': 0.8419},
#       {'x': 6.6999, 'y': 0.8419}],
#      'field_elements': [{'text': '17',
#        'bounding_box': [{'x': 6.7964, 'y': 0.7238},
#         {'x': 6.9074, 'y': 0.7238},
#         {'x': 6.9074, 'y': 0.8015},
#         {'x': 6.7964, 'y': 0.8015}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 15,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 6.9967, 'y': 0.6704},
#       {'x': 7.9965, 'y': 0.6782},
#       {'x': 7.9965, 'y': 0.8419},
#       {'x': 6.9967, 'y': 0.8419}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 0.3963, 'y': 0.8575},
#       {'x': 1.2555, 'y': 0.8497},
#       {'x': 1.2555, 'y': 1.0134},
#       {'x': 0.4041, 'y': 1.0134}],
#      'field_elements': []},
#     {'text': '18',
#      'row_index': 3,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.2555, 'y': 0.8497},
#       {'x': 1.5289, 'y': 0.8497},
#       {'x': 1.5289, 'y': 1.0134},
#       {'x': 1.2555, 'y': 1.0134}],
#      'field_elements': [{'text': '18',
#        'bounding_box': [{'x': 1.2847, 'y': 0.8889},
#         {'x': 1.3984, 'y': 0.8889},
#         {'x': 1.3984, 'y': 0.9697},
#         {'x': 1.2847, 'y': 0.9697}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': 'Add lines 16 and 17 . . . . . .',
#      'row_index': 3,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 4,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.5289, 'y': 0.8497},
#       {'x': 3.6223, 'y': 0.8497},
#       {'x': 3.6301, 'y': 1.0134},
#       {'x': 1.5289, 'y': 1.0134}],
#      'field_elements': [{'text': 'Add',
#        'bounding_box': [{'x': 1.5993, 'y': 0.8889},
#         {'x': 1.7963, 'y': 0.8889},
#         {'x': 1.7963, 'y': 0.9694},
#         {'x': 1.5993, 'y': 0.9694}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'lines',
#        'bounding_box': [{'x': 1.8423, 'y': 0.8889},
#         {'x': 2.0577, 'y': 0.8889},
#         {'x': 2.0577, 'y': 0.9694},
#         {'x': 1.8423, 'y': 0.9694}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '16',
#        'bounding_box': [{'x': 2.1016, 'y': 0.8894},
#         {'x': 2.2113, 'y': 0.8894},
#         {'x': 2.2113, 'y': 0.9694},
#         {'x': 2.1016, 'y': 0.9694}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'and',
#        'bounding_box': [{'x': 2.2503, 'y': 0.8889},
#         {'x': 2.4262, 'y': 0.8889},
#         {'x': 2.4262, 'y': 0.9694},
#         {'x': 2.2503, 'y': 0.9694}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '17',
#        'bounding_box': [{'x': 2.4742, 'y': 0.8894},
#         {'x': 2.5829, 'y': 0.8894},
#         {'x': 2.5829, 'y': 0.9682},
#         {'x': 2.4742, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 2.6759, 'y': 0.9559},
#         {'x': 2.6882, 'y': 0.9559},
#         {'x': 2.6882, 'y': 0.9682},
#         {'x': 2.6759, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 2.8426, 'y': 0.9559},
#         {'x': 2.8549, 'y': 0.9559},
#         {'x': 2.8549, 'y': 0.9682},
#         {'x': 2.8426, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 3.0092, 'y': 0.9559},
#         {'x': 3.0216, 'y': 0.9559},
#         {'x': 3.0216, 'y': 0.9682},
#         {'x': 3.0092, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 3.1759, 'y': 0.9559},
#         {'x': 3.1882, 'y': 0.9559},
#         {'x': 3.1882, 'y': 0.9682},
#         {'x': 3.1759, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 3.3426, 'y': 0.9559},
#         {'x': 3.3549, 'y': 0.9559},
#         {'x': 3.3549, 'y': 0.9682},
#         {'x': 3.3426, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 3.5092, 'y': 0.9559},
#         {'x': 3.5216, 'y': 0.9559},
#         {'x': 3.5216, 'y': 0.9682},
#         {'x': 3.5092, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '. .',
#      'row_index': 3,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 3.6223, 'y': 0.8497},
#       {'x': 3.9582, 'y': 0.8497},
#       {'x': 3.9582, 'y': 1.0134},
#       {'x': 3.6301, 'y': 1.0134}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 3.6759, 'y': 0.9559},
#         {'x': 3.6882, 'y': 0.9559},
#         {'x': 3.6882, 'y': 0.9682},
#         {'x': 3.6759, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 3.8426, 'y': 0.9559},
#         {'x': 3.8549, 'y': 0.9559},
#         {'x': 3.8549, 'y': 0.9682},
#         {'x': 3.8426, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '. .',
#      'row_index': 3,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 3.9582, 'y': 0.8497},
#       {'x': 4.2003, 'y': 0.8497},
#       {'x': 4.2003, 'y': 1.0134},
#       {'x': 3.9582, 'y': 1.0134}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.0092, 'y': 0.9559},
#         {'x': 4.0216, 'y': 0.9559},
#         {'x': 4.0216, 'y': 0.9682},
#         {'x': 4.0092, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 4.1759, 'y': 0.9559},
#         {'x': 4.1882, 'y': 0.9559},
#         {'x': 4.1882, 'y': 0.9682},
#         {'x': 4.1759, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '.',
#      'row_index': 3,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.2003, 'y': 0.8497},
#       {'x': 4.4346, 'y': 0.8419},
#       {'x': 4.4346, 'y': 1.0134},
#       {'x': 4.2003, 'y': 1.0134}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.3426, 'y': 0.9559},
#         {'x': 4.3549, 'y': 0.9559},
#         {'x': 4.3549, 'y': 0.9682},
#         {'x': 4.3426, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '.',
#      'row_index': 3,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.4346, 'y': 0.8419},
#       {'x': 4.6065, 'y': 0.8419},
#       {'x': 4.6065, 'y': 1.0134},
#       {'x': 4.4346, 'y': 1.0134}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.5092, 'y': 0.9559},
#         {'x': 4.5216, 'y': 0.9559},
#         {'x': 4.5216, 'y': 0.9682},
#         {'x': 4.5092, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '. . . .',
#      'row_index': 3,
#      'column_index': 10,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.6065, 'y': 0.8419},
#       {'x': 5.3329, 'y': 0.8419},
#       {'x': 5.3329, 'y': 1.0134},
#       {'x': 4.6065, 'y': 1.0134}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.6759, 'y': 0.9559},
#         {'x': 4.6882, 'y': 0.9559},
#         {'x': 4.6882, 'y': 0.9682},
#         {'x': 4.6759, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 4.8426, 'y': 0.9559},
#         {'x': 4.8549, 'y': 0.9559},
#         {'x': 4.8549, 'y': 0.9682},
#         {'x': 4.8426, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.0092, 'y': 0.9559},
#         {'x': 5.0216, 'y': 0.9559},
#         {'x': 5.0216, 'y': 0.9682},
#         {'x': 5.0092, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.1759, 'y': 0.9559},
#         {'x': 5.1882, 'y': 0.9559},
#         {'x': 5.1882, 'y': 0.9682},
#         {'x': 5.1759, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '. . . . . . . .',
#      'row_index': 3,
#      'column_index': 12,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 5.3329, 'y': 0.8419},
#       {'x': 6.6999, 'y': 0.8419},
#       {'x': 6.6999, 'y': 1.0056},
#       {'x': 5.3329, 'y': 1.0134}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 5.3426, 'y': 0.9559},
#         {'x': 5.3549, 'y': 0.9559},
#         {'x': 5.3549, 'y': 0.9682},
#         {'x': 5.3426, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.5092, 'y': 0.9559},
#         {'x': 5.5216, 'y': 0.9559},
#         {'x': 5.5216, 'y': 0.9682},
#         {'x': 5.5092, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.6759, 'y': 0.9559},
#         {'x': 5.6882, 'y': 0.9559},
#         {'x': 5.6882, 'y': 0.9682},
#         {'x': 5.6759, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.8426, 'y': 0.9559},
#         {'x': 5.8549, 'y': 0.9559},
#         {'x': 5.8549, 'y': 0.9682},
#         {'x': 5.8426, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.0092, 'y': 0.9559},
#         {'x': 6.0216, 'y': 0.9559},
#         {'x': 6.0216, 'y': 0.9682},
#         {'x': 6.0092, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.1759, 'y': 0.9559},
#         {'x': 6.1882, 'y': 0.9559},
#         {'x': 6.1882, 'y': 0.9682},
#         {'x': 6.1759, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.3426, 'y': 0.9559},
#         {'x': 6.3549, 'y': 0.9559},
#         {'x': 6.3549, 'y': 0.9682},
#         {'x': 6.3426, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.5092, 'y': 0.9559},
#         {'x': 6.5216, 'y': 0.9559},
#         {'x': 6.5216, 'y': 0.9682},
#         {'x': 6.5092, 'y': 0.9682}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '18',
#      'row_index': 3,
#      'column_index': 14,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 6.6999, 'y': 0.8419},
#       {'x': 6.9967, 'y': 0.8419},
#       {'x': 6.9967, 'y': 1.0056},
#       {'x': 6.6999, 'y': 1.0056}],
#      'field_elements': [{'text': '18',
#        'bounding_box': [{'x': 6.7964, 'y': 0.8889},
#         {'x': 6.9102, 'y': 0.8889},
#         {'x': 6.9102, 'y': 0.9697},
#         {'x': 6.7964, 'y': 0.9697}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 15,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 6.9967, 'y': 0.8419},
#       {'x': 7.9965, 'y': 0.8419},
#       {'x': 7.9965, 'y': 1.0056},
#       {'x': 6.9967, 'y': 1.0056}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 0.4041, 'y': 1.0134},
#       {'x': 1.2555, 'y': 1.0134},
#       {'x': 1.2555, 'y': 1.1849},
#       {'x': 0.4041, 'y': 1.1849}],
#      'field_elements': []},
#     {'text': '19',
#      'row_index': 4,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.2555, 'y': 1.0134},
#       {'x': 1.5289, 'y': 1.0134},
#       {'x': 1.5289, 'y': 1.1849},
#       {'x': 1.2555, 'y': 1.1849}],
#      'field_elements': [{'text': '19',
#        'bounding_box': [{'x': 1.2847, 'y': 1.0555},
#         {'x': 1.3977, 'y': 1.0555},
#         {'x': 1.3977, 'y': 1.1363},
#         {'x': 1.2847, 'y': 1.1363}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': 'Child tax credit or credit for other dependents from',
#      'row_index': 4,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 6,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 1.5289, 'y': 1.0134},
#       {'x': 4.2003, 'y': 1.0134},
#       {'x': 4.2003, 'y': 1.1849},
#       {'x': 1.5289, 'y': 1.1849}],
#      'field_elements': [{'text': 'Child',
#        'bounding_box': [{'x': 1.6048, 'y': 1.0537},
#         {'x': 1.8498, 'y': 1.0537},
#         {'x': 1.8498, 'y': 1.1367},
#         {'x': 1.6048, 'y': 1.1367}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'tax',
#        'bounding_box': [{'x': 1.8891, 'y': 1.0602},
#         {'x': 2.0393, 'y': 1.0602},
#         {'x': 2.0393, 'y': 1.1361},
#         {'x': 1.8891, 'y': 1.1361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'credit',
#        'bounding_box': [{'x': 2.0752, 'y': 1.0555},
#         {'x': 2.3498, 'y': 1.0555},
#         {'x': 2.3498, 'y': 1.1361},
#         {'x': 2.0752, 'y': 1.1361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'or',
#        'bounding_box': [{'x': 2.388, 'y': 1.0758},
#         {'x': 2.4848, 'y': 1.0758},
#         {'x': 2.4848, 'y': 1.1361},
#         {'x': 2.388, 'y': 1.1361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'credit',
#        'bounding_box': [{'x': 2.5197, 'y': 1.0555},
#         {'x': 2.7942, 'y': 1.0555},
#         {'x': 2.7942, 'y': 1.1361},
#         {'x': 2.5197, 'y': 1.1361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'for',
#        'bounding_box': [{'x': 2.8298, 'y': 1.0547},
#         {'x': 2.9621, 'y': 1.0547},
#         {'x': 2.9621, 'y': 1.1361},
#         {'x': 2.8298, 'y': 1.1361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'other',
#        'bounding_box': [{'x': 2.997, 'y': 1.0555},
#         {'x': 3.2502, 'y': 1.0555},
#         {'x': 3.2502, 'y': 1.1361},
#         {'x': 2.997, 'y': 1.1361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'dependents',
#        'bounding_box': [{'x': 3.2851, 'y': 1.0555},
#         {'x': 3.8686, 'y': 1.0555},
#         {'x': 3.8686, 'y': 1.1568},
#         {'x': 3.2851, 'y': 1.1568}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': 'from',
#        'bounding_box': [{'x': 3.9041, 'y': 1.0547},
#         {'x': 4.1241, 'y': 1.0547},
#         {'x': 4.1241, 'y': 1.1361},
#         {'x': 3.9041, 'y': 1.1361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': 'Schedule 8812 . .',
#      'row_index': 4,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 4,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 4.2003, 'y': 1.0134},
#       {'x': 5.3329, 'y': 1.0134},
#       {'x': 5.3329, 'y': 1.1771},
#       {'x': 4.2003, 'y': 1.1849}],
#      'field_elements': [{'text': 'Schedule',
#        'bounding_box': [{'x': 4.1662, 'y': 1.0537},
#         {'x': 4.6251, 'y': 1.0537},
#         {'x': 4.6251, 'y': 1.1367},
#         {'x': 4.1662, 'y': 1.1367}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '8812',
#        'bounding_box': [{'x': 4.6626, 'y': 1.0561},
#         {'x': 4.8983, 'y': 1.0561},
#         {'x': 4.8983, 'y': 1.1361},
#         {'x': 4.6626, 'y': 1.1361}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.0092, 'y': 1.1225},
#         {'x': 5.0216, 'y': 1.1225},
#         {'x': 5.0216, 'y': 1.1349},
#         {'x': 5.0092, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.1759, 'y': 1.1225},
#         {'x': 5.1882, 'y': 1.1225},
#         {'x': 5.1882, 'y': 1.1349},
#         {'x': 5.1759, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '. . . . . . . .',
#      'row_index': 4,
#      'column_index': 12,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 5.3329, 'y': 1.0134},
#       {'x': 6.6999, 'y': 1.0056},
#       {'x': 6.6999, 'y': 1.1771},
#       {'x': 5.3329, 'y': 1.1771}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 5.3426, 'y': 1.1225},
#         {'x': 5.3549, 'y': 1.1225},
#         {'x': 5.3549, 'y': 1.1349},
#         {'x': 5.3426, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.5092, 'y': 1.1225},
#         {'x': 5.5216, 'y': 1.1225},
#         {'x': 5.5216, 'y': 1.1349},
#         {'x': 5.5092, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.6759, 'y': 1.1225},
#         {'x': 5.6882, 'y': 1.1225},
#         {'x': 5.6882, 'y': 1.1349},
#         {'x': 5.6759, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.8426, 'y': 1.1225},
#         {'x': 5.8549, 'y': 1.1225},
#         {'x': 5.8549, 'y': 1.1349},
#         {'x': 5.8426, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.0092, 'y': 1.1225},
#         {'x': 6.0216, 'y': 1.1225},
#         {'x': 6.0216, 'y': 1.1349},
#         {'x': 6.0092, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.1759, 'y': 1.1225},
#         {'x': 6.1882, 'y': 1.1225},
#         {'x': 6.1882, 'y': 1.1349},
#         {'x': 6.1759, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.3426, 'y': 1.1225},
#         {'x': 6.3549, 'y': 1.1225},
#         {'x': 6.3549, 'y': 1.1349},
#         {'x': 6.3426, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.5092, 'y': 1.1225},
#         {'x': 6.5216, 'y': 1.1225},
#         {'x': 6.5216, 'y': 1.1349},
#         {'x': 6.5092, 'y': 1.1349}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '19',
#      'row_index': 4,
#      'column_index': 14,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
#      'bounding_box': [{'x': 6.6999, 'y': 1.0056},
#       {'x': 6.9967, 'y': 1.0056},
#       {'x': 6.9967, 'y': 1.1771},
#       {'x': 6.6999, 'y': 1.1771}],
#      'field_elements': [{'text': '19',
#        'bounding_box': [{'x': 6.7964, 'y': 1.0555},
#         {'x': 6.9094, 'y': 1.0555},
#         {'x': 6.9094, 'y': 1.1363},
#         {'x': 6.7964, 'y': 1.1363}],
#        'confidence': 1.0,
#        'page_number': 2,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 15,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 2,
# ...
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Paid',
#    'bounding_box': [{'x': 0.5105, 'y': 7.5291},
#     {'x': 0.8143, 'y': 7.5291},
#     {'x': 0.8143, 'y': 7.6402},
#     {'x': 0.5105, 'y': 7.6402}],
#    'words': [{'text': 'Paid',
#      'bounding_box': [{'x': 0.5105, 'y': 7.5291},
#       {'x': 0.8143, 'y': 7.5291},
#       {'x': 0.8143, 'y': 7.6402},
#       {'x': 0.5105, 'y': 7.6402}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Preparer’s name',
#    'bounding_box': [{'x': 1.4076, 'y': 7.4583},
#     {'x': 2.1166, 'y': 7.4583},
#     {'x': 2.1166, 'y': 7.5469},
#     {'x': 1.4076, 'y': 7.5469}],
#    'words': [{'text': 'Preparer’s',
#      'bounding_box': [{'x': 1.4076, 'y': 7.4583},
#       {'x': 1.8471, 'y': 7.4583},
#       {'x': 1.8471, 'y': 7.5469},
#       {'x': 1.4076, 'y': 7.5469}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'name',
#      'bounding_box': [{'x': 1.8833, 'y': 7.4763},
#       {'x': 2.1166, 'y': 7.4763},
#       {'x': 2.1166, 'y': 7.5288},
#       {'x': 1.8833, 'y': 7.5288}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Preparer’s signature',
#    'bounding_box': [{'x': 3.0631, 'y': 7.4583},
#     {'x': 3.9323, 'y': 7.4583},
#     {'x': 3.9323, 'y': 7.5481},
#     {'x': 3.0631, 'y': 7.5481}],
#    'words': [{'text': 'Preparer’s',
#      'bounding_box': [{'x': 3.0631, 'y': 7.4583},
#       {'x': 3.5027, 'y': 7.4583},
#       {'x': 3.5027, 'y': 7.5469},
#       {'x': 3.0631, 'y': 7.5469}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'signature',
#      'bounding_box': [{'x': 3.5356, 'y': 7.4583},
#       {'x': 3.9323, 'y': 7.4583},
#       {'x': 3.9323, 'y': 7.5481},
#       {'x': 3.5356, 'y': 7.5481}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Date',
#    'bounding_box': [{'x': 5.4631, 'y': 7.4583},
#     {'x': 5.6572, 'y': 7.4583},
#     {'x': 5.6572, 'y': 7.5288},
#     {'x': 5.4631, 'y': 7.5288}],
#    'words': [{'text': 'Date',
#      'bounding_box': [{'x': 5.4631, 'y': 7.4583},
#       {'x': 5.6572, 'y': 7.4583},
#       {'x': 5.6572, 'y': 7.5288},
#       {'x': 5.4631, 'y': 7.5288}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'PTIN',
#    'bounding_box': [{'x': 6.2902, 'y': 7.4583},
#     {'x': 6.4894, 'y': 7.4583},
#     {'x': 6.4894, 'y': 7.5277},
#     {'x': 6.2902, 'y': 7.5277}],
#    'words': [{'text': 'PTIN',
#      'bounding_box': [{'x': 6.2902, 'y': 7.4583},
#       {'x': 6.4894, 'y': 7.4583},
#       {'x': 6.4894, 'y': 7.5277},
#       {'x': 6.2902, 'y': 7.5277}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Check if:',
#    'bounding_box': [{'x': 7.0597, 'y': 7.4567},
#     {'x': 7.4309, 'y': 7.4567},
#     {'x': 7.4309, 'y': 7.5293},
#     {'x': 7.0597, 'y': 7.5293}],
#    'words': [{'text': 'Check',
#      'bounding_box': [{'x': 7.0597, 'y': 7.4567},
#       {'x': 7.3347, 'y': 7.4567},
#       {'x': 7.3347, 'y': 7.5293},
#       {'x': 7.0597, 'y': 7.5293}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'if:',
#      'bounding_box': [{'x': 7.3684, 'y': 7.4575},
#       {'x': 7.4309, 'y': 7.4575},
#       {'x': 7.4309, 'y': 7.5277},
#       {'x': 7.3684, 'y': 7.5277}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Preparer',
#    'bounding_box': [{'x': 0.5105, 'y': 7.6958},
#     {'x': 1.1363, 'y': 7.6958},
#     {'x': 1.1363, 'y': 7.8326},
#     {'x': 0.5105, 'y': 7.8326}],
#    'words': [{'text': 'Preparer',
#      'bounding_box': [{'x': 0.5105, 'y': 7.6958},
#       {'x': 1.1363, 'y': 7.6958},
#       {'x': 1.1363, 'y': 7.8326},
#       {'x': 0.5105, 'y': 7.8326}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Self-employed',
#    'bounding_box': [{'x': 7.2536, 'y': 7.6233},
#     {'x': 7.8755, 'y': 7.6233},
#     {'x': 7.8755, 'y': 7.7144},
#     {'x': 7.2536, 'y': 7.7144}],
#    'words': [{'text': 'Self-employed',
#      'bounding_box': [{'x': 7.2536, 'y': 7.6233},
#       {'x': 7.8755, 'y': 7.6233},
#       {'x': 7.8755, 'y': 7.7144},
#       {'x': 7.2536, 'y': 7.7144}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Use Only',
#    'bounding_box': [{'x': 0.5101, 'y': 7.8599},
#     {'x': 1.1545, 'y': 7.8599},
#     {'x': 1.1545, 'y': 7.9992},
#     {'x': 0.5101, 'y': 7.9992}],
#    'words': [{'text': 'Use',
#      'bounding_box': [{'x': 0.5101, 'y': 7.8625},
#       {'x': 0.7799, 'y': 7.8625},
#       {'x': 0.7799, 'y': 7.974},
#       {'x': 0.5101, 'y': 7.974}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'Only',
#      'bounding_box': [{'x': 0.8312, 'y': 7.8599},
#       {'x': 1.1545, 'y': 7.8599},
#       {'x': 1.1545, 'y': 7.9992},
#       {'x': 0.8312, 'y': 7.9992}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Firm’s name',
#    'bounding_box': [{'x': 1.4076, 'y': 7.8125},
#     {'x': 1.9349, 'y': 7.8125},
#     {'x': 1.9349, 'y': 7.883},
#     {'x': 1.4076, 'y': 7.883}],
#    'words': [{'text': 'Firm’s',
#      'bounding_box': [{'x': 1.4076, 'y': 7.8125},
#       {'x': 1.6654, 'y': 7.8125},
#       {'x': 1.6654, 'y': 7.883},
#       {'x': 1.4076, 'y': 7.883}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'name',
#      'bounding_box': [{'x': 1.7016, 'y': 7.8305},
#       {'x': 1.9349, 'y': 7.8305},
#       {'x': 1.9349, 'y': 7.883},
#       {'x': 1.7016, 'y': 7.883}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Phone no.',
#    'bounding_box': [{'x': 6.4631, 'y': 7.8125},
#     {'x': 6.8904, 'y': 7.8125},
#     {'x': 6.8904, 'y': 7.883},
#     {'x': 6.4631, 'y': 7.883}],
#    'words': [{'text': 'Phone',
#      'bounding_box': [{'x': 6.4631, 'y': 7.8125},
#       {'x': 6.7328, 'y': 7.8125},
#       {'x': 6.7328, 'y': 7.883},
#       {'x': 6.4631, 'y': 7.883}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'no.',
#      'bounding_box': [{'x': 6.7679, 'y': 7.8305},
#       {'x': 6.8904, 'y': 7.8305},
#       {'x': 6.8904, 'y': 7.883},
#       {'x': 6.7679, 'y': 7.883}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Firm’s address',
#    'bounding_box': [{'x': 1.4076, 'y': 7.9791},
#     {'x': 2.0418, 'y': 7.9791},
#     {'x': 2.0418, 'y': 8.0496},
#     {'x': 1.4076, 'y': 8.0496}],
#    'words': [{'text': 'Firm’s',
#      'bounding_box': [{'x': 1.4076, 'y': 7.9791},
#       {'x': 1.6654, 'y': 7.9791},
#       {'x': 1.6654, 'y': 8.0496},
#       {'x': 1.4076, 'y': 8.0496}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'address',
#      'bounding_box': [{'x': 1.6988, 'y': 7.9791},
#       {'x': 2.0418, 'y': 7.9791},
#       {'x': 2.0418, 'y': 8.0496},
#       {'x': 1.6988, 'y': 8.0496}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Firm’s EIN',
#    'bounding_box': [{'x': 6.4631, 'y': 7.9791},
#     {'x': 6.8983, 'y': 7.9791},
#     {'x': 6.8983, 'y': 8.0496},
#     {'x': 6.4631, 'y': 8.0496}],
#    'words': [{'text': 'Firm’s',
#      'bounding_box': [{'x': 6.4631, 'y': 7.9791},
#       {'x': 6.721, 'y': 7.9791},
#       {'x': 6.721, 'y': 8.0496},
#       {'x': 6.4631, 'y': 8.0496}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'EIN',
#      'bounding_box': [{'x': 6.7585, 'y': 7.9791},
#       {'x': 6.8983, 'y': 7.9791},
#       {'x': 6.8983, 'y': 8.0486},
#       {'x': 6.7585, 'y': 8.0486}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Go to www.irs.gov/Form1040 for instructions and the latest information.',
#    'bounding_box': [{'x': 0.5042, 'y': 8.1511},
#     {'x': 3.6087, 'y': 8.1511},
#     {'x': 3.6087, 'y': 8.2425},
#     {'x': 0.5042, 'y': 8.2425}],
#    'words': [{'text': 'Go',
#      'bounding_box': [{'x': 0.5042, 'y': 8.1511},
#       {'x': 0.6261, 'y': 8.1511},
#       {'x': 0.6261, 'y': 8.2238},
#       {'x': 0.5042, 'y': 8.2238}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'to',
#      'bounding_box': [{'x': 0.6575, 'y': 8.1569},
#       {'x': 0.7396, 'y': 8.1569},
#       {'x': 0.7396, 'y': 8.2233},
#       {'x': 0.6575, 'y': 8.2233}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'www.irs.gov/Form1040',
#      'bounding_box': [{'x': 0.7741, 'y': 8.1511},
#       {'x': 1.7771, 'y': 8.1511},
#       {'x': 1.7771, 'y': 8.2425},
#       {'x': 0.7741, 'y': 8.2425}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'for',
#      'bounding_box': [{'x': 1.8082, 'y': 8.152},
#       {'x': 1.924, 'y': 8.152},
#       {'x': 1.924, 'y': 8.2233},
#       {'x': 1.8082, 'y': 8.2233}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'instructions',
#      'bounding_box': [{'x': 1.9578, 'y': 8.1528},
#       {'x': 2.4523, 'y': 8.1528},
#       {'x': 2.4523, 'y': 8.2233},
#       {'x': 1.9578, 'y': 8.2233}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'and',
#      'bounding_box': [{'x': 2.4858, 'y': 8.1528},
#       {'x': 2.6397, 'y': 8.1528},
#       {'x': 2.6397, 'y': 8.2233},
#       {'x': 2.4858, 'y': 8.2233}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'the',
#      'bounding_box': [{'x': 2.6741, 'y': 8.1528},
#       {'x': 2.8082, 'y': 8.1528},
#       {'x': 2.8082, 'y': 8.2233},
#       {'x': 2.6741, 'y': 8.2233}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'latest',
#      'bounding_box': [{'x': 2.8438, 'y': 8.1528},
#       {'x': 3.0701, 'y': 8.1528},
#       {'x': 3.0701, 'y': 8.2233},
#       {'x': 2.8438, 'y': 8.2233}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': 'information.',
#      'bounding_box': [{'x': 3.1067, 'y': 8.152},
#       {'x': 3.6087, 'y': 8.152},
#       {'x': 3.6087, 'y': 8.2233},
#       {'x': 3.1067, 'y': 8.2233}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Form 1040 (2022)',
#    'bounding_box': [{'x': 7.236, 'y': 8.1361},
#     {'x': 7.9961, 'y': 8.1361},
#     {'x': 7.9961, 'y': 8.2418},
#     {'x': 7.236, 'y': 8.2418}],
#    'words': [{'text': 'Form',
#      'bounding_box': [{'x': 7.236, 'y': 8.1659},
#       {'x': 7.4187, 'y': 8.1659},
#       {'x': 7.4187, 'y': 8.2263},
#       {'x': 7.236, 'y': 8.2263}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': '1040',
#      'bounding_box': [{'x': 7.468, 'y': 8.1361},
#       {'x': 7.7341, 'y': 8.1361},
#       {'x': 7.7341, 'y': 8.227},
#       {'x': 7.468, 'y': 8.227}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'},
#     {'text': '(2022)',
#      'bounding_box': [{'x': 7.7754, 'y': 8.1644},
#       {'x': 7.9961, 'y': 8.1644},
#       {'x': 7.9961, 'y': 8.2418},
#       {'x': 7.7754, 'y': 8.2418}],
#      'confidence': 1.0,
#      'page_number': 2,
#      'kind': 'word'}],
#    'page_number': 2,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}}],
#  'selection_marks': [{'text': None,
#    'bounding_box': [{'x': 4.1278, 'y': 0.5417},
#     {'x': 4.2389, 'y': 0.5417},
#     {'x': 4.2389, 'y': 0.6528},
#     {'x': 4.1278, 'y': 0.6528}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 4.8278, 'y': 0.5417},
#     {'x': 4.9389, 'y': 0.5417},
#     {'x': 4.9389, 'y': 0.6528},
#     {'x': 4.8278, 'y': 0.6528}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 5.5278, 'y': 0.5417},
#     {'x': 5.6389, 'y': 0.5417},
#     {'x': 5.6389, 'y': 0.6528},
#     {'x': 5.5278, 'y': 0.6528}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.4611, 'y': 4.3681},
#     {'x': 6.5722, 'y': 4.3681},
#     {'x': 6.5722, 'y': 4.4792},
#     {'x': 6.4611, 'y': 4.4792}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 5.2417, 'y': 4.5417},
#     {'x': 5.3528, 'y': 4.5417},
#     {'x': 5.3528, 'y': 4.6528},
#     {'x': 5.2417, 'y': 4.6528}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.0417, 'y': 4.5417},
#     {'x': 6.1528, 'y': 4.5417},
#     {'x': 6.1528, 'y': 4.6528},
#     {'x': 6.0417, 'y': 4.6528}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.3973, 'y': 4.7343},
#     {'x': 1.4627, 'y': 4.7343},
#     {'x': 1.4627, 'y': 4.8031},
#     {'x': 1.3973, 'y': 4.8031}],
#    'confidence': 0.394,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 5.7, 'y': 5.6736},
#     {'x': 5.8111, 'y': 5.6736},
#     {'x': 5.8111, 'y': 5.7847},
#     {'x': 5.7, 'y': 5.7847}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.1, 'y': 5.6736},
#     {'x': 7.2111, 'y': 5.6736},
#     {'x': 7.2111, 'y': 5.7847},
#     {'x': 7.1, 'y': 5.7847}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.0111, 'y': 5.9259},
#     {'x': 7.1927, 'y': 5.9259},
#     {'x': 7.1927, 'y': 6.0649},
#     {'x': 7.0111, 'y': 6.0649}],
#    'confidence': 0.294,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.9989, 'y': 6.6707},
#     {'x': 7.1595, 'y': 6.6707},
#     {'x': 7.1595, 'y': 6.82},
#     {'x': 6.9989, 'y': 6.82}],
#    'confidence': 0.394,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.9999, 'y': 7.0815},
#     {'x': 7.1506, 'y': 7.0815},
#     {'x': 7.1506, 'y': 7.2428},
#     {'x': 6.9999, 'y': 7.2428}],
#    'confidence': 0.394,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.1, 'y': 7.5972},
#     {'x': 7.2111, 'y': 7.5972},
#     {'x': 7.2111, 'y': 7.7083},
#     {'x': 7.1, 'y': 7.7083}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 2,
#    'kind': 'selectionMark'}]}

# %% [markdown]
# #### Access all lines

# %%
len(content.lines)
# Out:
# 476

# %% [markdown]
# #### Exploring content object

# %%
# Page 1
content.to_dict()
# Out:
# {'page_number': 1,
#  'text_angle': 0.0,
#  'width': 8.5,
#  'height': 11.0,
#  'unit': 'inch',
#  'tables': [{'page_number': 1,
#    'row_count': 31,
#    'column_count': 10,
#    'cells': [{'text': 'Age/Blindness',
#      'row_index': 0,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4464, 'y': 3.9195},
#       {'x': 1.2812, 'y': 3.9195},
#       {'x': 1.2812, 'y': 4.0812},
#       {'x': 0.4386, 'y': 4.0812}],
#      'field_elements': [{'text': 'Age/Blindness',
#        'bounding_box': [{'x': 0.4994, 'y': 3.9564},
#         {'x': 1.2335, 'y': 3.9564},
#         {'x': 1.2335, 'y': 4.0593},
#         {'x': 0.4994, 'y': 4.0593}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'You: Were born before January 2, 1958',
#      'row_index': 0,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2812, 'y': 3.9195},
#       {'x': 3.6685, 'y': 3.9195},
#       {'x': 3.6607, 'y': 4.0812},
#       {'x': 1.2812, 'y': 4.0812}],
#      'field_elements': [{'text': 'You:',
#        'bounding_box': [{'x': 1.2991, 'y': 3.9583},
#         {'x': 1.5321, 'y': 3.9583},
#         {'x': 1.5321, 'y': 4.0391},
#         {'x': 1.2991, 'y': 4.0391}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Were',
#        'bounding_box': [{'x': 1.8013, 'y': 3.9583},
#         {'x': 2.0545, 'y': 3.9583},
#         {'x': 2.0545, 'y': 4.0389},
#         {'x': 1.8013, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'born',
#        'bounding_box': [{'x': 2.0946, 'y': 3.9583},
#         {'x': 2.3063, 'y': 3.9583},
#         {'x': 2.3063, 'y': 4.0389},
#         {'x': 2.0946, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'before',
#        'bounding_box': [{'x': 2.3513, 'y': 3.9574},
#         {'x': 2.6576, 'y': 3.9574},
#         {'x': 2.6576, 'y': 4.0389},
#         {'x': 2.3513, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'January',
#        'bounding_box': [{'x': 2.6926, 'y': 3.9583},
#         {'x': 3.0785, 'y': 3.9583},
#         {'x': 3.0785, 'y': 4.0605},
#         {'x': 2.6926, 'y': 4.0605}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '2,',
#        'bounding_box': [{'x': 3.1126, 'y': 3.9589},
#         {'x': 3.1925, 'y': 3.9589},
#         {'x': 3.1925, 'y': 4.0539},
#         {'x': 3.1126, 'y': 4.0539}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '1958',
#        'bounding_box': [{'x': 3.2419, 'y': 3.9589},
#         {'x': 3.4726, 'y': 3.9589},
#         {'x': 3.4726, 'y': 4.0389},
#         {'x': 3.2419, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 1.6278, 'y': 3.9375},
#         {'x': 1.7389, 'y': 3.9375},
#         {'x': 1.7389, 'y': 4.0486},
#         {'x': 1.6278, 'y': 4.0486}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Are blind',
#      'row_index': 0,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6685, 'y': 3.9195},
#       {'x': 4.2225, 'y': 3.9195},
#       {'x': 4.2225, 'y': 4.0812},
#       {'x': 3.6607, 'y': 4.0812}],
#      'field_elements': [{'text': 'Are',
#        'bounding_box': [{'x': 3.7993, 'y': 3.9583},
#         {'x': 3.9666, 'y': 3.9583},
#         {'x': 3.9666, 'y': 4.0389},
#         {'x': 3.7993, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'blind',
#        'bounding_box': [{'x': 4.007, 'y': 3.9583},
#         {'x': 4.235, 'y': 3.9583},
#         {'x': 4.235, 'y': 4.0389},
#         {'x': 4.007, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 3.6278, 'y': 3.9375},
#         {'x': 3.7389, 'y': 3.9375},
#         {'x': 3.7389, 'y': 4.0486},
#         {'x': 3.6278, 'y': 4.0486}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Spouse:',
#      'row_index': 0,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2225, 'y': 3.9195},
#       {'x': 4.8856, 'y': 3.9195},
#       {'x': 4.8856, 'y': 4.0812},
#       {'x': 4.2225, 'y': 4.0812}],
#      'field_elements': [{'text': 'Spouse:',
#        'bounding_box': [{'x': 4.5024, 'y': 3.9564},
#         {'x': 4.9214, 'y': 3.9564},
#         {'x': 4.9214, 'y': 4.0578},
#         {'x': 4.5024, 'y': 4.0578}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Was born before January 2, 1958',
#      'row_index': 0,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 3.9195},
#       {'x': 6.9765, 'y': 3.9195},
#       {'x': 6.9765, 'y': 4.0812},
#       {'x': 4.8856, 'y': 4.0812}],
#      'field_elements': [{'text': 'Was',
#        'bounding_box': [{'x': 5.2013, 'y': 3.9583},
#         {'x': 5.4126, 'y': 3.9583},
#         {'x': 5.4126, 'y': 4.0389},
#         {'x': 5.2013, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'born',
#        'bounding_box': [{'x': 5.4539, 'y': 3.9583},
#         {'x': 5.6656, 'y': 3.9583},
#         {'x': 5.6656, 'y': 4.0389},
#         {'x': 5.4539, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'before',
#        'bounding_box': [{'x': 5.7106, 'y': 3.9574},
#         {'x': 6.0169, 'y': 3.9574},
#         {'x': 6.0169, 'y': 4.0389},
#         {'x': 5.7106, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'January',
#        'bounding_box': [{'x': 6.052, 'y': 3.9583},
#         {'x': 6.4378, 'y': 3.9583},
#         {'x': 6.4378, 'y': 4.0605},
#         {'x': 6.052, 'y': 4.0605}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '2,',
#        'bounding_box': [{'x': 6.4719, 'y': 3.9589},
#         {'x': 6.5518, 'y': 3.9589},
#         {'x': 6.5518, 'y': 4.0539},
#         {'x': 6.4719, 'y': 4.0539}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '1958',
#        'bounding_box': [{'x': 6.6012, 'y': 3.9589},
#         {'x': 6.8318, 'y': 3.9589},
#         {'x': 6.8318, 'y': 4.0389},
#         {'x': 6.6012, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 5.0278, 'y': 3.9375},
#         {'x': 5.1389, 'y': 3.9375},
#         {'x': 5.1389, 'y': 4.0486},
#         {'x': 5.0278, 'y': 4.0486}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Is blind',
#      'row_index': 0,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9765, 'y': 3.9195},
#       {'x': 7.9985, 'y': 3.9195},
#       {'x': 7.9985, 'y': 4.0812},
#       {'x': 6.9765, 'y': 4.0812}],
#      'field_elements': [{'text': 'Is',
#        'bounding_box': [{'x': 7.2091, 'y': 3.9583},
#         {'x': 7.281, 'y': 3.9583},
#         {'x': 7.281, 'y': 4.0389},
#         {'x': 7.2091, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'blind',
#        'bounding_box': [{'x': 7.3227, 'y': 3.9583},
#         {'x': 7.5507, 'y': 3.9583},
#         {'x': 7.5507, 'y': 4.0389},
#         {'x': 7.3227, 'y': 4.0389}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 7.0278, 'y': 3.9375},
#         {'x': 7.1389, 'y': 3.9375},
#         {'x': 7.1389, 'y': 4.0486},
#         {'x': 7.0278, 'y': 4.0486}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Dependents If more',
#      'row_index': 1,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4386, 'y': 4.0812},
#       {'x': 1.2812, 'y': 4.0812},
#       {'x': 1.2734, 'y': 4.4123},
#       {'x': 0.4386, 'y': 4.42}],
#      'field_elements': [{'text': 'Dependents',
#        'bounding_box': [{'x': 0.509, 'y': 4.1389},
#         {'x': 1.2486, 'y': 4.1389},
#         {'x': 1.2486, 'y': 4.257},
#         {'x': 0.509, 'y': 4.257}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'If',
#        'bounding_box': [{'x': 0.5091, 'y': 4.3338},
#         {'x': 0.5618, 'y': 4.3338},
#         {'x': 0.5618, 'y': 4.4141},
#         {'x': 0.5091, 'y': 4.4141}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'more',
#        'bounding_box': [{'x': 0.5997, 'y': 4.355},
#         {'x': 0.8457, 'y': 4.355},
#         {'x': 0.8457, 'y': 4.4153},
#         {'x': 0.5997, 'y': 4.4153}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '(see instructions): (1) First name Last name',
#      'row_index': 1,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2812, 'y': 4.0812},
#       {'x': 3.6607, 'y': 4.0812},
#       {'x': 3.6607, 'y': 4.4123},
#       {'x': 1.2734, 'y': 4.4123}],
#      'field_elements': [{'text': '(see',
#        'bounding_box': [{'x': 1.3052, 'y': 4.1453},
#         {'x': 1.5016, 'y': 4.1453},
#         {'x': 1.5016, 'y': 4.2484},
#         {'x': 1.3052, 'y': 4.2484}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'instructions):',
#        'bounding_box': [{'x': 1.5422, 'y': 4.1453},
#         {'x': 2.1611, 'y': 4.1453},
#         {'x': 2.1611, 'y': 4.2484},
#         {'x': 1.5422, 'y': 4.2484}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '(1)',
#        'bounding_box': [{'x': 1.3328, 'y': 4.2969},
#         {'x': 1.4343, 'y': 4.2969},
#         {'x': 1.4343, 'y': 4.3856},
#         {'x': 1.3328, 'y': 4.3856}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'First',
#        'bounding_box': [{'x': 1.474, 'y': 4.2986},
#         {'x': 1.6525, 'y': 4.2986},
#         {'x': 1.6525, 'y': 4.3691},
#         {'x': 1.474, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'name',
#        'bounding_box': [{'x': 1.6887, 'y': 4.3166},
#         {'x': 1.922, 'y': 4.3166},
#         {'x': 1.922, 'y': 4.3691},
#         {'x': 1.6887, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Last',
#        'bounding_box': [{'x': 2.4656, 'y': 4.2986},
#         {'x': 2.6406, 'y': 4.2986},
#         {'x': 2.6406, 'y': 4.3691},
#         {'x': 2.4656, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'name',
#        'bounding_box': [{'x': 2.6767, 'y': 4.3166},
#         {'x': 2.9101, 'y': 4.3166},
#         {'x': 2.9101, 'y': 4.3691},
#         {'x': 2.6767, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '(2) Social security number',
#      'row_index': 1,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6607, 'y': 4.0812},
#       {'x': 4.8856, 'y': 4.0812},
#       {'x': 4.8856, 'y': 4.4123},
#       {'x': 3.6607, 'y': 4.4123}],
#      'field_elements': [{'text': '(2)',
#        'bounding_box': [{'x': 3.9189, 'y': 4.1553},
#         {'x': 4.0204, 'y': 4.1553},
#         {'x': 4.0204, 'y': 4.244},
#         {'x': 3.9189, 'y': 4.244}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Social',
#        'bounding_box': [{'x': 4.0561, 'y': 4.1553},
#         {'x': 4.3123, 'y': 4.1553},
#         {'x': 4.3123, 'y': 4.2279},
#         {'x': 4.0561, 'y': 4.2279}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'security',
#        'bounding_box': [{'x': 4.3489, 'y': 4.157},
#         {'x': 4.6854, 'y': 4.157},
#         {'x': 4.6854, 'y': 4.2464},
#         {'x': 4.3489, 'y': 4.2464}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'number',
#        'bounding_box': [{'x': 4.1396, 'y': 4.2736},
#         {'x': 4.4667, 'y': 4.2736},
#         {'x': 4.4667, 'y': 4.3441},
#         {'x': 4.1396, 'y': 4.3441}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 3.9153, 'y': 4.1506},
#         {'x': 4.022, 'y': 4.1506},
#         {'x': 4.022, 'y': 4.2379},
#         {'x': 3.9153, 'y': 4.2379}],
#        'confidence': 0.223,
#        'state': 'selected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '(3) Relationship to you',
#      'row_index': 1,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.0812},
#       {'x': 5.775, 'y': 4.0812},
#       {'x': 5.775, 'y': 4.4123},
#       {'x': 4.8856, 'y': 4.4123}],
#      'field_elements': [{'text': '(3)',
#        'bounding_box': [{'x': 5.0175, 'y': 4.1553},
#         {'x': 5.119, 'y': 4.1553},
#         {'x': 5.119, 'y': 4.244},
#         {'x': 5.0175, 'y': 4.244}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Relationship',
#        'bounding_box': [{'x': 5.1586, 'y': 4.157},
#         {'x': 5.6841, 'y': 4.157},
#         {'x': 5.6841, 'y': 4.2455},
#         {'x': 5.1586, 'y': 4.2455}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'to',
#        'bounding_box': [{'x': 5.2149, 'y': 4.2777},
#         {'x': 5.297, 'y': 4.2777},
#         {'x': 5.297, 'y': 4.3441},
#         {'x': 5.2149, 'y': 4.3441}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'you',
#        'bounding_box': [{'x': 5.3283, 'y': 4.2916},
#         {'x': 5.4798, 'y': 4.2916},
#         {'x': 5.4798, 'y': 4.3631},
#         {'x': 5.3283, 'y': 4.3631}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '(4) Check the box if qualifies Child tax credit',
#      'row_index': 1,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.775, 'y': 4.0812},
#       {'x': 6.9765, 'y': 4.0812},
#       {'x': 6.9765, 'y': 4.4123},
#       {'x': 5.775, 'y': 4.4123}],
#      'field_elements': [{'text': '(4)',
#        'bounding_box': [{'x': 5.8313, 'y': 4.1234},
#         {'x': 5.9328, 'y': 4.1234},
#         {'x': 5.9328, 'y': 4.212},
#         {'x': 5.8313, 'y': 4.212}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Check',
#        'bounding_box': [{'x': 5.969, 'y': 4.1234},
#         {'x': 6.2412, 'y': 4.1234},
#         {'x': 6.2412, 'y': 4.196},
#         {'x': 5.969, 'y': 4.196}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'the',
#        'bounding_box': [{'x': 6.2688, 'y': 4.125},
#         {'x': 6.4017, 'y': 4.125},
#         {'x': 6.4017, 'y': 4.1955},
#         {'x': 6.2688, 'y': 4.1955}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'box',
#        'bounding_box': [{'x': 6.4367, 'y': 4.125},
#         {'x': 6.5916, 'y': 4.125},
#         {'x': 6.5916, 'y': 4.1955},
#         {'x': 6.4367, 'y': 4.1955}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'if',
#        'bounding_box': [{'x': 6.6258, 'y': 4.1242},
#         {'x': 6.6691, 'y': 4.1242},
#         {'x': 6.6691, 'y': 4.1944},
#         {'x': 6.6258, 'y': 4.1944}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'qualifies',
#        'bounding_box': [{'x': 6.6993, 'y': 4.1242},
#         {'x': 7.0476, 'y': 4.1242},
#         {'x': 7.0476, 'y': 4.2136},
#         {'x': 6.6993, 'y': 4.2136}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Child',
#        'bounding_box': [{'x': 6.0247, 'y': 4.2969},
#         {'x': 6.2391, 'y': 4.2969},
#         {'x': 6.2391, 'y': 4.3696},
#         {'x': 6.0247, 'y': 4.3696}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'tax',
#        'bounding_box': [{'x': 6.2735, 'y': 4.3027},
#         {'x': 6.4049, 'y': 4.3027},
#         {'x': 6.4049, 'y': 4.3691},
#         {'x': 6.2735, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'credit',
#        'bounding_box': [{'x': 6.4363, 'y': 4.2986},
#         {'x': 6.6766, 'y': 4.2986},
#         {'x': 6.6766, 'y': 4.3691},
#         {'x': 6.4363, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'for (see instructions): Credit for other dependents',
#      'row_index': 1,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9765, 'y': 4.0812},
#       {'x': 7.9985, 'y': 4.0812},
#       {'x': 7.9985, 'y': 4.4123},
#       {'x': 6.9765, 'y': 4.4123}],
#      'field_elements': [{'text': 'for',
#        'bounding_box': [{'x': 7.0784, 'y': 4.1242},
#         {'x': 7.193, 'y': 4.1242},
#         {'x': 7.193, 'y': 4.1955},
#         {'x': 7.0784, 'y': 4.1955}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '(see',
#        'bounding_box': [{'x': 7.2243, 'y': 4.1234},
#         {'x': 7.3944, 'y': 4.1234},
#         {'x': 7.3944, 'y': 4.2136},
#         {'x': 7.2243, 'y': 4.2136}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'instructions):',
#        'bounding_box': [{'x': 7.4296, 'y': 4.1234},
#         {'x': 7.9657, 'y': 4.1234},
#         {'x': 7.9657, 'y': 4.2136},
#         {'x': 7.4296, 'y': 4.2136}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Credit',
#        'bounding_box': [{'x': 6.9315, 'y': 4.2969},
#         {'x': 7.162, 'y': 4.2969},
#         {'x': 7.162, 'y': 4.3696},
#         {'x': 6.9315, 'y': 4.3696}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'for',
#        'bounding_box': [{'x': 7.1899, 'y': 4.2978},
#         {'x': 7.2935, 'y': 4.2978},
#         {'x': 7.2935, 'y': 4.3691},
#         {'x': 7.1899, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'other',
#        'bounding_box': [{'x': 7.3208, 'y': 4.2986},
#         {'x': 7.5191, 'y': 4.2986},
#         {'x': 7.5191, 'y': 4.3691},
#         {'x': 7.3208, 'y': 4.3691}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'dependents',
#        'bounding_box': [{'x': 7.5464, 'y': 4.2986},
#         {'x': 8.0034, 'y': 4.2986},
#         {'x': 8.0034, 'y': 4.3872},
#         {'x': 7.5464, 'y': 4.3872}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'than four',
#      'row_index': 2,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4386, 'y': 4.42},
#       {'x': 1.2734, 'y': 4.4123},
#       {'x': 1.2656, 'y': 4.574},
#       {'x': 0.4386, 'y': 4.574}],
#      'field_elements': [{'text': 'than',
#        'bounding_box': [{'x': 0.501, 'y': 4.4563},
#         {'x': 0.7111, 'y': 4.4563},
#         {'x': 0.7111, 'y': 4.5368},
#         {'x': 0.501, 'y': 4.5368}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'four',
#        'bounding_box': [{'x': 0.7504, 'y': 4.4554},
#         {'x': 0.9446, 'y': 4.4554},
#         {'x': 0.9446, 'y': 4.5368},
#         {'x': 0.7504, 'y': 4.5368}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2734, 'y': 4.4123},
#       {'x': 3.6607, 'y': 4.4123},
#       {'x': 3.6607, 'y': 4.5817},
#       {'x': 1.2656, 'y': 4.574}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6607, 'y': 4.4123},
#       {'x': 4.2225, 'y': 4.4123},
#       {'x': 4.2303, 'y': 4.5817},
#       {'x': 3.6607, 'y': 4.5817}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2225, 'y': 4.4123},
#       {'x': 4.8856, 'y': 4.4123},
#       {'x': 4.8856, 'y': 4.5817},
#       {'x': 4.2303, 'y': 4.5817}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.4123},
#       {'x': 5.775, 'y': 4.4123},
#       {'x': 5.775, 'y': 4.5817},
#       {'x': 4.8856, 'y': 4.5817}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.775, 'y': 4.4123},
#       {'x': 6.9765, 'y': 4.4123},
#       {'x': 6.9843, 'y': 4.5817},
#       {'x': 5.775, 'y': 4.5817}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 6.2944, 'y': 4.4444},
#         {'x': 6.4056, 'y': 4.4444},
#         {'x': 6.4056, 'y': 4.5555},
#         {'x': 6.2944, 'y': 4.5555}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 2,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9765, 'y': 4.4123},
#       {'x': 7.9985, 'y': 4.4123},
#       {'x': 7.9985, 'y': 4.5817},
#       {'x': 6.9843, 'y': 4.5817}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 7.3944, 'y': 4.4444},
#         {'x': 7.5056, 'y': 4.4444},
#         {'x': 7.5056, 'y': 4.5555},
#         {'x': 7.3944, 'y': 4.5555}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'dependents,',
#      'row_index': 3,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4386, 'y': 4.574},
#       {'x': 1.2656, 'y': 4.574},
#       {'x': 1.2656, 'y': 4.7203},
#       {'x': 0.4386, 'y': 4.7203}],
#      'field_elements': [{'text': 'dependents,',
#        'bounding_box': [{'x': 0.504, 'y': 4.5778},
#         {'x': 1.1123, 'y': 4.5778},
#         {'x': 1.1123, 'y': 4.6791},
#         {'x': 0.504, 'y': 4.6791}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2656, 'y': 4.574},
#       {'x': 3.6607, 'y': 4.5817},
#       {'x': 3.6607, 'y': 4.7434},
#       {'x': 1.2656, 'y': 4.7203}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6607, 'y': 4.5817},
#       {'x': 4.2303, 'y': 4.5817},
#       {'x': 4.2303, 'y': 4.7434},
#       {'x': 3.6607, 'y': 4.7434}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2303, 'y': 4.5817},
#       {'x': 4.8856, 'y': 4.5817},
#       {'x': 4.8856, 'y': 4.7434},
#       {'x': 4.2303, 'y': 4.7434}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.5817},
#       {'x': 5.775, 'y': 4.5817},
#       {'x': 5.775, 'y': 4.7434},
#       {'x': 4.8856, 'y': 4.7434}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.775, 'y': 4.5817},
#       {'x': 6.9843, 'y': 4.5817},
#       {'x': 6.9843, 'y': 4.7434},
#       {'x': 5.775, 'y': 4.7434}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 6.2944, 'y': 4.6111},
#         {'x': 6.4056, 'y': 4.6111},
#         {'x': 6.4056, 'y': 4.7222},
#         {'x': 6.2944, 'y': 4.7222}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 3,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9843, 'y': 4.5817},
#       {'x': 7.9985, 'y': 4.5817},
#       {'x': 7.9985, 'y': 4.7434},
#       {'x': 6.9843, 'y': 4.7434}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 7.3944, 'y': 4.6111},
#         {'x': 7.5056, 'y': 4.6111},
#         {'x': 7.5056, 'y': 4.7222},
#         {'x': 7.3944, 'y': 4.7222}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'see instructions and check',
#      'row_index': 4,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4386, 'y': 4.7203},
#       {'x': 1.2656, 'y': 4.7203},
#       {'x': 1.2656, 'y': 4.9205},
#       {'x': 0.4308, 'y': 4.9282}],
#      'field_elements': [{'text': 'see',
#        'bounding_box': [{'x': 0.5033, 'y': 4.7199},
#         {'x': 0.6659, 'y': 4.7199},
#         {'x': 0.6659, 'y': 4.7799},
#         {'x': 0.5033, 'y': 4.7799}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'instructions',
#        'bounding_box': [{'x': 0.7049, 'y': 4.6993},
#         {'x': 1.2475, 'y': 4.6993},
#         {'x': 1.2475, 'y': 4.7799},
#         {'x': 0.7049, 'y': 4.7799}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'and',
#        'bounding_box': [{'x': 0.504, 'y': 4.8208},
#         {'x': 0.6799, 'y': 4.8208},
#         {'x': 0.6799, 'y': 4.9014},
#         {'x': 0.504, 'y': 4.9014}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'check',
#        'bounding_box': [{'x': 0.7222, 'y': 4.8208},
#         {'x': 1.0167, 'y': 4.8208},
#         {'x': 1.0167, 'y': 4.9014},
#         {'x': 0.7222, 'y': 4.9014}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2656, 'y': 4.7203},
#       {'x': 1.4528, 'y': 4.7203},
#       {'x': 1.4528, 'y': 4.9205},
#       {'x': 1.2656, 'y': 4.9205}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.4528, 'y': 4.7203},
#       {'x': 3.6607, 'y': 4.7434},
#       {'x': 3.6529, 'y': 4.9128},
#       {'x': 1.4528, 'y': 4.9205}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6607, 'y': 4.7434},
#       {'x': 4.2303, 'y': 4.7434},
#       {'x': 4.2303, 'y': 4.9128},
#       {'x': 3.6529, 'y': 4.9128}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2303, 'y': 4.7434},
#       {'x': 4.8856, 'y': 4.7434},
#       {'x': 4.8856, 'y': 4.9128},
#       {'x': 4.2303, 'y': 4.9128}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.7434},
#       {'x': 5.775, 'y': 4.7434},
#       {'x': 5.7672, 'y': 4.9128},
#       {'x': 4.8856, 'y': 4.9128}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.775, 'y': 4.7434},
#       {'x': 6.7112, 'y': 4.7434},
#       {'x': 6.7034, 'y': 4.9128},
#       {'x': 5.7672, 'y': 4.9128}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 6.2944, 'y': 4.7777},
#         {'x': 6.4056, 'y': 4.7777},
#         {'x': 6.4056, 'y': 4.8888},
#         {'x': 6.2944, 'y': 4.8888}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.7112, 'y': 4.7434},
#       {'x': 6.9843, 'y': 4.7434},
#       {'x': 6.9843, 'y': 4.9128},
#       {'x': 6.7034, 'y': 4.9128}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 4,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9843, 'y': 4.7434},
#       {'x': 7.9985, 'y': 4.7434},
#       {'x': 7.9985, 'y': 4.9128},
#       {'x': 6.9843, 'y': 4.9128}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 7.3944, 'y': 4.7777},
#         {'x': 7.5056, 'y': 4.7777},
#         {'x': 7.5056, 'y': 4.8888},
#         {'x': 7.3944, 'y': 4.8888}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'here . .',
#      'row_index': 5,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4308, 'y': 4.9282},
#       {'x': 1.2656, 'y': 4.9205},
#       {'x': 1.2578, 'y': 5.0745},
#       {'x': 0.4308, 'y': 5.0745}],
#      'field_elements': [{'text': 'here',
#        'bounding_box': [{'x': 0.5071, 'y': 4.9424},
#         {'x': 0.716, 'y': 4.9424},
#         {'x': 0.716, 'y': 5.023},
#         {'x': 0.5071, 'y': 5.023}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 0.8426, 'y': 5.0094},
#         {'x': 0.8549, 'y': 5.0094},
#         {'x': 0.8549, 'y': 5.0217},
#         {'x': 0.8426, 'y': 5.0217}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 1.0092, 'y': 5.0094},
#         {'x': 1.0216, 'y': 5.0094},
#         {'x': 1.0216, 'y': 5.0217},
#         {'x': 1.0092, 'y': 5.0217}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': None,
#        'bounding_box': [{'x': 1.1069, 'y': 4.9271},
#         {'x': 1.218, 'y': 4.9271},
#         {'x': 1.218, 'y': 5.0382},
#         {'x': 1.1069, 'y': 5.0382}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2656, 'y': 4.9205},
#       {'x': 1.4528, 'y': 4.9205},
#       {'x': 1.4528, 'y': 5.0745},
#       {'x': 1.2578, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 2,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.4528, 'y': 4.9205},
#       {'x': 3.6529, 'y': 4.9128},
#       {'x': 3.6529, 'y': 5.0745},
#       {'x': 1.4528, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 4,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 3.6529, 'y': 4.9128},
#       {'x': 4.2303, 'y': 4.9128},
#       {'x': 4.2303, 'y': 5.0745},
#       {'x': 3.6529, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2303, 'y': 4.9128},
#       {'x': 4.8856, 'y': 4.9128},
#       {'x': 4.8856, 'y': 5.0745},
#       {'x': 4.2303, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 4.9128},
#       {'x': 5.7672, 'y': 4.9128},
#       {'x': 5.7672, 'y': 5.0745},
#       {'x': 4.8856, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.7672, 'y': 4.9128},
#       {'x': 6.7034, 'y': 4.9128},
#       {'x': 6.7034, 'y': 5.0745},
#       {'x': 5.7672, 'y': 5.0745}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 6.2944, 'y': 4.9444},
#         {'x': 6.4056, 'y': 4.9444},
#         {'x': 6.4056, 'y': 5.0555},
#         {'x': 6.2944, 'y': 5.0555}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.7034, 'y': 4.9128},
#       {'x': 6.9843, 'y': 4.9128},
#       {'x': 6.9843, 'y': 5.0745},
#       {'x': 6.7034, 'y': 5.0745}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 5,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9843, 'y': 4.9128},
#       {'x': 7.9985, 'y': 4.9128},
#       {'x': 7.9985, 'y': 5.0745},
#       {'x': 6.9843, 'y': 5.0745}],
#      'field_elements': [{'text': None,
#        'bounding_box': [{'x': 7.3944, 'y': 4.9444},
#         {'x': 7.5056, 'y': 4.9444},
#         {'x': 7.5056, 'y': 5.0555},
#         {'x': 7.3944, 'y': 5.0555}],
#        'confidence': 1.0,
#        'state': 'unselected',
#        'page_number': 1,
#        'kind': 'selectionMark'}]},
#     {'text': 'Income',
#      'row_index': 6,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4308, 'y': 5.0745},
#       {'x': 1.2578, 'y': 5.0745},
#       {'x': 1.2578, 'y': 5.2824},
#       {'x': 0.4308, 'y': 5.2824}],
#      'field_elements': [{'text': 'Income',
#        'bounding_box': [{'x': 0.5115, 'y': 5.1667},
#         {'x': 1.0888, 'y': 5.1667},
#         {'x': 1.0888, 'y': 5.2878},
#         {'x': 0.5115, 'y': 5.2878}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1 a',
#      'row_index': 6,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.2578, 'y': 5.0745},
#       {'x': 1.4528, 'y': 5.0745},
#       {'x': 1.4528, 'y': 5.2824},
#       {'x': 1.2578, 'y': 5.2824}],
#      'field_elements': [{'text': '1',
#        'bounding_box': [{'x': 1.3464, 'y': 5.1404},
#         {'x': 1.3818, 'y': 5.1404},
#         {'x': 1.3818, 'y': 5.2182},
#         {'x': 1.3464, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'a',
#        'bounding_box': [{'x': 1.4036, 'y': 5.1592},
#         {'x': 1.4596, 'y': 5.1592},
#         {'x': 1.4596, 'y': 5.2197},
#         {'x': 1.4036, 'y': 5.2197}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Total amount from Form(s) W-2, box 1 (see instructions)',
#      'row_index': 6,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 3,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1.4528, 'y': 5.0745},
#       {'x': 4.2303, 'y': 5.0745},
#       {'x': 4.2381, 'y': 5.267},
#       {'x': 1.4528, 'y': 5.2824}],
#      'field_elements': [{'text': 'Total',
#        'bounding_box': [{'x': 1.6002, 'y': 5.1389},
#         {'x': 1.8393, 'y': 5.1389},
#         {'x': 1.8393, 'y': 5.2194},
#         {'x': 1.6002, 'y': 5.2194}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'amount',
#        'bounding_box': [{'x': 1.8818, 'y': 5.1436},
#         {'x': 2.2512, 'y': 5.1436},
#         {'x': 2.2512, 'y': 5.2194},
#         {'x': 1.8818, 'y': 5.2194}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'from',
#        'bounding_box': [{'x': 2.2868, 'y': 5.138},
#         {'x': 2.5068, 'y': 5.138},
#         {'x': 2.5068, 'y': 5.2194},
#         {'x': 2.2868, 'y': 5.2194}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'Form(s)',
#        'bounding_box': [{'x': 2.5534, 'y': 5.137},
#         {'x': 2.912, 'y': 5.137},
#         {'x': 2.912, 'y': 5.2401},
#         {'x': 2.5534, 'y': 5.2401}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'W-2,',
#        'bounding_box': [{'x': 2.9494, 'y': 5.1389},
#         {'x': 3.1776, 'y': 5.1389},
#         {'x': 3.1776, 'y': 5.2344},
#         {'x': 2.9494, 'y': 5.2344}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'box',
#        'bounding_box': [{'x': 3.2252, 'y': 5.1389},
#         {'x': 3.404, 'y': 5.1389},
#         {'x': 3.404, 'y': 5.2194},
#         {'x': 3.2252, 'y': 5.2194}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '1',
#        'bounding_box': [{'x': 3.4456, 'y': 5.1394},
#         {'x': 3.4754, 'y': 5.1394},
#         {'x': 3.4754, 'y': 5.2182},
#         {'x': 3.4456, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '(see',
#        'bounding_box': [{'x': 3.5338, 'y': 5.137},
#         {'x': 3.7301, 'y': 5.137},
#         {'x': 3.7301, 'y': 5.2401},
#         {'x': 3.5338, 'y': 5.2401}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': 'instructions)',
#        'bounding_box': [{'x': 3.7708, 'y': 5.137},
#         {'x': 4.3629, 'y': 5.137},
#         {'x': 4.3629, 'y': 5.2401},
#         {'x': 3.7708, 'y': 5.2401}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '. . .',
#      'row_index': 6,
#      'column_index': 5,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.2303, 'y': 5.0745},
#       {'x': 4.8856, 'y': 5.0745},
#       {'x': 4.8856, 'y': 5.267},
#       {'x': 4.2381, 'y': 5.267}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 4.5092, 'y': 5.2059},
#         {'x': 4.5216, 'y': 5.2059},
#         {'x': 4.5216, 'y': 5.2182},
#         {'x': 4.5092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 4.6759, 'y': 5.2059},
#         {'x': 4.6882, 'y': 5.2059},
#         {'x': 4.6882, 'y': 5.2182},
#         {'x': 4.6759, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 4.8426, 'y': 5.2059},
#         {'x': 4.8549, 'y': 5.2059},
#         {'x': 4.8549, 'y': 5.2182},
#         {'x': 4.8426, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '. . . . .',
#      'row_index': 6,
#      'column_index': 6,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 4.8856, 'y': 5.0745},
#       {'x': 5.7672, 'y': 5.0745},
#       {'x': 5.7672, 'y': 5.2593},
#       {'x': 4.8856, 'y': 5.267}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 5.0092, 'y': 5.2059},
#         {'x': 5.0216, 'y': 5.2059},
#         {'x': 5.0216, 'y': 5.2182},
#         {'x': 5.0092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.1759, 'y': 5.2059},
#         {'x': 5.1882, 'y': 5.2059},
#         {'x': 5.1882, 'y': 5.2182},
#         {'x': 5.1759, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.3426, 'y': 5.2059},
#         {'x': 5.3549, 'y': 5.2059},
#         {'x': 5.3549, 'y': 5.2182},
#         {'x': 5.3426, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.5092, 'y': 5.2059},
#         {'x': 5.5216, 'y': 5.2059},
#         {'x': 5.5216, 'y': 5.2182},
#         {'x': 5.5092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 5.6759, 'y': 5.2059},
#         {'x': 5.6882, 'y': 5.2059},
#         {'x': 5.6882, 'y': 5.2182},
#         {'x': 5.6759, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '. . . . .',
#      'row_index': 6,
#      'column_index': 7,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 5.7672, 'y': 5.0745},
#       {'x': 6.7034, 'y': 5.0745},
#       {'x': 6.7034, 'y': 5.2516},
#       {'x': 5.7672, 'y': 5.2593}],
#      'field_elements': [{'text': '.',
#        'bounding_box': [{'x': 5.8426, 'y': 5.2059},
#         {'x': 5.8549, 'y': 5.2059},
#         {'x': 5.8549, 'y': 5.2182},
#         {'x': 5.8426, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.0092, 'y': 5.2059},
#         {'x': 6.0216, 'y': 5.2059},
#         {'x': 6.0216, 'y': 5.2182},
#         {'x': 6.0092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.1759, 'y': 5.2059},
#         {'x': 6.1882, 'y': 5.2059},
#         {'x': 6.1882, 'y': 5.2182},
#         {'x': 6.1759, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.3426, 'y': 5.2059},
#         {'x': 6.3549, 'y': 5.2059},
#         {'x': 6.3549, 'y': 5.2182},
#         {'x': 6.3426, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'},
#       {'text': '.',
#        'bounding_box': [{'x': 6.5092, 'y': 5.2059},
#         {'x': 6.5216, 'y': 5.2059},
#         {'x': 6.5216, 'y': 5.2182},
#         {'x': 6.5092, 'y': 5.2182}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1a',
#      'row_index': 6,
#      'column_index': 8,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.7034, 'y': 5.0745},
#       {'x': 6.9843, 'y': 5.0745},
#       {'x': 6.9843, 'y': 5.2516},
#       {'x': 6.7034, 'y': 5.2516}],
#      'field_elements': [{'text': '1a',
#        'bounding_box': [{'x': 6.7954, 'y': 5.1404},
#         {'x': 6.9086, 'y': 5.1404},
#         {'x': 6.9086, 'y': 5.2197},
#         {'x': 6.7954, 'y': 5.2197}],
#        'confidence': 1.0,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '',
#      'row_index': 6,
#      'column_index': 9,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 6.9843, 'y': 5.0745},
#       {'x': 7.9985, 'y': 5.0745},
#       {'x': 7.9985, 'y': 5.2516},
#       {'x': 6.9843, 'y': 5.2516}],
#      'field_elements': []},
#     {'text': '',
#      'row_index': 7,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 0.4308, 'y': 5.2824},
#       {'x': 1.2578, 'y': 5.2824},
#       {'x': 1.2578, 'y': 5.421},
#       {'x': 0.4308, 'y': 5.421}],
#      'field_elements': []},
#     {'text': 'b',
#      'row_index': 7,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
# ...
#       {'x': 6.9098, 'y': 9.22},
#       {'x': 6.7964, 'y': 9.22}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 5.8426, 'y': 9.1989},
#     {'x': 5.8549, 'y': 9.1989},
#     {'x': 5.8549, 'y': 9.2113},
#     {'x': 5.8426, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 5.8426, 'y': 9.1989},
#       {'x': 5.8549, 'y': 9.1989},
#       {'x': 5.8549, 'y': 9.2113},
#       {'x': 5.8426, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 6.0092, 'y': 9.1989},
#     {'x': 6.0216, 'y': 9.1989},
#     {'x': 6.0216, 'y': 9.2113},
#     {'x': 6.0092, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 6.0092, 'y': 9.1989},
#       {'x': 6.0216, 'y': 9.1989},
#       {'x': 6.0216, 'y': 9.2113},
#       {'x': 6.0092, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 6.1759, 'y': 9.1989},
#     {'x': 6.1882, 'y': 9.1989},
#     {'x': 6.1882, 'y': 9.2113},
#     {'x': 6.1759, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 6.1759, 'y': 9.1989},
#       {'x': 6.1882, 'y': 9.1989},
#       {'x': 6.1882, 'y': 9.2113},
#       {'x': 6.1759, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 6.3426, 'y': 9.1989},
#     {'x': 6.3549, 'y': 9.1989},
#     {'x': 6.3549, 'y': 9.2113},
#     {'x': 6.3426, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 6.3426, 'y': 9.1989},
#       {'x': 6.3549, 'y': 9.1989},
#       {'x': 6.3549, 'y': 9.2113},
#       {'x': 6.3426, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': '.',
#    'bounding_box': [{'x': 6.5092, 'y': 9.1989},
#     {'x': 6.5216, 'y': 9.1989},
#     {'x': 6.5216, 'y': 9.2113},
#     {'x': 6.5092, 'y': 9.2113}],
#    'words': [{'text': '.',
#      'bounding_box': [{'x': 6.5092, 'y': 9.1989},
#       {'x': 6.5216, 'y': 9.1989},
#       {'x': 6.5216, 'y': 9.2113},
#       {'x': 6.5092, 'y': 9.2113}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'For Disclosure, Privacy Act, and Paperwork Reduction Act Notice, see separate instructions.',
#    'bounding_box': [{'x': 0.5067, 'y': 9.4861},
#     {'x': 4.7771, 'y': 9.4861},
#     {'x': 4.7771, 'y': 9.5731},
#     {'x': 0.5067, 'y': 9.5731}],
#    'words': [{'text': 'For',
#      'bounding_box': [{'x': 0.5067, 'y': 9.4861},
#       {'x': 0.6547, 'y': 9.4861},
#       {'x': 0.6547, 'y': 9.5568},
#       {'x': 0.5067, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Disclosure,',
#      'bounding_box': [{'x': 0.6886, 'y': 9.4861},
#       {'x': 1.1962, 'y': 9.4861},
#       {'x': 1.1962, 'y': 9.5715},
#       {'x': 0.6886, 'y': 9.5715}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Privacy',
#      'bounding_box': [{'x': 1.2358, 'y': 9.4861},
#       {'x': 1.57, 'y': 9.4861},
#       {'x': 1.57, 'y': 9.5731},
#       {'x': 1.2358, 'y': 9.5731}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Act,',
#      'bounding_box': [{'x': 1.5959, 'y': 9.4861},
#       {'x': 1.7743, 'y': 9.4861},
#       {'x': 1.7743, 'y': 9.5715},
#       {'x': 1.5959, 'y': 9.5715}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'and',
#      'bounding_box': [{'x': 1.8103, 'y': 9.4861},
#       {'x': 1.9749, 'y': 9.4861},
#       {'x': 1.9749, 'y': 9.5568},
#       {'x': 1.8103, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Paperwork',
#      'bounding_box': [{'x': 2.0138, 'y': 9.4861},
#       {'x': 2.5133, 'y': 9.4861},
#       {'x': 2.5133, 'y': 9.5731},
#       {'x': 2.0138, 'y': 9.5731}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Reduction',
#      'bounding_box': [{'x': 2.5466, 'y': 9.4861},
#       {'x': 3.0099, 'y': 9.4861},
#       {'x': 3.0099, 'y': 9.5568},
#       {'x': 2.5466, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Act',
#      'bounding_box': [{'x': 3.0416, 'y': 9.4861},
#       {'x': 3.1974, 'y': 9.4861},
#       {'x': 3.1974, 'y': 9.5568},
#       {'x': 3.0416, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Notice,',
#      'bounding_box': [{'x': 3.2325, 'y': 9.4861},
#       {'x': 3.5494, 'y': 9.4861},
#       {'x': 3.5494, 'y': 9.5715},
#       {'x': 3.2325, 'y': 9.5715}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'see',
#      'bounding_box': [{'x': 3.5851, 'y': 9.5039},
#       {'x': 3.7441, 'y': 9.5039},
#       {'x': 3.7441, 'y': 9.5568},
#       {'x': 3.5851, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'separate',
#      'bounding_box': [{'x': 3.7759, 'y': 9.4902},
#       {'x': 4.178, 'y': 9.4902},
#       {'x': 4.178, 'y': 9.5731},
#       {'x': 3.7759, 'y': 9.5731}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'instructions.',
#      'bounding_box': [{'x': 4.2126, 'y': 9.4861},
#       {'x': 4.7771, 'y': 9.4861},
#       {'x': 4.7771, 'y': 9.5568},
#       {'x': 4.2126, 'y': 9.5568}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Cat. No. 11320B',
#    'bounding_box': [{'x': 5.6933, 'y': 9.4916},
#     {'x': 6.3065, 'y': 9.4916},
#     {'x': 6.3065, 'y': 9.5539},
#     {'x': 5.6933, 'y': 9.5539}],
#    'words': [{'text': 'Cat.',
#      'bounding_box': [{'x': 5.6933, 'y': 9.4916},
#       {'x': 5.837, 'y': 9.4916},
#       {'x': 5.837, 'y': 9.5539},
#       {'x': 5.6933, 'y': 9.5539}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'No.',
#      'bounding_box': [{'x': 5.8736, 'y': 9.493},
#       {'x': 5.9914, 'y': 9.493},
#       {'x': 5.9914, 'y': 9.5534},
#       {'x': 5.8736, 'y': 9.5534}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '11320B',
#      'bounding_box': [{'x': 6.0288, 'y': 9.493},
#       {'x': 6.3065, 'y': 9.493},
#       {'x': 6.3065, 'y': 9.5534},
#       {'x': 6.0288, 'y': 9.5534}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}},
#   {'text': 'Form 1040 (2022)',
#    'bounding_box': [{'x': 7.2324, 'y': 9.4625},
#     {'x': 7.9954, 'y': 9.4625},
#     {'x': 7.9954, 'y': 9.5709},
#     {'x': 7.2324, 'y': 9.5709}],
#    'words': [{'text': 'Form',
#      'bounding_box': [{'x': 7.2324, 'y': 9.4922},
#       {'x': 7.4151, 'y': 9.4922},
#       {'x': 7.4151, 'y': 9.5526},
#       {'x': 7.2324, 'y': 9.5526}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '1040',
#      'bounding_box': [{'x': 7.4644, 'y': 9.4625},
#       {'x': 7.7305, 'y': 9.4625},
#       {'x': 7.7305, 'y': 9.5533},
#       {'x': 7.4644, 'y': 9.5533}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '(2022)',
#      'bounding_box': [{'x': 7.7718, 'y': 9.4807},
#       {'x': 7.9954, 'y': 9.4807},
#       {'x': 7.9954, 'y': 9.5709},
#       {'x': 7.7718, 'y': 9.5709}],
#      'confidence': 1.0,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 1.0}}],
#  'selection_marks': [{'text': None,
#    'bounding_box': [{'x': 1.3278, 'y': 0.9375},
#     {'x': 1.4389, 'y': 0.9375},
#     {'x': 1.4389, 'y': 1.0486},
#     {'x': 1.3278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.9278, 'y': 0.9375},
#     {'x': 2.0389, 'y': 0.9375},
#     {'x': 2.0389, 'y': 1.0486},
#     {'x': 1.9278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 3.2278, 'y': 0.9375},
#     {'x': 3.3389, 'y': 0.9375},
#     {'x': 3.3389, 'y': 1.0486},
#     {'x': 3.2278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 5.0278, 'y': 0.9375},
#     {'x': 5.1389, 'y': 0.9375},
#     {'x': 5.1389, 'y': 1.0486},
#     {'x': 5.0278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.5278, 'y': 0.9375},
#     {'x': 6.6389, 'y': 0.9375},
#     {'x': 6.6389, 'y': 1.0486},
#     {'x': 6.5278, 'y': 1.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.0, 'y': 3.0069},
#     {'x': 7.1111, 'y': 3.0069},
#     {'x': 7.1111, 'y': 3.118},
#     {'x': 7.0, 'y': 3.118}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.5, 'y': 3.0069},
#     {'x': 7.6111, 'y': 3.0069},
#     {'x': 7.6111, 'y': 3.118},
#     {'x': 7.5, 'y': 3.118}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.0, 'y': 3.3472},
#     {'x': 7.1111, 'y': 3.3472},
#     {'x': 7.1111, 'y': 3.4583},
#     {'x': 7.0, 'y': 3.4583}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.5, 'y': 3.3472},
#     {'x': 7.6111, 'y': 3.3472},
#     {'x': 7.6111, 'y': 3.4583},
#     {'x': 7.5, 'y': 3.4583}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 2.5278, 'y': 3.5278},
#     {'x': 2.6389, 'y': 3.5278},
#     {'x': 2.6389, 'y': 3.6389},
#     {'x': 2.5278, 'y': 3.6389}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 3.9278, 'y': 3.5278},
#     {'x': 4.0389, 'y': 3.5278},
#     {'x': 4.0389, 'y': 3.6389},
#     {'x': 3.9278, 'y': 3.6389}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.3278, 'y': 3.6944},
#     {'x': 1.4389, 'y': 3.6944},
#     {'x': 1.4389, 'y': 3.8055},
#     {'x': 1.3278, 'y': 3.8055}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.6278, 'y': 3.9375},
#     {'x': 1.7389, 'y': 3.9375},
#     {'x': 1.7389, 'y': 4.0486},
#     {'x': 1.6278, 'y': 4.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 3.6278, 'y': 3.9375},
#     {'x': 3.7389, 'y': 3.9375},
#     {'x': 3.7389, 'y': 4.0486},
#     {'x': 3.6278, 'y': 4.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 5.0278, 'y': 3.9375},
#     {'x': 5.1389, 'y': 3.9375},
#     {'x': 5.1389, 'y': 4.0486},
#     {'x': 5.0278, 'y': 4.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.0278, 'y': 3.9375},
#     {'x': 7.1389, 'y': 3.9375},
#     {'x': 7.1389, 'y': 4.0486},
#     {'x': 7.0278, 'y': 4.0486}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 3.9153, 'y': 4.1506},
#     {'x': 4.022, 'y': 4.1506},
#     {'x': 4.022, 'y': 4.2379},
#     {'x': 3.9153, 'y': 4.2379}],
#    'confidence': 0.223,
#    'state': 'selected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.2944, 'y': 4.4444},
#     {'x': 6.4056, 'y': 4.4444},
#     {'x': 6.4056, 'y': 4.5555},
#     {'x': 6.2944, 'y': 4.5555}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.3944, 'y': 4.4444},
#     {'x': 7.5056, 'y': 4.4444},
#     {'x': 7.5056, 'y': 4.5555},
#     {'x': 7.3944, 'y': 4.5555}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.2944, 'y': 4.6111},
#     {'x': 6.4056, 'y': 4.6111},
#     {'x': 6.4056, 'y': 4.7222},
#     {'x': 6.2944, 'y': 4.7222}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.3944, 'y': 4.6111},
#     {'x': 7.5056, 'y': 4.6111},
#     {'x': 7.5056, 'y': 4.7222},
#     {'x': 7.3944, 'y': 4.7222}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.2944, 'y': 4.7777},
#     {'x': 6.4056, 'y': 4.7777},
#     {'x': 6.4056, 'y': 4.8888},
#     {'x': 6.2944, 'y': 4.8888}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.3944, 'y': 4.7777},
#     {'x': 7.5056, 'y': 4.7777},
#     {'x': 7.5056, 'y': 4.8888},
#     {'x': 7.3944, 'y': 4.8888}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.1069, 'y': 4.9271},
#     {'x': 1.218, 'y': 4.9271},
#     {'x': 1.218, 'y': 5.0382},
#     {'x': 1.1069, 'y': 5.0382}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.2944, 'y': 4.9444},
#     {'x': 6.4056, 'y': 4.9444},
#     {'x': 6.4056, 'y': 5.0555},
#     {'x': 6.2944, 'y': 5.0555}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 7.3944, 'y': 4.9444},
#     {'x': 7.5056, 'y': 4.9444},
#     {'x': 7.5056, 'y': 5.0555},
#     {'x': 7.3944, 'y': 5.0555}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 0.4977, 'y': 5.554},
#     {'x': 0.5796, 'y': 5.554},
#     {'x': 0.5796, 'y': 5.624},
#     {'x': 0.4977, 'y': 5.624}],
#    'confidence': 0.223,
#    'state': 'selected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 1.3983, 'y': 5.6511},
#     {'x': 1.4681, 'y': 5.6511},
#     {'x': 1.4681, 'y': 5.7202},
#     {'x': 1.3983, 'y': 5.7202}],
#    'confidence': 0.223,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.4611, 'y': 7.6111},
#     {'x': 6.5722, 'y': 7.6111},
#     {'x': 6.5722, 'y': 7.7222},
#     {'x': 6.4611, 'y': 7.7222}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'},
#   {'text': None,
#    'bounding_box': [{'x': 6.4611, 'y': 7.7778},
#     {'x': 6.5722, 'y': 7.7778},
#     {'x': 6.5722, 'y': 7.8889},
#     {'x': 6.4611, 'y': 7.8889}],
#    'confidence': 1.0,
#    'state': 'unselected',
#    'page_number': 1,
#    'kind': 'selectionMark'}]}

# %%
print("Page has width: {} and height: {}, measured with unit: {}".format(content.width, content.height, content.unit))
# Out:
# Page has width: 8.5 and height: 11.0, measured with unit: inch

# %%
# Explore Page 2 content: fill in your code here
pageTwoContent.to_dict()
print("Second Page has width: {} and height: {}, measured with unit: {}".format(pageTwoContent.width, pageTwoContent.height, pageTwoContent.unit))
# Out:
# Second Page has width: 8.5 and height: 11.0, measured with unit: inch

# %% [markdown]
# #### Utility Function

# %%
# --------------------------
# Code Snippet Source 
# https://github.com/Azure-Samples/cognitive-services-quickstart-code/blob/master/python/ComputerVision/REST/python-disk.md
# --------------------------
def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

# %% [markdown]
# #### Extract all words from the Form 1040

# %%
# --------------------------
# Code Snippet Source 
# https://github.com/Azure-Samples/cognitive-services-quickstart-code/blob/master/python/ComputerVision/REST/python-disk.md
# --------------------------

for line_idx, line in enumerate(content.lines):
    print("Line # {} has word count '{}' and text '{}' within bounding box '{}'".format(
        line_idx,
        len(line.words),
        line.text,
        format_bounding_box(line.bounding_box)
    ))
    if line.appearance:
        if line.appearance.style_name == "handwriting" and line.appearance.style_confidence > 0.8:
            print("Text line '{}' is handwritten and might be a signature.".format(line.text))
    for word in line.words:
        print("...Word '{}' has a confidence of {}".format(word.text, word.confidence))
# Out:
# Line # 0 has word count '7' and text '1040 U.S. Individual Income Tax Return 2022' within bounding box '[0.6155, 0.5159], [4.8528, 0.5159], [4.8528, 0.7825], [0.6155, 0.7825]'
# ...Word '1040' has a confidence of 1.0
# ...Word 'U.S.' has a confidence of 1.0
# ...Word 'Individual' has a confidence of 1.0
# ...Word 'Income' has a confidence of 1.0
# ...Word 'Tax' has a confidence of 1.0
# ...Word 'Return' has a confidence of 1.0
# ...Word '2022' has a confidence of 1.0
# Line # 1 has word count '6' and text 'Department of the Treasury—Internal Revenue Service' within bounding box '[1.3621, 0.5409], [3.3836, 0.5409], [3.3836, 0.619], [1.3621, 0.619]'
# ...Word 'Department' has a confidence of 1.0
# ...Word 'of' has a confidence of 1.0
# ...Word 'the' has a confidence of 1.0
# ...Word 'Treasury—Internal' has a confidence of 1.0
# ...Word 'Revenue' has a confidence of 1.0
# ...Word 'Service' has a confidence of 1.0
# Line # 2 has word count '3' and text 'OMB No. 1545-0074' within bounding box '[4.9524, 0.7067], [5.8473, 0.7067], [5.8473, 0.7793], [4.9524, 0.7793]'
# ...Word 'OMB' has a confidence of 1.0
# ...Word 'No.' has a confidence of 1.0
# ...Word '1545-0074' has a confidence of 1.0
# Line # 3 has word count '10' and text 'IRS Use Only—Do not write or staple in this space.' within bounding box '[6.0092, 0.7208], [7.8906, 0.7208], [7.8906, 0.7989], [6.0092, 0.7989]'
# ...Word 'IRS' has a confidence of 1.0
# ...Word 'Use' has a confidence of 1.0
# ...Word 'Only—Do' has a confidence of 1.0
# ...Word 'not' has a confidence of 1.0
# ...Word 'write' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'staple' has a confidence of 1.0
# ...Word 'in' has a confidence of 1.0
# ...Word 'this' has a confidence of 1.0
# ...Word 'space.' has a confidence of 1.0
# Line # 4 has word count '1' and text 'Form' within bounding box '[0.5083, 0.7552], [0.5083, 0.5421], [0.5788, 0.5421], [0.5788, 0.7552]'
# ...Word 'Form' has a confidence of 1.0
# Line # 5 has word count '2' and text 'Filing Status' within bounding box '[0.5087, 0.9325], [1.2444, 0.9325], [1.2444, 1.0547], [0.5087, 1.0547]'
# ...Word 'Filing' has a confidence of 1.0
# ...Word 'Status' has a confidence of 1.0
# Line # 6 has word count '1' and text 'Single' within bounding box '[1.5041, 0.9495], [1.8044, 0.9495], [1.8044, 1.0539], [1.5041, 1.0539]'
# ...Word 'Single' has a confidence of 1.0
# Line # 7 has word count '3' and text 'Married filing jointly' within bounding box '[2.1089, 0.9505], [3.0641, 0.9505], [3.0641, 1.0539], [2.1089, 1.0539]'
# ...Word 'Married' has a confidence of 1.0
# ...Word 'filing' has a confidence of 1.0
# ...Word 'jointly' has a confidence of 1.0
# Line # 8 has word count '4' and text 'Married filing separately (MFS)' within bounding box '[3.4088, 0.9495], [4.888, 0.9495], [4.888, 1.0539], [3.4088, 1.0539]'
# ...Word 'Married' has a confidence of 1.0
# ...Word 'filing' has a confidence of 1.0
# ...Word 'separately' has a confidence of 1.0
# ...Word '(MFS)' has a confidence of 1.0
# Line # 9 has word count '4' and text 'Head of household (HOH)' within bounding box '[5.2081, 0.9495], [6.3944, 0.9495], [6.3944, 1.0526], [5.2081, 1.0526]'
# ...Word 'Head' has a confidence of 1.0
# ...Word 'of' has a confidence of 1.0
# ...Word 'household' has a confidence of 1.0
# ...Word '(HOH)' has a confidence of 1.0
# Line # 10 has word count '2' and text 'Qualifying surviving' within bounding box '[6.7042, 0.9509], [7.658, 0.9509], [7.658, 1.0553], [6.7042, 1.0553]'
# ...Word 'Qualifying' has a confidence of 1.0
# ...Word 'surviving' has a confidence of 1.0
# Line # 11 has word count '2' and text 'Check only' within bounding box '[0.5048, 1.0995], [1.0548, 1.0995], [1.0548, 1.2036], [0.5048, 1.2036]'
# ...Word 'Check' has a confidence of 1.0
# ...Word 'only' has a confidence of 1.0
# Line # 12 has word count '2' and text 'spouse (QSS)' within bounding box '[6.7034, 1.0689], [7.3739, 1.0689], [7.3739, 1.172], [6.7034, 1.172]'
# ...Word 'spouse' has a confidence of 1.0
# ...Word '(QSS)' has a confidence of 1.0
# Line # 13 has word count '2' and text 'one box.' within bounding box '[0.504, 1.2194], [0.9249, 1.2194], [0.9249, 1.2999], [0.504, 1.2999]'
# ...Word 'one' has a confidence of 1.0
# ...Word 'box.' has a confidence of 1.0
# Line # 14 has word count '27' and text 'If you checked the MFS box, enter the name of your spouse. If you checked the HOH or QSS box, enter the child’s name if the qualifying' within bounding box '[1.3367, 1.2134], [7.9801, 1.2134], [7.9801, 1.3178], [1.3367, 1.3178]'
# ...Word 'If' has a confidence of 1.0
# ...Word 'you' has a confidence of 1.0
# ...Word 'checked' has a confidence of 1.0
# ...Word 'the' has a confidence of 1.0
# ...Word 'MFS' has a confidence of 1.0
# ...Word 'box,' has a confidence of 1.0
# ...Word 'enter' has a confidence of 1.0
# ...Word 'the' has a confidence of 1.0
# ...Word 'name' has a confidence of 1.0
# ...Word 'of' has a confidence of 1.0
# ...Word 'your' has a confidence of 1.0
# ...Word 'spouse.' has a confidence of 1.0
# ...Word 'If' has a confidence of 1.0
# ...Word 'you' has a confidence of 1.0
# ...Word 'checked' has a confidence of 1.0
# ...Word 'the' has a confidence of 1.0
# ...Word 'HOH' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'QSS' has a confidence of 1.0
# ...Word 'box,' has a confidence of 1.0
# ...Word 'enter' has a confidence of 1.0
# ...Word 'the' has a confidence of 1.0
# ...Word 'child’s' has a confidence of 1.0
# ...Word 'name' has a confidence of 1.0
# ...Word 'if' has a confidence of 1.0
# ...Word 'the' has a confidence of 1.0
# ...Word 'qualifying' has a confidence of 1.0
# Line # 15 has word count '8' and text 'person is a child but not your dependent:' within bounding box '[1.3361, 1.3611], [3.3226, 1.3611], [3.3226, 1.4633], [1.3361, 1.4633]'
# ...Word 'person' has a confidence of 1.0
# ...Word 'is' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'child' has a confidence of 1.0
# ...Word 'but' has a confidence of 1.0
# ...Word 'not' has a confidence of 1.0
# ...Word 'your' has a confidence of 1.0
# ...Word 'dependent:' has a confidence of 1.0
# Line # 16 has word count '6' and text 'Your first name and middle initial' within bounding box '[0.5558, 1.5464], [1.9734, 1.5464], [1.9734, 1.6177], [0.5558, 1.6177]'
# ...Word 'Your' has a confidence of 1.0
# ...Word 'first' has a confidence of 1.0
# ...Word 'name' has a confidence of 1.0
# ...Word 'and' has a confidence of 1.0
# ...Word 'middle' has a confidence of 1.0
# ...Word 'initial' has a confidence of 1.0
# Line # 17 has word count '2' and text 'Last name' within bounding box '[3.3631, 1.5472], [3.8076, 1.5472], [3.8076, 1.6177], [3.3631, 1.6177]'
# ...Word 'Last' has a confidence of 1.0
# ...Word 'name' has a confidence of 1.0
# Line # 18 has word count '4' and text 'Your social security number' within bounding box '[6.5548, 1.5472], [7.855, 1.5472], [7.855, 1.6342], [6.5548, 1.6342]'
# ...Word 'Your' has a confidence of 1.0
# ...Word 'social' has a confidence of 1.0
# ...Word 'security' has a confidence of 1.0
# ...Word 'number' has a confidence of 1.0
# Line # 19 has word count '9' and text 'If joint return, spouse’s first name and middle initial' within bounding box '[0.5635, 1.8798], [2.7622, 1.8798], [2.7622, 1.9691], [0.5635, 1.9691]'
# ...Word 'If' has a confidence of 1.0
# ...Word 'joint' has a confidence of 1.0
# ...Word 'return,' has a confidence of 1.0
# ...Word 'spouse’s' has a confidence of 1.0
# ...Word 'first' has a confidence of 1.0
# ...Word 'name' has a confidence of 1.0
# ...Word 'and' has a confidence of 1.0
# ...Word 'middle' has a confidence of 1.0
# ...Word 'initial' has a confidence of 1.0
# Line # 20 has word count '2' and text 'Last name' within bounding box '[3.3631, 1.8806], [3.8076, 1.8806], [3.8076, 1.9511], [3.3631, 1.9511]'
# ...Word 'Last' has a confidence of 1.0
# ...Word 'name' has a confidence of 1.0
# Line # 21 has word count '4' and text 'Spouse’s social security number' within bounding box '[6.5576, 1.8789], [8.0018, 1.8789], [8.0018, 1.9676], [6.5576, 1.9676]'
# ...Word 'Spouse’s' has a confidence of 1.0
# ...Word 'social' has a confidence of 1.0
# ...Word 'security' has a confidence of 1.0
# ...Word 'number' has a confidence of 1.0
# Line # 22 has word count '13' and text 'Home address (number and street). If you have a P.O. box, see instructions.' within bounding box '[0.5631, 2.2122], [3.8412, 2.2122], [3.8412, 2.3033], [0.5631, 2.3033]'
# ...Word 'Home' has a confidence of 1.0
# ...Word 'address' has a confidence of 1.0
# ...Word '(number' has a confidence of 1.0
# ...Word 'and' has a confidence of 1.0
# ...Word 'street).' has a confidence of 1.0
# ...Word 'If' has a confidence of 1.0
# ...Word 'you' has a confidence of 1.0
# ...Word 'have' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'P.O.' has a confidence of 1.0
# ...Word 'box,' has a confidence of 1.0
# ...Word 'see' has a confidence of 1.0
# ...Word 'instructions.' has a confidence of 1.0
# Line # 23 has word count '2' and text 'Apt. no.' within bounding box '[5.855, 2.2139], [6.1896, 2.2139], [6.1896, 2.3024], [5.855, 2.3024]'
# ...Word 'Apt.' has a confidence of 1.0
# ...Word 'no.' has a confidence of 1.0
# Line # 24 has word count '3' and text 'Presidential Election Campaign' within bounding box '[6.5622, 2.2222], [7.9973, 2.2222], [7.9973, 2.3187], [6.5622, 2.3187]'
# ...Word 'Presidential' has a confidence of 1.0
# ...Word 'Election' has a confidence of 1.0
# ...Word 'Campaign' has a confidence of 1.0
# Line # 25 has word count '6' and text 'Check here if you, or your' within bounding box '[6.56, 2.3611], [7.7556, 2.3611], [7.7556, 2.4587], [6.56, 2.4587]'
# ...Word 'Check' has a confidence of 1.0
# ...Word 'here' has a confidence of 1.0
# ...Word 'if' has a confidence of 1.0
# ...Word 'you,' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'your' has a confidence of 1.0
# Line # 26 has word count '15' and text 'City, town, or post office. If you have a foreign address, also complete spaces below.' within bounding box '[0.5597, 2.5456], [4.2439, 2.5456], [4.2439, 2.637], [0.5597, 2.637]'
# ...Word 'City,' has a confidence of 1.0
# ...Word 'town,' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'post' has a confidence of 1.0
# ...Word 'office.' has a confidence of 1.0
# ...Word 'If' has a confidence of 1.0
# ...Word 'you' has a confidence of 1.0
# ...Word 'have' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'foreign' has a confidence of 1.0
# ...Word 'address,' has a confidence of 1.0
# ...Word 'also' has a confidence of 1.0
# ...Word 'complete' has a confidence of 1.0
# ...Word 'spaces' has a confidence of 1.0
# ...Word 'below.' has a confidence of 1.0
# Line # 27 has word count '1' and text 'State' within bounding box '[4.7592, 2.5456], [4.9824, 2.5456], [4.9824, 2.6182], [4.7592, 2.6182]'
# ...Word 'State' has a confidence of 1.0
# Line # 28 has word count '2' and text 'ZIP code' within bounding box '[5.6577, 2.5472], [6.0462, 2.5472], [6.0462, 2.6177], [5.6577, 2.6177]'
# ...Word 'ZIP' has a confidence of 1.0
# ...Word 'code' has a confidence of 1.0
# Line # 29 has word count '6' and text 'spouse if filing jointly, want $3' within bounding box '[6.5588, 2.4792], [7.9494, 2.4792], [7.9494, 2.584], [6.5588, 2.584]'
# ...Word 'spouse' has a confidence of 1.0
# ...Word 'if' has a confidence of 1.0
# ...Word 'filing' has a confidence of 1.0
# ...Word 'jointly,' has a confidence of 1.0
# ...Word 'want' has a confidence of 1.0
# ...Word '$3' has a confidence of 1.0
# Line # 30 has word count '7' and text 'to go to this fund. Checking a' within bounding box '[6.5565, 2.6111], [7.9317, 2.6111], [7.9317, 2.709], [6.5565, 2.709]'
# ...Word 'to' has a confidence of 1.0
# ...Word 'go' has a confidence of 1.0
# ...Word 'to' has a confidence of 1.0
# ...Word 'this' has a confidence of 1.0
# ...Word 'fund.' has a confidence of 1.0
# ...Word 'Checking' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# Line # 31 has word count '5' and text 'box below will not change' within bounding box '[6.5625, 2.7379], [7.7668, 2.7379], [7.7668, 2.834], [6.5625, 2.834]'
# ...Word 'box' has a confidence of 1.0
# ...Word 'below' has a confidence of 1.0
# ...Word 'will' has a confidence of 1.0
# ...Word 'not' has a confidence of 1.0
# ...Word 'change' has a confidence of 1.0
# Line # 32 has word count '3' and text 'Foreign country name' within bounding box '[0.5631, 2.8806], [1.5045, 2.8806], [1.5045, 2.9703], [0.5631, 2.9703]'
# ...Word 'Foreign' has a confidence of 1.0
# ...Word 'country' has a confidence of 1.0
# ...Word 'name' has a confidence of 1.0
# Line # 33 has word count '2' and text 'Foreign province/state/county' within bounding box '[3.6631, 2.8789], [4.9583, 2.8789], [4.9583, 2.9703], [3.6631, 2.9703]'
# ...Word 'Foreign' has a confidence of 1.0
# ...Word 'province/state/county' has a confidence of 1.0
# Line # 34 has word count '3' and text 'Foreign postal code' within bounding box '[5.6625, 2.8806], [6.4506, 2.8806], [6.4506, 2.9703], [5.6625, 2.9703]'
# ...Word 'Foreign' has a confidence of 1.0
# ...Word 'postal' has a confidence of 1.0
# ...Word 'code' has a confidence of 1.0
# Line # 35 has word count '4' and text 'your tax or refund.' within bounding box '[6.5564, 2.8621], [7.4034, 2.8621], [7.4034, 2.9587], [6.5564, 2.9587]'
# ...Word 'your' has a confidence of 1.0
# ...Word 'tax' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'refund.' has a confidence of 1.0
# Line # 36 has word count '1' and text 'You' within bounding box '[7.1492, 3.0278], [7.3267, 3.0278], [7.3267, 3.0984], [7.1492, 3.0984]'
# ...Word 'You' has a confidence of 1.0
# Line # 37 has word count '1' and text 'Spouse' within bounding box '[7.6521, 3.0261], [7.9956, 3.0261], [7.9956, 3.1148], [7.6521, 3.1148]'
# ...Word 'Spouse' has a confidence of 1.0
# Line # 38 has word count '1' and text 'Digital' within bounding box '[0.5096, 3.2222], [0.9158, 3.2222], [0.9158, 3.3485], [0.5096, 3.3485]'
# ...Word 'Digital' has a confidence of 1.0
# Line # 39 has word count '22' and text 'At any time during 2022, did you: (a) receive (as a reward, award, or payment for property or services); or (b) sell,' within bounding box '[1.2993, 3.2203], [6.8612, 3.2203], [6.8612, 3.3248], [1.2993, 3.3248]'
# ...Word 'At' has a confidence of 1.0
# ...Word 'any' has a confidence of 1.0
# ...Word 'time' has a confidence of 1.0
# ...Word 'during' has a confidence of 1.0
# ...Word '2022,' has a confidence of 1.0
# ...Word 'did' has a confidence of 1.0
# ...Word 'you:' has a confidence of 1.0
# ...Word '(a)' has a confidence of 1.0
# ...Word 'receive' has a confidence of 1.0
# ...Word '(as' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'reward,' has a confidence of 1.0
# ...Word 'award,' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'payment' has a confidence of 1.0
# ...Word 'for' has a confidence of 1.0
# ...Word 'property' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'services);' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word '(b)' has a confidence of 1.0
# ...Word 'sell,' has a confidence of 1.0
# Line # 40 has word count '1' and text 'Assets' within bounding box '[0.4992, 3.368], [0.9435, 3.368], [0.9435, 3.469], [0.4992, 3.469]'
# ...Word 'Assets' has a confidence of 1.0
# Line # 41 has word count '19' and text 'exchange, gift, or otherwise dispose of a digital asset (or a financial interest in a digital asset)? (See instructions.)' within bounding box '[1.304, 3.3731], [6.8691, 3.3731], [6.8691, 3.4776], [1.304, 3.4776]'
# ...Word 'exchange,' has a confidence of 1.0
# ...Word 'gift,' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'otherwise' has a confidence of 1.0
# ...Word 'dispose' has a confidence of 1.0
# ...Word 'of' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'digital' has a confidence of 1.0
# ...Word 'asset' has a confidence of 1.0
# ...Word '(or' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'financial' has a confidence of 1.0
# ...Word 'interest' has a confidence of 1.0
# ...Word 'in' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'digital' has a confidence of 1.0
# ...Word 'asset)?' has a confidence of 1.0
# ...Word '(See' has a confidence of 1.0
# ...Word 'instructions.)' has a confidence of 1.0
# Line # 42 has word count '1' and text 'Yes' within bounding box '[7.1491, 3.3694], [7.3443, 3.3694], [7.3443, 3.4502], [7.1491, 3.4502]'
# ...Word 'Yes' has a confidence of 1.0
# Line # 43 has word count '1' and text 'No' within bounding box '[7.6577, 3.3694], [7.796, 3.3694], [7.796, 3.4502], [7.6577, 3.4502]'
# ...Word 'No' has a confidence of 1.0
# Line # 44 has word count '1' and text 'Standard' within bounding box '[0.5031, 3.5532], [1.0972, 3.5532], [1.0972, 3.6569], [0.5031, 3.6569]'
# ...Word 'Standard' has a confidence of 1.0
# Line # 45 has word count '3' and text 'Someone can claim:' within bounding box '[1.3024, 3.5467], [2.367, 3.5467], [2.367, 3.6297], [1.3024, 3.6297]'
# ...Word 'Someone' has a confidence of 1.0
# ...Word 'can' has a confidence of 1.0
# ...Word 'claim:' has a confidence of 1.0
# Line # 46 has word count '4' and text 'You as a dependent' within bounding box '[2.7002, 3.5486], [3.697, 3.5486], [3.697, 3.6498], [2.7002, 3.6498]'
# ...Word 'You' has a confidence of 1.0
# ...Word 'as' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'dependent' has a confidence of 1.0
# Line # 47 has word count '5' and text 'Your spouse as a dependent' within bounding box '[4.1002, 3.5486], [5.5271, 3.5486], [5.5271, 3.6498], [4.1002, 3.6498]'
# ...Word 'Your' has a confidence of 1.0
# ...Word 'spouse' has a confidence of 1.0
# ...Word 'as' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'dependent' has a confidence of 1.0
# Line # 48 has word count '1' and text 'Deduction' within bounding box '[0.5096, 3.7014], [1.174, 3.7014], [1.174, 3.8024], [0.5096, 3.8024]'
# ...Word 'Deduction' has a confidence of 1.0
# Line # 49 has word count '12' and text 'Spouse itemizes on a separate return or you were a dual-status alien' within bounding box '[1.5041, 3.7134], [4.8986, 3.7134], [4.8986, 3.8175], [1.5041, 3.8175]'
# ...Word 'Spouse' has a confidence of 1.0
# ...Word 'itemizes' has a confidence of 1.0
# ...Word 'on' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'separate' has a confidence of 1.0
# ...Word 'return' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'you' has a confidence of 1.0
# ...Word 'were' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# ...Word 'dual-status' has a confidence of 1.0
# ...Word 'alien' has a confidence of 1.0
# Line # 50 has word count '2' and text 'Age/Blindness You:' within bounding box '[0.4994, 3.9564], [1.5321, 3.9564], [1.5321, 4.0593], [0.4994, 4.0593]'
# ...Word 'Age/Blindness' has a confidence of 1.0
# ...Word 'You:' has a confidence of 1.0
# Line # 51 has word count '6' and text 'Were born before January 2, 1958' within bounding box '[1.8013, 3.9574], [3.4726, 3.9574], [3.4726, 4.0605], [1.8013, 4.0605]'
# ...Word 'Were' has a confidence of 1.0
# ...Word 'born' has a confidence of 1.0
# ...Word 'before' has a confidence of 1.0
# ...Word 'January' has a confidence of 1.0
# ...Word '2,' has a confidence of 1.0
# ...Word '1958' has a confidence of 1.0
# Line # 52 has word count '2' and text 'Are blind' within bounding box '[3.7993, 3.9583], [4.235, 3.9583], [4.235, 4.0389], [3.7993, 4.0389]'
# ...Word 'Are' has a confidence of 1.0
# ...Word 'blind' has a confidence of 1.0
# Line # 53 has word count '1' and text 'Spouse:' within bounding box '[4.5024, 3.9564], [4.9214, 3.9564], [4.9214, 4.0578], [4.5024, 4.0578]'
# ...Word 'Spouse:' has a confidence of 1.0
# Line # 54 has word count '6' and text 'Was born before January 2, 1958' within bounding box '[5.2013, 3.9574], [6.8318, 3.9574], [6.8318, 4.0605], [5.2013, 4.0605]'
# ...Word 'Was' has a confidence of 1.0
# ...Word 'born' has a confidence of 1.0
# ...Word 'before' has a confidence of 1.0
# ...Word 'January' has a confidence of 1.0
# ...Word '2,' has a confidence of 1.0
# ...Word '1958' has a confidence of 1.0
# Line # 55 has word count '2' and text 'Is blind' within bounding box '[7.2091, 3.9583], [7.5507, 3.9583], [7.5507, 4.0389], [7.2091, 4.0389]'
# ...Word 'Is' has a confidence of 1.0
# ...Word 'blind' has a confidence of 1.0
# Line # 56 has word count '3' and text 'Dependents (see instructions):' within bounding box '[0.509, 4.1389], [2.1611, 4.1389], [2.1611, 4.257], [0.509, 4.257]'
# ...Word 'Dependents' has a confidence of 1.0
# ...Word '(see' has a confidence of 1.0
# ...Word 'instructions):' has a confidence of 1.0
# Line # 57 has word count '3' and text '(2) Social security' within bounding box '[3.9189, 4.1553], [4.6854, 4.1553], [4.6854, 4.2464], [3.9189, 4.2464]'
# ...Word '(2)' has a confidence of 1.0
# ...Word 'Social' has a confidence of 1.0
# ...Word 'security' has a confidence of 1.0
# Line # 58 has word count '2' and text '(3) Relationship' within bounding box '[5.0175, 4.1553], [5.6841, 4.1553], [5.6841, 4.2455], [5.0175, 4.2455]'
# ...Word '(3)' has a confidence of 1.0
# ...Word 'Relationship' has a confidence of 1.0
# Line # 59 has word count '9' and text '(4) Check the box if qualifies for (see instructions):' within bounding box '[5.8313, 4.1234], [7.9657, 4.1234], [7.9657, 4.2136], [5.8313, 4.2136]'
# ...Word '(4)' has a confidence of 1.0
# ...Word 'Check' has a confidence of 1.0
# ...Word 'the' has a confidence of 1.0
# ...Word 'box' has a confidence of 1.0
# ...Word 'if' has a confidence of 1.0
# ...Word 'qualifies' has a confidence of 1.0
# ...Word 'for' has a confidence of 1.0
# ...Word '(see' has a confidence of 1.0
# ...Word 'instructions):' has a confidence of 1.0
# Line # 60 has word count '2' and text 'If more' within bounding box '[0.5091, 4.3338], [0.8457, 4.3338], [0.8457, 4.4153], [0.5091, 4.4153]'
# ...Word 'If' has a confidence of 1.0
# ...Word 'more' has a confidence of 1.0
# Line # 61 has word count '3' and text '(1) First name' within bounding box '[1.3328, 4.2969], [1.922, 4.2969], [1.922, 4.3856], [1.3328, 4.3856]'
# ...Word '(1)' has a confidence of 1.0
# ...Word 'First' has a confidence of 1.0
# ...Word 'name' has a confidence of 1.0
# Line # 62 has word count '2' and text 'Last name' within bounding box '[2.4656, 4.2986], [2.9101, 4.2986], [2.9101, 4.3691], [2.4656, 4.3691]'
# ...Word 'Last' has a confidence of 1.0
# ...Word 'name' has a confidence of 1.0
# Line # 63 has word count '1' and text 'number' within bounding box '[4.1396, 4.2736], [4.4667, 4.2736], [4.4667, 4.3441], [4.1396, 4.3441]'
# ...Word 'number' has a confidence of 1.0
# Line # 64 has word count '2' and text 'to you' within bounding box '[5.2149, 4.2777], [5.4798, 4.2777], [5.4798, 4.3631], [5.2149, 4.3631]'
# ...Word 'to' has a confidence of 1.0
# ...Word 'you' has a confidence of 1.0
# Line # 65 has word count '3' and text 'Child tax credit' within bounding box '[6.0247, 4.2969], [6.6766, 4.2969], [6.6766, 4.3696], [6.0247, 4.3696]'
# ...Word 'Child' has a confidence of 1.0
# ...Word 'tax' has a confidence of 1.0
# ...Word 'credit' has a confidence of 1.0
# Line # 66 has word count '4' and text 'Credit for other dependents' within bounding box '[6.9315, 4.2969], [8.0034, 4.2969], [8.0034, 4.3872], [6.9315, 4.3872]'
# ...Word 'Credit' has a confidence of 1.0
# ...Word 'for' has a confidence of 1.0
# ...Word 'other' has a confidence of 1.0
# ...Word 'dependents' has a confidence of 1.0
# Line # 67 has word count '2' and text 'than four' within bounding box '[0.501, 4.4554], [0.9446, 4.4554], [0.9446, 4.5368], [0.501, 4.5368]'
# ...Word 'than' has a confidence of 1.0
# ...Word 'four' has a confidence of 1.0
# Line # 68 has word count '1' and text 'dependents,' within bounding box '[0.504, 4.5778], [1.1123, 4.5778], [1.1123, 4.6791], [0.504, 4.6791]'
# ...Word 'dependents,' has a confidence of 1.0
# Line # 69 has word count '2' and text 'see instructions' within bounding box '[0.5033, 4.6993], [1.2475, 4.6993], [1.2475, 4.7799], [0.5033, 4.7799]'
# ...Word 'see' has a confidence of 1.0
# ...Word 'instructions' has a confidence of 1.0
# Line # 70 has word count '2' and text 'and check' within bounding box '[0.504, 4.8208], [1.0167, 4.8208], [1.0167, 4.9014], [0.504, 4.9014]'
# ...Word 'and' has a confidence of 1.0
# ...Word 'check' has a confidence of 1.0
# Line # 71 has word count '1' and text 'here' within bounding box '[0.5071, 4.9424], [0.716, 4.9424], [0.716, 5.023], [0.5071, 5.023]'
# ...Word 'here' has a confidence of 1.0
# Line # 72 has word count '1' and text '.' within bounding box '[0.8426, 5.0094], [0.8549, 5.0094], [0.8549, 5.0217], [0.8426, 5.0217]'
# ...Word '.' has a confidence of 1.0
# Line # 73 has word count '1' and text '.' within bounding box '[1.0092, 5.0094], [1.0216, 5.0094], [1.0216, 5.0217], [1.0092, 5.0217]'
# ...Word '.' has a confidence of 1.0
# Line # 74 has word count '1' and text 'Income' within bounding box '[0.5115, 5.1667], [1.0888, 5.1667], [1.0888, 5.2878], [0.5115, 5.2878]'
# ...Word 'Income' has a confidence of 1.0
# Line # 75 has word count '2' and text '1 a' within bounding box '[1.3464, 5.1404], [1.4596, 5.1404], [1.4596, 5.2197], [1.3464, 5.2197]'
# ...Word '1' has a confidence of 1.0
# ...Word 'a' has a confidence of 1.0
# Line # 76 has word count '9' and text 'Total amount from Form(s) W-2, box 1 (see instructions)' within bounding box '[1.6002, 5.137], [4.3629, 5.137], [4.3629, 5.2401], [1.6002, 5.2401]'
# ...Word 'Total' has a confidence of 1.0
# ...Word 'amount' has a confidence of 1.0
# ...Word 'from' has a confidence of 1.0
# ...Word 'Form(s)' has a confidence of 1.0
# ...Word 'W-2,' has a confidence of 1.0
# ...Word 'box' has a confidence of 1.0
# ...Word '1' has a confidence of 1.0
# ...Word '(see' has a confidence of 1.0
# ...Word 'instructions)' has a confidence of 1.0
# Line # 77 has word count '1' and text '1a' within bounding box '[6.7954, 5.1404], [6.9086, 5.1404], [6.9086, 5.2197], [6.7954, 5.2197]'
# ...Word '1a' has a confidence of 1.0
# Line # 78 has word count '1' and text '.' within bounding box '[4.5092, 5.2059], [4.5216, 5.2059], [4.5216, 5.2182], [4.5092, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 79 has word count '1' and text '.' within bounding box '[4.6759, 5.2059], [4.6882, 5.2059], [4.6882, 5.2182], [4.6759, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 80 has word count '1' and text '.' within bounding box '[4.8426, 5.2059], [4.8549, 5.2059], [4.8549, 5.2182], [4.8426, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 81 has word count '1' and text '.' within bounding box '[5.0092, 5.2059], [5.0216, 5.2059], [5.0216, 5.2182], [5.0092, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 82 has word count '1' and text '.' within bounding box '[5.1759, 5.2059], [5.1882, 5.2059], [5.1882, 5.2182], [5.1759, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 83 has word count '1' and text '.' within bounding box '[5.3426, 5.2059], [5.3549, 5.2059], [5.3549, 5.2182], [5.3426, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 84 has word count '1' and text '.' within bounding box '[5.5092, 5.2059], [5.5216, 5.2059], [5.5216, 5.2182], [5.5092, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 85 has word count '1' and text '.' within bounding box '[5.6759, 5.2059], [5.6882, 5.2059], [5.6882, 5.2182], [5.6759, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 86 has word count '1' and text '.' within bounding box '[5.8426, 5.2059], [5.8549, 5.2059], [5.8549, 5.2182], [5.8426, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 87 has word count '1' and text '.' within bounding box '[6.0092, 5.2059], [6.0216, 5.2059], [6.0216, 5.2182], [6.0092, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 88 has word count '1' and text '.' within bounding box '[6.1759, 5.2059], [6.1882, 5.2059], [6.1882, 5.2182], [6.1759, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 89 has word count '1' and text '.' within bounding box '[6.3426, 5.2059], [6.3549, 5.2059], [6.3549, 5.2182], [6.3426, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 90 has word count '1' and text '.' within bounding box '[6.5092, 5.2059], [6.5216, 5.2059], [6.5216, 5.2182], [6.5092, 5.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 91 has word count '1' and text 'b' within bounding box '[1.406, 5.3055], [1.4639, 5.3055], [1.4639, 5.3863], [1.406, 5.3863]'
# ...Word 'b' has a confidence of 1.0
# Line # 92 has word count '9' and text 'Household employee wages not reported on Form(s) W-2 .' within bounding box '[1.6087, 5.3037], [4.5216, 5.3037], [4.5216, 5.4081], [1.6087, 5.4081]'
# ...Word 'Household' has a confidence of 1.0
# ...Word 'employee' has a confidence of 1.0
# ...Word 'wages' has a confidence of 1.0
# ...Word 'not' has a confidence of 1.0
# ...Word 'reported' has a confidence of 1.0
# ...Word 'on' has a confidence of 1.0
# ...Word 'Form(s)' has a confidence of 1.0
# ...Word 'W-2' has a confidence of 1.0
# ...Word '.' has a confidence of 1.0
# Line # 93 has word count '1' and text '1b' within bounding box '[6.7934, 5.3055], [6.9108, 5.3055], [6.9108, 5.3863], [6.7934, 5.3863]'
# ...Word '1b' has a confidence of 1.0
# Line # 94 has word count '1' and text '.' within bounding box '[4.6759, 5.3725], [4.6882, 5.3725], [4.6882, 5.3849], [4.6759, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 95 has word count '1' and text '.' within bounding box '[4.8426, 5.3725], [4.8549, 5.3725], [4.8549, 5.3849], [4.8426, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 96 has word count '1' and text '.' within bounding box '[5.0092, 5.3725], [5.0216, 5.3725], [5.0216, 5.3849], [5.0092, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 97 has word count '1' and text '.' within bounding box '[5.1759, 5.3725], [5.1882, 5.3725], [5.1882, 5.3849], [5.1759, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 98 has word count '1' and text '.' within bounding box '[5.3426, 5.3725], [5.3549, 5.3725], [5.3549, 5.3849], [5.3426, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 99 has word count '1' and text '.' within bounding box '[5.5092, 5.3725], [5.5216, 5.3725], [5.5216, 5.3849], [5.5092, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 100 has word count '1' and text '.' within bounding box '[5.6759, 5.3725], [5.6882, 5.3725], [5.6882, 5.3849], [5.6759, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 101 has word count '1' and text '.' within bounding box '[5.8426, 5.3725], [5.8549, 5.3725], [5.8549, 5.3849], [5.8426, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 102 has word count '1' and text '.' within bounding box '[6.0092, 5.3725], [6.0216, 5.3725], [6.0216, 5.3849], [6.0092, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 103 has word count '1' and text '.' within bounding box '[6.1759, 5.3725], [6.1882, 5.3725], [6.1882, 5.3849], [6.1759, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 104 has word count '1' and text '.' within bounding box '[6.3426, 5.3725], [6.3549, 5.3725], [6.3549, 5.3849], [6.3426, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 105 has word count '1' and text '.' within bounding box '[6.5092, 5.3725], [6.5216, 5.3725], [6.5216, 5.3849], [6.5092, 5.3849]'
# ...Word '.' has a confidence of 1.0
# Line # 106 has word count '2' and text 'Attach Form(s)' within bounding box '[0.4994, 5.4428], [1.179, 5.4428], [1.179, 5.5314], [0.4994, 5.5314]'
# ...Word 'Attach' has a confidence of 1.0
# ...Word 'Form(s)' has a confidence of 1.0
# Line # 107 has word count '1' and text 'c' within bounding box '[1.4042, 5.4925], [1.4609, 5.4925], [1.4609, 5.553], [1.4042, 5.553]'
# ...Word 'c' has a confidence of 1.0
# Line # 108 has word count '9' and text 'Tip income not reported on line 1a (see instructions)' within bounding box '[1.6002, 5.4703], [4.1714, 5.4703], [4.1714, 5.5734], [1.6002, 5.5734]'
# ...Word 'Tip' has a confidence of 1.0
# ...Word 'income' has a confidence of 1.0
# ...Word 'not' has a confidence of 1.0
# ...Word 'reported' has a confidence of 1.0
# ...Word 'on' has a confidence of 1.0
# ...Word 'line' has a confidence of 1.0
# ...Word '1a' has a confidence of 1.0
# ...Word '(see' has a confidence of 1.0
# ...Word 'instructions)' has a confidence of 1.0
# Line # 109 has word count '1' and text '1c' within bounding box '[6.7954, 5.4738], [6.9099, 5.4738], [6.9099, 5.553], [6.7954, 5.553]'
# ...Word '1c' has a confidence of 1.0
# Line # 110 has word count '1' and text '.' within bounding box '[4.3426, 5.5392], [4.3549, 5.5392], [4.3549, 5.5515], [4.3426, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 111 has word count '1' and text '.' within bounding box '[4.5092, 5.5392], [4.5216, 5.5392], [4.5216, 5.5515], [4.5092, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 112 has word count '1' and text '.' within bounding box '[4.6759, 5.5392], [4.6882, 5.5392], [4.6882, 5.5515], [4.6759, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 113 has word count '1' and text '.' within bounding box '[4.8426, 5.5392], [4.8549, 5.5392], [4.8549, 5.5515], [4.8426, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 114 has word count '1' and text '.' within bounding box '[5.0092, 5.5392], [5.0216, 5.5392], [5.0216, 5.5515], [5.0092, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 115 has word count '1' and text '.' within bounding box '[5.1759, 5.5392], [5.1882, 5.5392], [5.1882, 5.5515], [5.1759, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 116 has word count '1' and text '.' within bounding box '[5.3426, 5.5392], [5.3549, 5.5392], [5.3549, 5.5515], [5.3426, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 117 has word count '1' and text '.' within bounding box '[5.5092, 5.5392], [5.5216, 5.5392], [5.5216, 5.5515], [5.5092, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 118 has word count '1' and text '.' within bounding box '[5.6759, 5.5392], [5.6882, 5.5392], [5.6882, 5.5515], [5.6759, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 119 has word count '1' and text '.' within bounding box '[5.8426, 5.5392], [5.8549, 5.5392], [5.8549, 5.5515], [5.8426, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 120 has word count '1' and text '.' within bounding box '[6.0092, 5.5392], [6.0216, 5.5392], [6.0216, 5.5515], [6.0092, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 121 has word count '1' and text '.' within bounding box '[6.1759, 5.5392], [6.1882, 5.5392], [6.1882, 5.5515], [6.1759, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 122 has word count '1' and text '.' within bounding box '[6.3426, 5.5392], [6.3549, 5.5392], [6.3549, 5.5515], [6.3426, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 123 has word count '1' and text '.' within bounding box '[6.5092, 5.5392], [6.5216, 5.5392], [6.5216, 5.5515], [6.5092, 5.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 124 has word count '3' and text 'W-2 here. Also' within bounding box '[0.5003, 5.5611], [1.1732, 5.5611], [1.1732, 5.6318], [0.5003, 5.6318]'
# ...Word 'W-2' has a confidence of 1.0
# ...Word 'here.' has a confidence of 1.0
# ...Word 'Also' has a confidence of 1.0
# Line # 125 has word count '2' and text 'attach Forms' within bounding box '[0.5031, 5.6778], [1.1129, 5.6778], [1.1129, 5.7484], [0.5031, 5.7484]'
# ...Word 'attach' has a confidence of 1.0
# ...Word 'Forms' has a confidence of 1.0
# Line # 126 has word count '1' and text 'd' within bounding box '[1.4036, 5.6389], [1.462, 5.6389], [1.462, 5.7197], [1.4036, 5.7197]'
# ...Word 'd' has a confidence of 1.0
# Line # 127 has word count '11' and text 'Medicaid waiver payments not reported on Form(s) W-2 (see instructions) .' within bounding box '[1.6089, 5.637], [5.3549, 5.637], [5.3549, 5.7411], [1.6089, 5.7411]'
# ...Word 'Medicaid' has a confidence of 1.0
# ...Word 'waiver' has a confidence of 1.0
# ...Word 'payments' has a confidence of 1.0
# ...Word 'not' has a confidence of 1.0
# ...Word 'reported' has a confidence of 1.0
# ...Word 'on' has a confidence of 1.0
# ...Word 'Form(s)' has a confidence of 1.0
# ...Word 'W-2' has a confidence of 1.0
# ...Word '(see' has a confidence of 1.0
# ...Word 'instructions)' has a confidence of 1.0
# ...Word '.' has a confidence of 1.0
# Line # 128 has word count '1' and text '1d' within bounding box '[6.7934, 5.6389], [6.9089, 5.6389], [6.9089, 5.7197], [6.7934, 5.7197]'
# ...Word '1d' has a confidence of 1.0
# Line # 129 has word count '1' and text '.' within bounding box '[5.5092, 5.7059], [5.5216, 5.7059], [5.5216, 5.7182], [5.5092, 5.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 130 has word count '1' and text '.' within bounding box '[5.6759, 5.7059], [5.6882, 5.7059], [5.6882, 5.7182], [5.6759, 5.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 131 has word count '1' and text '.' within bounding box '[5.8426, 5.7059], [5.8549, 5.7059], [5.8549, 5.7182], [5.8426, 5.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 132 has word count '1' and text '.' within bounding box '[6.0092, 5.7059], [6.0216, 5.7059], [6.0216, 5.7182], [6.0092, 5.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 133 has word count '1' and text '.' within bounding box '[6.1759, 5.7059], [6.1882, 5.7059], [6.1882, 5.7182], [6.1759, 5.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 134 has word count '1' and text '.' within bounding box '[6.3426, 5.7059], [6.3549, 5.7059], [6.3549, 5.7182], [6.3426, 5.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 135 has word count '1' and text '.' within bounding box '[6.5092, 5.7059], [6.5216, 5.7059], [6.5216, 5.7182], [6.5092, 5.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 136 has word count '2' and text 'W-2G and' within bounding box '[0.5003, 5.7928], [0.9539, 5.7928], [0.9539, 5.8654], [0.5003, 5.8654]'
# ...Word 'W-2G' has a confidence of 1.0
# ...Word 'and' has a confidence of 1.0
# Line # 137 has word count '1' and text 'e' within bounding box '[1.4032, 5.8259], [1.4616, 5.8259], [1.4616, 5.8863], [1.4032, 5.8863]'
# ...Word 'e' has a confidence of 1.0
# Line # 138 has word count '9' and text 'Taxable dependent care benefits from Form 2441, line 26' within bounding box '[1.6002, 5.8047], [4.4403, 5.8047], [4.4403, 5.9068], [1.6002, 5.9068]'
# ...Word 'Taxable' has a confidence of 1.0
# ...Word 'dependent' has a confidence of 1.0
# ...Word 'care' has a confidence of 1.0
# ...Word 'benefits' has a confidence of 1.0
# ...Word 'from' has a confidence of 1.0
# ...Word 'Form' has a confidence of 1.0
# ...Word '2441,' has a confidence of 1.0
# ...Word 'line' has a confidence of 1.0
# ...Word '26' has a confidence of 1.0
# Line # 139 has word count '1' and text '1e' within bounding box '[6.7954, 5.8071], [6.9106, 5.8071], [6.9106, 5.8863], [6.7954, 5.8863]'
# ...Word '1e' has a confidence of 1.0
# Line # 140 has word count '1' and text '.' within bounding box '[4.6759, 5.8725], [4.6882, 5.8725], [4.6882, 5.8849], [4.6759, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 141 has word count '1' and text '.' within bounding box '[4.8426, 5.8725], [4.8549, 5.8725], [4.8549, 5.8849], [4.8426, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 142 has word count '1' and text '.' within bounding box '[5.0092, 5.8725], [5.0216, 5.8725], [5.0216, 5.8849], [5.0092, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 143 has word count '1' and text '.' within bounding box '[5.1759, 5.8725], [5.1882, 5.8725], [5.1882, 5.8849], [5.1759, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 144 has word count '1' and text '.' within bounding box '[5.3426, 5.8725], [5.3549, 5.8725], [5.3549, 5.8849], [5.3426, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 145 has word count '1' and text '.' within bounding box '[5.5092, 5.8725], [5.5216, 5.8725], [5.5216, 5.8849], [5.5092, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 146 has word count '1' and text '.' within bounding box '[5.6759, 5.8725], [5.6882, 5.8725], [5.6882, 5.8849], [5.6759, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 147 has word count '1' and text '.' within bounding box '[5.8426, 5.8725], [5.8549, 5.8725], [5.8549, 5.8849], [5.8426, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 148 has word count '1' and text '.' within bounding box '[6.0092, 5.8725], [6.0216, 5.8725], [6.0216, 5.8849], [6.0092, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 149 has word count '1' and text '.' within bounding box '[6.1759, 5.8725], [6.1882, 5.8725], [6.1882, 5.8849], [6.1759, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 150 has word count '1' and text '.' within bounding box '[6.3426, 5.8725], [6.3549, 5.8725], [6.3549, 5.8849], [6.3426, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 151 has word count '1' and text '.' within bounding box '[6.5092, 5.8725], [6.5216, 5.8725], [6.5216, 5.8849], [6.5092, 5.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 152 has word count '3' and text '1099-R if tax' within bounding box '[0.5072, 5.9111], [1.0797, 5.9111], [1.0797, 5.9818], [0.5072, 5.9818]'
# ...Word '1099-R' has a confidence of 1.0
# ...Word 'if' has a confidence of 1.0
# ...Word 'tax' has a confidence of 1.0
# Line # 153 has word count '2' and text 'was withheld.' within bounding box '[0.5006, 6.0278], [1.1293, 6.0278], [1.1293, 6.0984], [0.5006, 6.0984]'
# ...Word 'was' has a confidence of 1.0
# ...Word 'withheld.' has a confidence of 1.0
# Line # 154 has word count '1' and text 'f' within bounding box '[1.4, 5.9722], [1.437, 5.9722], [1.437, 6.0515], [1.4, 6.0515]'
# ...Word 'f' has a confidence of 1.0
# Line # 155 has word count '8' and text 'Employer-provided adoption benefits from Form 8839, line 29' within bounding box '[1.6087, 5.9713], [4.6576, 5.9713], [4.6576, 6.0744], [1.6087, 6.0744]'
# ...Word 'Employer-provided' has a confidence of 1.0
# ...Word 'adoption' has a confidence of 1.0
# ...Word 'benefits' has a confidence of 1.0
# ...Word 'from' has a confidence of 1.0
# ...Word 'Form' has a confidence of 1.0
# ...Word '8839,' has a confidence of 1.0
# ...Word 'line' has a confidence of 1.0
# ...Word '29' has a confidence of 1.0
# Line # 156 has word count '1' and text '1f' within bounding box '[6.8088, 5.9722], [6.8994, 5.9722], [6.8994, 6.0515], [6.8088, 6.0515]'
# ...Word '1f' has a confidence of 1.0
# Line # 157 has word count '1' and text '.' within bounding box '[4.8426, 6.0392], [4.8549, 6.0392], [4.8549, 6.0515], [4.8426, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 158 has word count '1' and text '.' within bounding box '[5.0092, 6.0392], [5.0216, 6.0392], [5.0216, 6.0515], [5.0092, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 159 has word count '1' and text '.' within bounding box '[5.1759, 6.0392], [5.1882, 6.0392], [5.1882, 6.0515], [5.1759, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 160 has word count '1' and text '.' within bounding box '[5.3426, 6.0392], [5.3549, 6.0392], [5.3549, 6.0515], [5.3426, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 161 has word count '1' and text '.' within bounding box '[5.5092, 6.0392], [5.5216, 6.0392], [5.5216, 6.0515], [5.5092, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 162 has word count '1' and text '.' within bounding box '[5.6759, 6.0392], [5.6882, 6.0392], [5.6882, 6.0515], [5.6759, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 163 has word count '1' and text '.' within bounding box '[5.8426, 6.0392], [5.8549, 6.0392], [5.8549, 6.0515], [5.8426, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 164 has word count '1' and text '.' within bounding box '[6.0092, 6.0392], [6.0216, 6.0392], [6.0216, 6.0515], [6.0092, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 165 has word count '1' and text '.' within bounding box '[6.1759, 6.0392], [6.1882, 6.0392], [6.1882, 6.0515], [6.1759, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 166 has word count '1' and text '.' within bounding box '[6.3426, 6.0392], [6.3549, 6.0392], [6.3549, 6.0515], [6.3426, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 167 has word count '1' and text '.' within bounding box '[6.5092, 6.0392], [6.5216, 6.0392], [6.5216, 6.0515], [6.5092, 6.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 168 has word count '4' and text 'If you did not' within bounding box '[0.508, 6.1854], [1.068, 6.1854], [1.068, 6.2756], [0.508, 6.2756]'
# ...Word 'If' has a confidence of 1.0
# ...Word 'you' has a confidence of 1.0
# ...Word 'did' has a confidence of 1.0
# ...Word 'not' has a confidence of 1.0
# Line # 169 has word count '1' and text 'g' within bounding box '[1.4042, 6.1592], [1.4612, 6.1592], [1.4612, 6.2399], [1.4042, 6.2399]'
# ...Word 'g' has a confidence of 1.0
# Line # 170 has word count '7' and text 'Wages from Form 8919, line 6 .' within bounding box '[1.6013, 6.138], [3.1882, 6.138], [3.1882, 6.2414], [1.6013, 6.2414]'
# ...Word 'Wages' has a confidence of 1.0
# ...Word 'from' has a confidence of 1.0
# ...Word 'Form' has a confidence of 1.0
# ...Word '8919,' has a confidence of 1.0
# ...Word 'line' has a confidence of 1.0
# ...Word '6' has a confidence of 1.0
# ...Word '.' has a confidence of 1.0
# Line # 171 has word count '1' and text '1g' within bounding box '[6.7934, 6.1404], [6.9082, 6.1404], [6.9082, 6.2399], [6.7934, 6.2399]'
# ...Word '1g' has a confidence of 1.0
# Line # 172 has word count '1' and text '.' within bounding box '[3.3426, 6.2059], [3.3549, 6.2059], [3.3549, 6.2182], [3.3426, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 173 has word count '1' and text '.' within bounding box '[3.5092, 6.2059], [3.5216, 6.2059], [3.5216, 6.2182], [3.5092, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 174 has word count '1' and text '.' within bounding box '[3.6759, 6.2059], [3.6882, 6.2059], [3.6882, 6.2182], [3.6759, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 175 has word count '1' and text '.' within bounding box '[3.8426, 6.2059], [3.8549, 6.2059], [3.8549, 6.2182], [3.8426, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 176 has word count '1' and text '.' within bounding box '[4.0092, 6.2059], [4.0216, 6.2059], [4.0216, 6.2182], [4.0092, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 177 has word count '1' and text '.' within bounding box '[4.1759, 6.2059], [4.1882, 6.2059], [4.1882, 6.2182], [4.1759, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 178 has word count '1' and text '.' within bounding box '[4.3426, 6.2059], [4.3549, 6.2059], [4.3549, 6.2182], [4.3426, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 179 has word count '1' and text '.' within bounding box '[4.5092, 6.2059], [4.5216, 6.2059], [4.5216, 6.2182], [4.5092, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 180 has word count '1' and text '.' within bounding box '[4.6759, 6.2059], [4.6882, 6.2059], [4.6882, 6.2182], [4.6759, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 181 has word count '1' and text '.' within bounding box '[4.8426, 6.2059], [4.8549, 6.2059], [4.8549, 6.2182], [4.8426, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 182 has word count '1' and text '.' within bounding box '[5.0092, 6.2059], [5.0216, 6.2059], [5.0216, 6.2182], [5.0092, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 183 has word count '1' and text '.' within bounding box '[5.1759, 6.2059], [5.1882, 6.2059], [5.1882, 6.2182], [5.1759, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 184 has word count '1' and text '.' within bounding box '[5.3426, 6.2059], [5.3549, 6.2059], [5.3549, 6.2182], [5.3426, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 185 has word count '1' and text '.' within bounding box '[5.5092, 6.2059], [5.5216, 6.2059], [5.5216, 6.2182], [5.5092, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 186 has word count '1' and text '.' within bounding box '[5.6759, 6.2059], [5.6882, 6.2059], [5.6882, 6.2182], [5.6759, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 187 has word count '1' and text '.' within bounding box '[5.8426, 6.2059], [5.8549, 6.2059], [5.8549, 6.2182], [5.8426, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 188 has word count '1' and text '.' within bounding box '[6.0092, 6.2059], [6.0216, 6.2059], [6.0216, 6.2182], [6.0092, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 189 has word count '1' and text '.' within bounding box '[6.1759, 6.2059], [6.1882, 6.2059], [6.1882, 6.2182], [6.1759, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 190 has word count '1' and text '.' within bounding box '[6.3426, 6.2059], [6.3549, 6.2059], [6.3549, 6.2182], [6.3426, 6.2182]'
# ...Word '.' has a confidence of 1.0
# Line # 191 has word count '1' and text '.' within bounding box '[6.5092, 6.2059], [6.5216, 6.2059], [6.5216, 6.2182], [6.5092, 6.2182]'
# ...Word '.' has a confidence of 1.0
# ...
# ...Word '.' has a confidence of 1.0
# Line # 400 has word count '1' and text '.' within bounding box '[5.6759, 8.5392], [5.6882, 8.5392], [5.6882, 8.5515], [5.6759, 8.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 401 has word count '1' and text '.' within bounding box '[5.8426, 8.5392], [5.8549, 8.5392], [5.8549, 8.5515], [5.8426, 8.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 402 has word count '1' and text '.' within bounding box '[6.0092, 8.5392], [6.0216, 8.5392], [6.0216, 8.5515], [6.0092, 8.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 403 has word count '1' and text '.' within bounding box '[6.1759, 8.5392], [6.1882, 8.5392], [6.1882, 8.5515], [6.1759, 8.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 404 has word count '1' and text '.' within bounding box '[6.3426, 8.5392], [6.3549, 8.5392], [6.3549, 8.5515], [6.3426, 8.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 405 has word count '1' and text '.' within bounding box '[6.5092, 8.5392], [6.5216, 8.5392], [6.5216, 8.5515], [6.5092, 8.5515]'
# ...Word '.' has a confidence of 1.0
# Line # 406 has word count '1' and text 'household,' within bounding box '[0.5336, 8.5917], [0.9667, 8.5917], [0.9667, 8.6694], [0.5336, 8.6694]'
# ...Word 'household,' has a confidence of 1.0
# Line # 407 has word count '1' and text '$19,400' within bounding box '[0.5301, 8.6815], [0.8503, 8.6815], [0.8503, 8.7666], [0.5301, 8.7666]'
# ...Word '$19,400' has a confidence of 1.0
# Line # 408 has word count '1' and text '12' within bounding box '[1.2847, 8.6389], [1.3977, 8.6389], [1.3977, 8.7182], [1.2847, 8.7182]'
# ...Word '12' has a confidence of 1.0
# Line # 409 has word count '8' and text 'Standard deduction or itemized deductions (from Schedule A)' within bounding box '[1.6024, 8.637], [4.8003, 8.637], [4.8003, 8.7401], [1.6024, 8.7401]'
# ...Word 'Standard' has a confidence of 1.0
# ...Word 'deduction' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'itemized' has a confidence of 1.0
# ...Word 'deductions' has a confidence of 1.0
# ...Word '(from' has a confidence of 1.0
# ...Word 'Schedule' has a confidence of 1.0
# ...Word 'A)' has a confidence of 1.0
# Line # 410 has word count '1' and text '12' within bounding box '[6.7964, 8.6389], [6.9094, 8.6389], [6.9094, 8.7182], [6.7964, 8.7182]'
# ...Word '12' has a confidence of 1.0
# Line # 411 has word count '1' and text '.' within bounding box '[5.0092, 8.7059], [5.0216, 8.7059], [5.0216, 8.7182], [5.0092, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 412 has word count '1' and text '.' within bounding box '[5.1759, 8.7059], [5.1882, 8.7059], [5.1882, 8.7182], [5.1759, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 413 has word count '1' and text '.' within bounding box '[5.3426, 8.7059], [5.3549, 8.7059], [5.3549, 8.7182], [5.3426, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 414 has word count '1' and text '.' within bounding box '[5.5092, 8.7059], [5.5216, 8.7059], [5.5216, 8.7182], [5.5092, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 415 has word count '1' and text '.' within bounding box '[5.6759, 8.7059], [5.6882, 8.7059], [5.6882, 8.7182], [5.6759, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 416 has word count '1' and text '.' within bounding box '[5.8426, 8.7059], [5.8549, 8.7059], [5.8549, 8.7182], [5.8426, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 417 has word count '1' and text '.' within bounding box '[6.0092, 8.7059], [6.0216, 8.7059], [6.0216, 8.7182], [6.0092, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 418 has word count '1' and text '.' within bounding box '[6.1759, 8.7059], [6.1882, 8.7059], [6.1882, 8.7182], [6.1759, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 419 has word count '1' and text '.' within bounding box '[6.3426, 8.7059], [6.3549, 8.7059], [6.3549, 8.7182], [6.3426, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 420 has word count '1' and text '.' within bounding box '[6.5092, 8.7059], [6.5216, 8.7059], [6.5216, 8.7182], [6.5092, 8.7182]'
# ...Word '.' has a confidence of 1.0
# Line # 421 has word count '1' and text '•' within bounding box '[0.4649, 8.8302], [0.4971, 8.8302], [0.4971, 8.8624], [0.4649, 8.8624]'
# ...Word '•' has a confidence of 1.0
# Line # 422 has word count '3' and text 'If you checked' within bounding box '[0.5359, 8.8132], [1.1028, 8.8132], [1.1028, 8.897], [0.5359, 8.897]'
# ...Word 'If' has a confidence of 1.0
# ...Word 'you' has a confidence of 1.0
# ...Word 'checked' has a confidence of 1.0
# Line # 423 has word count '1' and text '13' within bounding box '[1.2847, 8.8055], [1.398, 8.8055], [1.398, 8.8863], [1.2847, 8.8863]'
# ...Word '13' has a confidence of 1.0
# Line # 424 has word count '11' and text 'Qualified business income deduction from Form 8995 or Form 8995-A .' within bounding box '[1.6042, 8.8037], [5.1882, 8.8037], [5.1882, 8.8917], [1.6042, 8.8917]'
# ...Word 'Qualified' has a confidence of 1.0
# ...Word 'business' has a confidence of 1.0
# ...Word 'income' has a confidence of 1.0
# ...Word 'deduction' has a confidence of 1.0
# ...Word 'from' has a confidence of 1.0
# ...Word 'Form' has a confidence of 1.0
# ...Word '8995' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'Form' has a confidence of 1.0
# ...Word '8995-A' has a confidence of 1.0
# ...Word '.' has a confidence of 1.0
# Line # 425 has word count '1' and text '13' within bounding box '[6.7964, 8.8055], [6.9098, 8.8055], [6.9098, 8.8863], [6.7964, 8.8863]'
# ...Word '13' has a confidence of 1.0
# Line # 426 has word count '1' and text '.' within bounding box '[5.3426, 8.8725], [5.3549, 8.8725], [5.3549, 8.8849], [5.3426, 8.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 427 has word count '1' and text '.' within bounding box '[5.5092, 8.8725], [5.5216, 8.8725], [5.5216, 8.8849], [5.5092, 8.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 428 has word count '1' and text '.' within bounding box '[5.6759, 8.8725], [5.6882, 8.8725], [5.6882, 8.8849], [5.6759, 8.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 429 has word count '1' and text '.' within bounding box '[5.8426, 8.8725], [5.8549, 8.8725], [5.8549, 8.8849], [5.8426, 8.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 430 has word count '1' and text '.' within bounding box '[6.0092, 8.8725], [6.0216, 8.8725], [6.0216, 8.8849], [6.0092, 8.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 431 has word count '1' and text '.' within bounding box '[6.1759, 8.8725], [6.1882, 8.8725], [6.1882, 8.8849], [6.1759, 8.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 432 has word count '1' and text '.' within bounding box '[6.3426, 8.8725], [6.3549, 8.8725], [6.3549, 8.8849], [6.3426, 8.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 433 has word count '1' and text '.' within bounding box '[6.5092, 8.8725], [6.5216, 8.8725], [6.5216, 8.8849], [6.5092, 8.8849]'
# ...Word '.' has a confidence of 1.0
# Line # 434 has word count '3' and text 'any box under' within bounding box '[0.531, 8.9112], [1.0948, 8.9112], [1.0948, 8.9943], [0.531, 8.9943]'
# ...Word 'any' has a confidence of 1.0
# ...Word 'box' has a confidence of 1.0
# ...Word 'under' has a confidence of 1.0
# Line # 435 has word count '1' and text 'Standard' within bounding box '[0.5281, 9.0069], [0.8896, 9.0069], [0.8896, 9.0743], [0.5281, 9.0743]'
# ...Word 'Standard' has a confidence of 1.0
# Line # 436 has word count '1' and text '14' within bounding box '[1.2847, 8.9738], [1.3982, 8.9738], [1.3982, 9.0515], [1.2847, 9.0515]'
# ...Word '14' has a confidence of 1.0
# Line # 437 has word count '5' and text 'Add lines 12 and 13' within bounding box '[1.5993, 8.9722], [2.583, 8.9722], [2.583, 9.0528], [1.5993, 9.0528]'
# ...Word 'Add' has a confidence of 1.0
# ...Word 'lines' has a confidence of 1.0
# ...Word '12' has a confidence of 1.0
# ...Word 'and' has a confidence of 1.0
# ...Word '13' has a confidence of 1.0
# Line # 438 has word count '1' and text '14' within bounding box '[6.7964, 8.9738], [6.91, 8.9738], [6.91, 9.0515], [6.7964, 9.0515]'
# ...Word '14' has a confidence of 1.0
# Line # 439 has word count '1' and text '.' within bounding box '[2.6759, 9.0392], [2.6882, 9.0392], [2.6882, 9.0515], [2.6759, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 440 has word count '1' and text '.' within bounding box '[2.8426, 9.0392], [2.8549, 9.0392], [2.8549, 9.0515], [2.8426, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 441 has word count '1' and text '.' within bounding box '[3.0092, 9.0392], [3.0216, 9.0392], [3.0216, 9.0515], [3.0092, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 442 has word count '1' and text '.' within bounding box '[3.1759, 9.0392], [3.1882, 9.0392], [3.1882, 9.0515], [3.1759, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 443 has word count '1' and text '.' within bounding box '[3.3426, 9.0392], [3.3549, 9.0392], [3.3549, 9.0515], [3.3426, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 444 has word count '1' and text '.' within bounding box '[3.5092, 9.0392], [3.5216, 9.0392], [3.5216, 9.0515], [3.5092, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 445 has word count '1' and text '.' within bounding box '[3.6759, 9.0392], [3.6882, 9.0392], [3.6882, 9.0515], [3.6759, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 446 has word count '1' and text '.' within bounding box '[3.8426, 9.0392], [3.8549, 9.0392], [3.8549, 9.0515], [3.8426, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 447 has word count '1' and text '.' within bounding box '[4.0092, 9.0392], [4.0216, 9.0392], [4.0216, 9.0515], [4.0092, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 448 has word count '1' and text '.' within bounding box '[4.1759, 9.0392], [4.1882, 9.0392], [4.1882, 9.0515], [4.1759, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 449 has word count '1' and text '.' within bounding box '[4.3426, 9.0392], [4.3549, 9.0392], [4.3549, 9.0515], [4.3426, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 450 has word count '1' and text '.' within bounding box '[4.5092, 9.0392], [4.5216, 9.0392], [4.5216, 9.0515], [4.5092, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 451 has word count '1' and text '.' within bounding box '[4.6759, 9.0392], [4.6882, 9.0392], [4.6882, 9.0515], [4.6759, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 452 has word count '1' and text '.' within bounding box '[4.8426, 9.0392], [4.8549, 9.0392], [4.8549, 9.0515], [4.8426, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 453 has word count '1' and text '.' within bounding box '[5.0092, 9.0392], [5.0216, 9.0392], [5.0216, 9.0515], [5.0092, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 454 has word count '1' and text '.' within bounding box '[5.1759, 9.0392], [5.1882, 9.0392], [5.1882, 9.0515], [5.1759, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 455 has word count '1' and text '.' within bounding box '[5.3426, 9.0392], [5.3549, 9.0392], [5.3549, 9.0515], [5.3426, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 456 has word count '1' and text '.' within bounding box '[5.5092, 9.0392], [5.5216, 9.0392], [5.5216, 9.0515], [5.5092, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 457 has word count '1' and text '.' within bounding box '[5.6759, 9.0392], [5.6882, 9.0392], [5.6882, 9.0515], [5.6759, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 458 has word count '1' and text '.' within bounding box '[5.8426, 9.0392], [5.8549, 9.0392], [5.8549, 9.0515], [5.8426, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 459 has word count '1' and text '.' within bounding box '[6.0092, 9.0392], [6.0216, 9.0392], [6.0216, 9.0515], [6.0092, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 460 has word count '1' and text '.' within bounding box '[6.1759, 9.0392], [6.1882, 9.0392], [6.1882, 9.0515], [6.1759, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 461 has word count '1' and text '.' within bounding box '[6.3426, 9.0392], [6.3549, 9.0392], [6.3549, 9.0515], [6.3426, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 462 has word count '1' and text '.' within bounding box '[6.5092, 9.0392], [6.5216, 9.0392], [6.5216, 9.0515], [6.5092, 9.0515]'
# ...Word '.' has a confidence of 1.0
# Line # 463 has word count '1' and text 'Deduction,' within bounding box '[0.5284, 9.1057], [0.9514, 9.1057], [0.9514, 9.1833], [0.5284, 9.1833]'
# ...Word 'Deduction,' has a confidence of 1.0
# Line # 464 has word count '1' and text '15' within bounding box '[1.2847, 9.1335], [1.398, 9.1335], [1.398, 9.2131], [1.2847, 9.2131]'
# ...Word '15' has a confidence of 1.0
# Line # 465 has word count '17' and text 'Subtract line 14 from line 11. If zero or less, enter -0-. This is your taxable income' within bounding box '[1.6041, 9.1301], [5.6822, 9.1301], [5.6822, 9.2342], [1.6041, 9.2342]'
# ...Word 'Subtract' has a confidence of 1.0
# ...Word 'line' has a confidence of 1.0
# ...Word '14' has a confidence of 1.0
# ...Word 'from' has a confidence of 1.0
# ...Word 'line' has a confidence of 1.0
# ...Word '11.' has a confidence of 1.0
# ...Word 'If' has a confidence of 1.0
# ...Word 'zero' has a confidence of 1.0
# ...Word 'or' has a confidence of 1.0
# ...Word 'less,' has a confidence of 1.0
# ...Word 'enter' has a confidence of 1.0
# ...Word '-0-.' has a confidence of 1.0
# ...Word 'This' has a confidence of 1.0
# ...Word 'is' has a confidence of 1.0
# ...Word 'your' has a confidence of 1.0
# ...Word 'taxable' has a confidence of 1.0
# ...Word 'income' has a confidence of 1.0
# Line # 466 has word count '2' and text 'see instructions.' within bounding box '[0.5306, 9.2029], [1.1677, 9.2029], [1.1677, 9.2683], [0.5306, 9.2683]'
# ...Word 'see' has a confidence of 1.0
# ...Word 'instructions.' has a confidence of 1.0
# Line # 467 has word count '1' and text '15' within bounding box '[6.7964, 9.1404], [6.9098, 9.1404], [6.9098, 9.22], [6.7964, 9.22]'
# ...Word '15' has a confidence of 1.0
# Line # 468 has word count '1' and text '.' within bounding box '[5.8426, 9.1989], [5.8549, 9.1989], [5.8549, 9.2113], [5.8426, 9.2113]'
# ...Word '.' has a confidence of 1.0
# Line # 469 has word count '1' and text '.' within bounding box '[6.0092, 9.1989], [6.0216, 9.1989], [6.0216, 9.2113], [6.0092, 9.2113]'
# ...Word '.' has a confidence of 1.0
# Line # 470 has word count '1' and text '.' within bounding box '[6.1759, 9.1989], [6.1882, 9.1989], [6.1882, 9.2113], [6.1759, 9.2113]'
# ...Word '.' has a confidence of 1.0
# Line # 471 has word count '1' and text '.' within bounding box '[6.3426, 9.1989], [6.3549, 9.1989], [6.3549, 9.2113], [6.3426, 9.2113]'
# ...Word '.' has a confidence of 1.0
# Line # 472 has word count '1' and text '.' within bounding box '[6.5092, 9.1989], [6.5216, 9.1989], [6.5216, 9.2113], [6.5092, 9.2113]'
# ...Word '.' has a confidence of 1.0
# Line # 473 has word count '12' and text 'For Disclosure, Privacy Act, and Paperwork Reduction Act Notice, see separate instructions.' within bounding box '[0.5067, 9.4861], [4.7771, 9.4861], [4.7771, 9.5731], [0.5067, 9.5731]'
# ...Word 'For' has a confidence of 1.0
# ...Word 'Disclosure,' has a confidence of 1.0
# ...Word 'Privacy' has a confidence of 1.0
# ...Word 'Act,' has a confidence of 1.0
# ...Word 'and' has a confidence of 1.0
# ...Word 'Paperwork' has a confidence of 1.0
# ...Word 'Reduction' has a confidence of 1.0
# ...Word 'Act' has a confidence of 1.0
# ...Word 'Notice,' has a confidence of 1.0
# ...Word 'see' has a confidence of 1.0
# ...Word 'separate' has a confidence of 1.0
# ...Word 'instructions.' has a confidence of 1.0
# Line # 474 has word count '3' and text 'Cat. No. 11320B' within bounding box '[5.6933, 9.4916], [6.3065, 9.4916], [6.3065, 9.5539], [5.6933, 9.5539]'
# ...Word 'Cat.' has a confidence of 1.0
# ...Word 'No.' has a confidence of 1.0
# ...Word '11320B' has a confidence of 1.0
# Line # 475 has word count '3' and text 'Form 1040 (2022)' within bounding box '[7.2324, 9.4625], [7.9954, 9.4625], [7.9954, 9.5709], [7.2324, 9.5709]'
# ...Word 'Form' has a confidence of 1.0
# ...Word '1040' has a confidence of 1.0
# ...Word '(2022)' has a confidence of 1.0

# %% [markdown]
# #### Extract tables with rows and columns in the Form 1040

# %%
for table_idx, table in enumerate(content.tables):
    print("Table # {} has {} rows and {} columns".format(table_idx, table.row_count, table.column_count))
    print("Table # {} location on page: {}".format(table_idx, format_bounding_box(table.bounding_box)))
    for cell in table.cells:
        print("...Cell[{}][{}] has text '{}' within bounding box '{}'".format(cell.row_index, cell.column_index, cell.text, format_bounding_box(cell.bounding_box)))
# Out:
# Table # 0 has 31 rows and 10 columns
# Table # 0 location on page: [0.4379, 3.9777], [8.0414, 3.9755], [8.0427, 9.3346], [0.4369, 9.3308]
# ...Cell[0][0] has text 'Age/Blindness' within bounding box '[0.4464, 3.9195], [1.2812, 3.9195], [1.2812, 4.0812], [0.4386, 4.0812]'
# ...Cell[0][1] has text 'You: Were born before January 2, 1958' within bounding box '[1.2812, 3.9195], [3.6685, 3.9195], [3.6607, 4.0812], [1.2812, 4.0812]'
# ...Cell[0][4] has text 'Are blind' within bounding box '[3.6685, 3.9195], [4.2225, 3.9195], [4.2225, 4.0812], [3.6607, 4.0812]'
# ...Cell[0][5] has text 'Spouse:' within bounding box '[4.2225, 3.9195], [4.8856, 3.9195], [4.8856, 4.0812], [4.2225, 4.0812]'
# ...Cell[0][6] has text 'Was born before January 2, 1958' within bounding box '[4.8856, 3.9195], [6.9765, 3.9195], [6.9765, 4.0812], [4.8856, 4.0812]'
# ...Cell[0][9] has text 'Is blind' within bounding box '[6.9765, 3.9195], [7.9985, 3.9195], [7.9985, 4.0812], [6.9765, 4.0812]'
# ...Cell[1][0] has text 'Dependents If more' within bounding box '[0.4386, 4.0812], [1.2812, 4.0812], [1.2734, 4.4123], [0.4386, 4.42]'
# ...Cell[1][1] has text '(see instructions): (1) First name Last name' within bounding box '[1.2812, 4.0812], [3.6607, 4.0812], [3.6607, 4.4123], [1.2734, 4.4123]'
# ...Cell[1][4] has text '(2) Social security number' within bounding box '[3.6607, 4.0812], [4.8856, 4.0812], [4.8856, 4.4123], [3.6607, 4.4123]'
# ...Cell[1][6] has text '(3) Relationship to you' within bounding box '[4.8856, 4.0812], [5.775, 4.0812], [5.775, 4.4123], [4.8856, 4.4123]'
# ...Cell[1][7] has text '(4) Check the box if qualifies Child tax credit' within bounding box '[5.775, 4.0812], [6.9765, 4.0812], [6.9765, 4.4123], [5.775, 4.4123]'
# ...Cell[1][9] has text 'for (see instructions): Credit for other dependents' within bounding box '[6.9765, 4.0812], [7.9985, 4.0812], [7.9985, 4.4123], [6.9765, 4.4123]'
# ...Cell[2][0] has text 'than four' within bounding box '[0.4386, 4.42], [1.2734, 4.4123], [1.2656, 4.574], [0.4386, 4.574]'
# ...Cell[2][1] has text '' within bounding box '[1.2734, 4.4123], [3.6607, 4.4123], [3.6607, 4.5817], [1.2656, 4.574]'
# ...Cell[2][4] has text '' within bounding box '[3.6607, 4.4123], [4.2225, 4.4123], [4.2303, 4.5817], [3.6607, 4.5817]'
# ...Cell[2][5] has text '' within bounding box '[4.2225, 4.4123], [4.8856, 4.4123], [4.8856, 4.5817], [4.2303, 4.5817]'
# ...Cell[2][6] has text '' within bounding box '[4.8856, 4.4123], [5.775, 4.4123], [5.775, 4.5817], [4.8856, 4.5817]'
# ...Cell[2][7] has text '' within bounding box '[5.775, 4.4123], [6.9765, 4.4123], [6.9843, 4.5817], [5.775, 4.5817]'
# ...Cell[2][9] has text '' within bounding box '[6.9765, 4.4123], [7.9985, 4.4123], [7.9985, 4.5817], [6.9843, 4.5817]'
# ...Cell[3][0] has text 'dependents,' within bounding box '[0.4386, 4.574], [1.2656, 4.574], [1.2656, 4.7203], [0.4386, 4.7203]'
# ...Cell[3][1] has text '' within bounding box '[1.2656, 4.574], [3.6607, 4.5817], [3.6607, 4.7434], [1.2656, 4.7203]'
# ...Cell[3][4] has text '' within bounding box '[3.6607, 4.5817], [4.2303, 4.5817], [4.2303, 4.7434], [3.6607, 4.7434]'
# ...Cell[3][5] has text '' within bounding box '[4.2303, 4.5817], [4.8856, 4.5817], [4.8856, 4.7434], [4.2303, 4.7434]'
# ...Cell[3][6] has text '' within bounding box '[4.8856, 4.5817], [5.775, 4.5817], [5.775, 4.7434], [4.8856, 4.7434]'
# ...Cell[3][7] has text '' within bounding box '[5.775, 4.5817], [6.9843, 4.5817], [6.9843, 4.7434], [5.775, 4.7434]'
# ...Cell[3][9] has text '' within bounding box '[6.9843, 4.5817], [7.9985, 4.5817], [7.9985, 4.7434], [6.9843, 4.7434]'
# ...Cell[4][0] has text 'see instructions and check' within bounding box '[0.4386, 4.7203], [1.2656, 4.7203], [1.2656, 4.9205], [0.4308, 4.9282]'
# ...Cell[4][1] has text '' within bounding box '[1.2656, 4.7203], [1.4528, 4.7203], [1.4528, 4.9205], [1.2656, 4.9205]'
# ...Cell[4][2] has text '' within bounding box '[1.4528, 4.7203], [3.6607, 4.7434], [3.6529, 4.9128], [1.4528, 4.9205]'
# ...Cell[4][4] has text '' within bounding box '[3.6607, 4.7434], [4.2303, 4.7434], [4.2303, 4.9128], [3.6529, 4.9128]'
# ...Cell[4][5] has text '' within bounding box '[4.2303, 4.7434], [4.8856, 4.7434], [4.8856, 4.9128], [4.2303, 4.9128]'
# ...Cell[4][6] has text '' within bounding box '[4.8856, 4.7434], [5.775, 4.7434], [5.7672, 4.9128], [4.8856, 4.9128]'
# ...Cell[4][7] has text '' within bounding box '[5.775, 4.7434], [6.7112, 4.7434], [6.7034, 4.9128], [5.7672, 4.9128]'
# ...Cell[4][8] has text '' within bounding box '[6.7112, 4.7434], [6.9843, 4.7434], [6.9843, 4.9128], [6.7034, 4.9128]'
# ...Cell[4][9] has text '' within bounding box '[6.9843, 4.7434], [7.9985, 4.7434], [7.9985, 4.9128], [6.9843, 4.9128]'
# ...Cell[5][0] has text 'here . .' within bounding box '[0.4308, 4.9282], [1.2656, 4.9205], [1.2578, 5.0745], [0.4308, 5.0745]'
# ...Cell[5][1] has text '' within bounding box '[1.2656, 4.9205], [1.4528, 4.9205], [1.4528, 5.0745], [1.2578, 5.0745]'
# ...Cell[5][2] has text '' within bounding box '[1.4528, 4.9205], [3.6529, 4.9128], [3.6529, 5.0745], [1.4528, 5.0745]'
# ...Cell[5][4] has text '' within bounding box '[3.6529, 4.9128], [4.2303, 4.9128], [4.2303, 5.0745], [3.6529, 5.0745]'
# ...Cell[5][5] has text '' within bounding box '[4.2303, 4.9128], [4.8856, 4.9128], [4.8856, 5.0745], [4.2303, 5.0745]'
# ...Cell[5][6] has text '' within bounding box '[4.8856, 4.9128], [5.7672, 4.9128], [5.7672, 5.0745], [4.8856, 5.0745]'
# ...Cell[5][7] has text '' within bounding box '[5.7672, 4.9128], [6.7034, 4.9128], [6.7034, 5.0745], [5.7672, 5.0745]'
# ...Cell[5][8] has text '' within bounding box '[6.7034, 4.9128], [6.9843, 4.9128], [6.9843, 5.0745], [6.7034, 5.0745]'
# ...Cell[5][9] has text '' within bounding box '[6.9843, 4.9128], [7.9985, 4.9128], [7.9985, 5.0745], [6.9843, 5.0745]'
# ...Cell[6][0] has text 'Income' within bounding box '[0.4308, 5.0745], [1.2578, 5.0745], [1.2578, 5.2824], [0.4308, 5.2824]'
# ...Cell[6][1] has text '1 a' within bounding box '[1.2578, 5.0745], [1.4528, 5.0745], [1.4528, 5.2824], [1.2578, 5.2824]'
# ...Cell[6][2] has text 'Total amount from Form(s) W-2, box 1 (see instructions)' within bounding box '[1.4528, 5.0745], [4.2303, 5.0745], [4.2381, 5.267], [1.4528, 5.2824]'
# ...Cell[6][5] has text '. . .' within bounding box '[4.2303, 5.0745], [4.8856, 5.0745], [4.8856, 5.267], [4.2381, 5.267]'
# ...Cell[6][6] has text '. . . . .' within bounding box '[4.8856, 5.0745], [5.7672, 5.0745], [5.7672, 5.2593], [4.8856, 5.267]'
# ...Cell[6][7] has text '. . . . .' within bounding box '[5.7672, 5.0745], [6.7034, 5.0745], [6.7034, 5.2516], [5.7672, 5.2593]'
# ...Cell[6][8] has text '1a' within bounding box '[6.7034, 5.0745], [6.9843, 5.0745], [6.9843, 5.2516], [6.7034, 5.2516]'
# ...Cell[6][9] has text '' within bounding box '[6.9843, 5.0745], [7.9985, 5.0745], [7.9985, 5.2516], [6.9843, 5.2516]'
# ...Cell[7][0] has text '' within bounding box '[0.4308, 5.2824], [1.2578, 5.2824], [1.2578, 5.421], [0.4308, 5.421]'
# ...Cell[7][1] has text 'b' within bounding box '[1.2578, 5.2824], [1.4528, 5.2824], [1.4528, 5.421], [1.2578, 5.421]'
# ...Cell[7][2] has text 'Household employee wages not reported on Form(s)' within bounding box '[1.4528, 5.2824], [4.2381, 5.267], [4.2381, 5.4287], [1.4528, 5.421]'
# ...Cell[7][5] has text 'W-2 . . .' within bounding box '[4.2381, 5.267], [4.8856, 5.267], [4.8778, 5.4287], [4.2381, 5.4287]'
# ...Cell[7][6] has text '. . . . .' within bounding box '[4.8856, 5.267], [5.7672, 5.2593], [5.7672, 5.4287], [4.8778, 5.4287]'
# ...Cell[7][7] has text '. . . . .' within bounding box '[5.7672, 5.2593], [6.7034, 5.2516], [6.7034, 5.421], [5.7672, 5.4287]'
# ...Cell[7][8] has text '1b' within bounding box '[6.7034, 5.2516], [6.9843, 5.2516], [6.9843, 5.421], [6.7034, 5.421]'
# ...Cell[7][9] has text '' within bounding box '[6.9843, 5.2516], [7.9985, 5.2516], [7.9985, 5.421], [6.9843, 5.421]'
# ...Cell[8][0] has text 'Attach Form(s) W-2 here. Also' within bounding box '[0.4308, 5.421], [1.2578, 5.421], [1.25, 5.6058], [0.423, 5.6058]'
# ...Cell[8][1] has text 'c' within bounding box '[1.2578, 5.421], [1.4528, 5.421], [1.4528, 5.5981], [1.25, 5.6058]'
# ...Cell[8][2] has text 'Tip income not reported on line 1a (see instructions)' within bounding box '[1.4528, 5.421], [4.2381, 5.4287], [4.2381, 5.5981], [1.4528, 5.5981]'
# ...Cell[8][5] has text '. . . .' within bounding box '[4.2381, 5.4287], [4.8778, 5.4287], [4.8778, 5.5981], [4.2381, 5.5981]'
# ...Cell[8][6] has text '. . . . .' within bounding box '[4.8778, 5.4287], [5.7672, 5.4287], [5.7672, 5.5981], [4.8778, 5.5981]'
# ...Cell[8][7] has text '. . . . .' within bounding box '[5.7672, 5.4287], [6.7034, 5.421], [6.7034, 5.5904], [5.7672, 5.5981]'
# ...Cell[8][8] has text '1c' within bounding box '[6.7034, 5.421], [6.9843, 5.421], [6.9843, 5.5904], [6.7034, 5.5904]'
# ...Cell[8][9] has text '' within bounding box '[6.9843, 5.421], [7.9985, 5.421], [7.9985, 5.5904], [6.9843, 5.5904]'
# ...Cell[9][0] has text 'attach Forms' within bounding box '[0.423, 5.6058], [1.25, 5.6058], [1.25, 5.7675], [0.423, 5.7675]'
# ...Cell[9][1] has text 'd' within bounding box '[1.25, 5.6058], [1.4528, 5.5981], [1.4528, 5.7675], [1.25, 5.7675]'
# ...Cell[9][2] has text 'Medicaid waiver payments not reported on Form(s) W-2 (see instructions) . . .' within bounding box '[1.4528, 5.5981], [5.7672, 5.5981], [5.7672, 5.7598], [1.4528, 5.7675]'
# ...Cell[9][7] has text '. . . . .' within bounding box '[5.7672, 5.5981], [6.7034, 5.5904], [6.7034, 5.7598], [5.7672, 5.7598]'
# ...Cell[9][8] has text '1d' within bounding box '[6.7034, 5.5904], [6.9843, 5.5904], [6.9843, 5.7598], [6.7034, 5.7598]'
# ...Cell[9][9] has text '' within bounding box '[6.9843, 5.5904], [7.9985, 5.5904], [7.9985, 5.7598], [6.9843, 5.7598]'
# ...Cell[10][0] has text 'W-2G and' within bounding box '[0.423, 5.7675], [1.25, 5.7675], [1.25, 5.9138], [0.423, 5.9061]'
# ...Cell[10][1] has text 'e' within bounding box '[1.25, 5.7675], [1.4528, 5.7675], [1.4528, 5.9215], [1.25, 5.9138]'
# ...Cell[10][2] has text 'Taxable dependent care benefits from Form 2441, line 26 . .' within bounding box '[1.4528, 5.7675], [4.8778, 5.7675], [4.8778, 5.9369], [1.4528, 5.9215]'
# ...Cell[10][6] has text '. . . . .' within bounding box '[4.8778, 5.7675], [5.7672, 5.7598], [5.7672, 5.9292], [4.8778, 5.9369]'
# ...Cell[10][7] has text '. . . . .' within bounding box '[5.7672, 5.7598], [6.7034, 5.7598], [6.7034, 5.9215], [5.7672, 5.9292]'
# ...Cell[10][8] has text '1e' within bounding box '[6.7034, 5.7598], [6.9843, 5.7598], [6.9843, 5.9215], [6.7034, 5.9215]'
# ...Cell[10][9] has text '' within bounding box '[6.9843, 5.7598], [7.9985, 5.7598], [7.9985, 5.9215], [6.9843, 5.9215]'
# ...Cell[11][0] has text '1099-R if tax was withheld.' within bounding box '[0.423, 5.9061], [1.25, 5.9138], [1.2422, 6.114], [0.423, 6.1217]'
# ...Cell[11][1] has text 'f' within bounding box '[1.25, 5.9138], [1.4528, 5.9215], [1.4528, 6.114], [1.2422, 6.114]'
# ...Cell[11][2] has text 'Employer-provided adoption benefits from Form 8839, line 29 .' within bounding box '[1.4528, 5.9215], [4.8778, 5.9369], [4.8778, 6.0986], [1.4528, 6.114]'
# ...Cell[11][6] has text '. . . . .' within bounding box '[4.8778, 5.9369], [5.7672, 5.9292], [5.7672, 6.0986], [4.8778, 6.0986]'
# ...Cell[11][7] has text '. . . . .' within bounding box '[5.7672, 5.9292], [6.7034, 5.9215], [6.7034, 6.0909], [5.7672, 6.0986]'
# ...Cell[11][8] has text '1f' within bounding box '[6.7034, 5.9215], [6.9843, 5.9215], [6.9843, 6.0909], [6.7034, 6.0909]'
# ...Cell[11][9] has text '' within bounding box '[6.9843, 5.9215], [7.9985, 5.9215], [7.9985, 6.0909], [6.9843, 6.0909]'
# ...Cell[12][0] has text 'If you did not' within bounding box '[0.423, 6.1217], [1.2422, 6.114], [1.2422, 6.268], [0.423, 6.2757]'
# ...Cell[12][1] has text 'g' within bounding box '[1.2422, 6.114], [1.4528, 6.114], [1.4528, 6.268], [1.2422, 6.268]'
# ...Cell[12][2] has text 'Wages from Form 8919, line 6 . . . . . . . . . . .' within bounding box '[1.4528, 6.114], [4.8778, 6.0986], [4.8778, 6.2603], [1.4528, 6.268]'
# ...Cell[12][6] has text '. . . . .' within bounding box '[4.8778, 6.0986], [5.7672, 6.0986], [5.7672, 6.2603], [4.8778, 6.2603]'
# ...Cell[12][7] has text '. . . . .' within bounding box '[5.7672, 6.0986], [6.7034, 6.0909], [6.7034, 6.2603], [5.7672, 6.2603]'
# ...Cell[12][8] has text '1g' within bounding box '[6.7034, 6.0909], [6.9843, 6.0909], [6.9843, 6.2603], [6.7034, 6.2603]'
# ...Cell[12][9] has text '' within bounding box '[6.9843, 6.0909], [7.9985, 6.0909], [7.9985, 6.2603], [6.9843, 6.2603]'
# ...Cell[13][0] has text 'get a Form' within bounding box '[0.423, 6.2757], [1.2422, 6.268], [1.2344, 6.4143], [0.4152, 6.4066]'
# ...Cell[13][1] has text 'h' within bounding box '[1.2422, 6.268], [1.4528, 6.268], [1.4528, 6.4143], [1.2344, 6.4143]'
# ...Cell[13][2] has text 'Other earned income (see instructions) . . . . . . . .' within bounding box '[1.4528, 6.268], [4.8778, 6.2603], [4.8778, 6.422], [1.4528, 6.4143]'
# ...Cell[13][6] has text '. . . . .' within bounding box '[4.8778, 6.2603], [5.7672, 6.2603], [5.7672, 6.422], [4.8778, 6.422]'
# ...Cell[13][7] has text '. . . . .' within bounding box '[5.7672, 6.2603], [6.7034, 6.2603], [6.7034, 6.422], [5.7672, 6.422]'
# ...Cell[13][8] has text '1h' within bounding box '[6.7034, 6.2603], [6.9843, 6.2603], [6.9843, 6.422], [6.7034, 6.422]'
# ...Cell[13][9] has text '' within bounding box '[6.9843, 6.2603], [7.9985, 6.2603], [7.9985, 6.422], [6.9843, 6.422]'
# ...Cell[14][0] has text 'W-2, see instructions.' within bounding box '[0.4152, 6.4066], [1.2344, 6.4143], [1.2344, 6.5837], [0.4152, 6.5837]'
# ...Cell[14][1] has text 'i' within bounding box '[1.2344, 6.4143], [1.4528, 6.4143], [1.4528, 6.5837], [1.2344, 6.5837]'
# ...Cell[14][2] has text 'Nontaxable combat pay election (see instructions) . . . . .' within bounding box '[1.4528, 6.4143], [4.8778, 6.422], [4.8778, 6.5837], [1.4528, 6.5837]'
# ...Cell[14][6] has text '1i . .' within bounding box '[4.8778, 6.422], [5.7672, 6.422], [5.7672, 6.576], [4.8778, 6.5837]'
# ...Cell[14][7] has text '' within bounding box '[5.7672, 6.422], [6.7034, 6.422], [6.7034, 6.576], [5.7672, 6.576]'
# ...Cell[14][8] has text '' within bounding box '[6.7034, 6.422], [6.9843, 6.422], [6.9843, 6.576], [6.7034, 6.576]'
# ...Cell[14][9] has text '' within bounding box '[6.9843, 6.422], [7.9985, 6.422], [7.9985, 6.576], [6.9843, 6.576]'
# ...Cell[15][0] has text '' within bounding box '[0.4152, 6.5837], [1.2344, 6.5837], [1.2344, 6.7531], [0.4152, 6.7531]'
# ...Cell[15][1] has text 'z' within bounding box '[1.2344, 6.5837], [1.4528, 6.5837], [1.4528, 6.7608], [1.2344, 6.7531]'
# ...Cell[15][2] has text 'Add lines 1a through 1h .' within bounding box '[1.4528, 6.5837], [3.1224, 6.5837], [3.1224, 6.7608], [1.4528, 6.7608]'
# ...Cell[15][3] has text '. . .' within bounding box '[3.1224, 6.5837], [3.6451, 6.5837], [3.6373, 6.7608], [3.1224, 6.7608]'
# ...Cell[15][4] has text '. . . .' within bounding box '[3.6451, 6.5837], [4.2537, 6.5837], [4.2537, 6.7608], [3.6373, 6.7608]'
# ...Cell[15][5] has text '. . . .' within bounding box '[4.2537, 6.5837], [4.8778, 6.5837], [4.8778, 6.7608], [4.2537, 6.7608]'
# ...Cell[15][6] has text '. . . . .' within bounding box '[4.8778, 6.5837], [5.7672, 6.576], [5.7672, 6.7608], [4.8778, 6.7608]'
# ...Cell[15][7] has text '. . . . .' within bounding box '[5.7672, 6.576], [6.7034, 6.576], [6.6956, 6.7608], [5.7672, 6.7608]'
# ...Cell[15][8] has text '1z' within bounding box '[6.7034, 6.576], [6.9843, 6.576], [6.9921, 6.7531], [6.6956, 6.7608]'
# ...Cell[15][9] has text '' within bounding box '[6.9843, 6.576], [7.9985, 6.576], [7.9985, 6.7531], [6.9921, 6.7531]'
# ...Cell[16][0] has text 'Attach Sch. B' within bounding box '[0.4152, 6.7531], [1.2344, 6.7531], [1.2266, 6.9302], [0.4152, 6.9302]'
# ...Cell[16][1] has text '2a' within bounding box '[1.2344, 6.7531], [1.4528, 6.7608], [1.4528, 6.9302], [1.2266, 6.9302]'
# ...Cell[16][2] has text 'Tax-exempt interest . . .' within bounding box '[1.4528, 6.7608], [3.1224, 6.7608], [3.1146, 6.9225], [1.4528, 6.9302]'
# ...Cell[16][3] has text '2a' within bounding box '[3.1224, 6.7608], [3.6373, 6.7608], [3.6373, 6.9225], [3.1146, 6.9225]'
# ...Cell[16][4] has text '' within bounding box '[3.6373, 6.7608], [4.2537, 6.7608], [4.2537, 6.9225], [3.6373, 6.9225]'
# ...Cell[16][5] has text 'b' within bounding box '[4.2537, 6.7608], [4.8778, 6.7608], [4.8778, 6.9225], [4.2537, 6.9225]'
# ...Cell[16][6] has text 'Taxable interest . . . . .' within bounding box '[4.8778, 6.7608], [6.6956, 6.7608], [6.6956, 6.9225], [4.8778, 6.9225]'
# ...Cell[16][8] has text '2b' within bounding box '[6.6956, 6.7608], [6.9921, 6.7531], [6.9921, 6.9225], [6.6956, 6.9225]'
# ...Cell[16][9] has text '' within bounding box '[6.9921, 6.7531], [7.9985, 6.7531], [7.9985, 6.9225], [6.9921, 6.9225]'
# ...Cell[17][0] has text 'if required.' within bounding box '[0.4152, 6.9302], [1.2266, 6.9302], [1.2266, 7.0996], [0.4152, 7.1073]'
# ...Cell[17][1] has text '3a' within bounding box '[1.2266, 6.9302], [1.4528, 6.9302], [1.4528, 7.0919], [1.2266, 7.0996]'
# ...Cell[17][2] has text 'Qualified dividends . . .' within bounding box '[1.4528, 6.9302], [3.1146, 6.9225], [3.1146, 7.0919], [1.4528, 7.0919]'
# ...Cell[17][3] has text '3a' within bounding box '[3.1146, 6.9225], [3.6373, 6.9225], [3.6373, 7.0919], [3.1146, 7.0919]'
# ...Cell[17][4] has text '' within bounding box '[3.6373, 6.9225], [4.2537, 6.9225], [4.2615, 7.0919], [3.6373, 7.0919]'
# ...Cell[17][5] has text 'b' within bounding box '[4.2537, 6.9225], [4.8778, 6.9225], [4.8778, 7.0919], [4.2615, 7.0919]'
# ...Cell[17][6] has text 'Ordinary dividends . . . . .' within bounding box '[4.8778, 6.9225], [6.6956, 6.9225], [6.6956, 7.0919], [4.8778, 7.0919]'
# ...Cell[17][8] has text '3b' within bounding box '[6.6956, 6.9225], [6.9921, 6.9225], [6.9921, 7.0919], [6.6956, 7.0919]'
# ...Cell[17][9] has text '' within bounding box '[6.9921, 6.9225], [7.9985, 6.9225], [7.9985, 7.0919], [6.9921, 7.0919]'
# ...Cell[18][0] has text '' within bounding box '[0.4152, 7.1073], [1.2266, 7.0996], [1.2266, 7.2613], [0.4074, 7.2613]'
# ...Cell[18][1] has text '4a' within bounding box '[1.2266, 7.0996], [1.4528, 7.0919], [1.4528, 7.2613], [1.2266, 7.2613]'
# ...Cell[18][2] has text 'IRA distributions . . . .' within bounding box '[1.4528, 7.0919], [3.1146, 7.0919], [3.1068, 7.2613], [1.4528, 7.2613]'
# ...Cell[18][3] has text '4a' within bounding box '[3.1146, 7.0919], [3.6373, 7.0919], [3.6373, 7.2613], [3.1068, 7.2613]'
# ...Cell[18][4] has text '' within bounding box '[3.6373, 7.0919], [4.2615, 7.0919], [4.2615, 7.2613], [3.6373, 7.2613]'
# ...Cell[18][5] has text 'b Taxable amount . . . . . .' within bounding box '[4.2615, 7.0919], [6.6956, 7.0919], [6.6956, 7.2613], [4.2615, 7.2613]'
# ...Cell[18][8] has text '4b' within bounding box '[6.6956, 7.0919], [6.9921, 7.0919], [6.9921, 7.2613], [6.6956, 7.2613]'
# ...Cell[18][9] has text '' within bounding box '[6.9921, 7.0919], [7.9985, 7.0919], [7.9985, 7.2536], [6.9921, 7.2613]'
# ...Cell[19][0] has text 'Standard' within bounding box '[0.4074, 7.2613], [1.2266, 7.2613], [1.2188, 7.4153], [0.4074, 7.4153]'
# ...Cell[19][1] has text '5a' within bounding box '[1.2266, 7.2613], [1.4528, 7.2613], [1.4528, 7.4153], [1.2188, 7.4153]'
# ...Cell[19][2] has text 'Pensions and annuities . .' within bounding box '[1.4528, 7.2613], [3.1068, 7.2613], [3.1068, 7.4153], [1.4528, 7.4153]'
# ...Cell[19][3] has text '5a' within bounding box '[3.1068, 7.2613], [3.6373, 7.2613], [3.6373, 7.423], [3.1068, 7.4153]'
# ...Cell[19][4] has text '' within bounding box '[3.6373, 7.2613], [4.2615, 7.2613], [4.2615, 7.423], [3.6373, 7.423]'
# ...Cell[19][5] has text 'b Taxable amount . . . . . .' within bounding box '[4.2615, 7.2613], [6.6956, 7.2613], [6.6956, 7.423], [4.2615, 7.423]'
# ...Cell[19][8] has text '5b' within bounding box '[6.6956, 7.2613], [6.9921, 7.2613], [6.9921, 7.423], [6.6956, 7.423]'
# ...Cell[19][9] has text '' within bounding box '[6.9921, 7.2613], [7.9985, 7.2536], [7.9985, 7.423], [6.9921, 7.423]'
# ...Cell[20][0] has text 'Deduction for— •' within bounding box '[0.4074, 7.4153], [1.2188, 7.4153], [1.2188, 7.5924], [0.4074, 7.6001]'
# ...Cell[20][1] has text '6a' within bounding box '[1.2188, 7.4153], [1.4528, 7.4153], [1.4606, 7.5924], [1.2188, 7.5924]'
# ...Cell[20][2] has text 'Social security benefits . .' within bounding box '[1.4528, 7.4153], [3.1068, 7.4153], [3.099, 7.5924], [1.4606, 7.5924]'
# ...Cell[20][3] has text '6a' within bounding box '[3.1068, 7.4153], [3.6373, 7.423], [3.6373, 7.5924], [3.099, 7.5924]'
# ...Cell[20][4] has text '' within bounding box '[3.6373, 7.423], [4.2615, 7.423], [4.2615, 7.5924], [3.6373, 7.5924]'
# ...Cell[20][5] has text 'b' within bounding box '[4.2615, 7.423], [4.8778, 7.423], [4.8778, 7.5924], [4.2615, 7.5924]'
# ...Cell[20][6] has text 'Taxable amount . . . . . .' within bounding box '[4.8778, 7.423], [6.6956, 7.423], [6.6956, 7.5924], [4.8778, 7.5924]'
# ...Cell[20][8] has text '6b' within bounding box '[6.6956, 7.423], [6.9921, 7.423], [6.9921, 7.5924], [6.6956, 7.5924]'
# ...Cell[20][9] has text '' within bounding box '[6.9921, 7.423], [7.9985, 7.423], [7.9985, 7.5924], [6.9921, 7.5924]'
# ...Cell[21][0] has text 'Single or Married filing' within bounding box '[0.4074, 7.6001], [1.2188, 7.5924], [1.2188, 7.7618], [0.4074, 7.7618]'
# ...Cell[21][1] has text 'c' within bounding box '[1.2188, 7.5924], [1.4606, 7.5924], [1.4606, 7.7618], [1.2188, 7.7618]'
# ...Cell[21][2] has text 'If you elect to use the lump-sum election method, check here (see instructions) . . . . .' within bounding box '[1.4606, 7.5924], [6.6956, 7.5924], [6.6956, 7.7618], [1.4606, 7.7618]'
# ...Cell[21][8] has text '' within bounding box '[6.6956, 7.5924], [6.9921, 7.5924], [6.9921, 7.7541], [6.6956, 7.7618]'
# ...Cell[21][9] has text '' within bounding box '[6.9921, 7.5924], [7.9985, 7.5924], [7.9985, 7.7541], [6.9921, 7.7541]'
# ...Cell[22][0] has text 'separately, $12,950' within bounding box '[0.4074, 7.7618], [1.2188, 7.7618], [1.211, 7.9389], [0.3996, 7.9466]'
# ...Cell[22][1] has text '7' within bounding box '[1.2188, 7.7618], [1.4606, 7.7618], [1.4606, 7.9389], [1.211, 7.9389]'
# ...Cell[22][2] has text 'Capital gain or (loss). Attach Schedule D if required. If not required, check here .' within bounding box '[1.4606, 7.7618], [5.7594, 7.7618], [5.7594, 7.9312], [1.4606, 7.9389]'
# ...Cell[22][7] has text '. . . .' within bounding box '[5.7594, 7.7618], [6.6956, 7.7618], [6.6956, 7.9235], [5.7594, 7.9312]'
# ...Cell[22][8] has text '7' within bounding box '[6.6956, 7.7618], [6.9921, 7.7541], [6.9921, 7.9235], [6.6956, 7.9235]'
# ...Cell[22][9] has text '' within bounding box '[6.9921, 7.7541], [7.9985, 7.7541], [7.9985, 7.9235], [6.9921, 7.9235]'
# ...Cell[23][0] has text '• Married filing' within bounding box '[0.3996, 7.9466], [1.211, 7.9389], [1.211, 8.0852], [0.3996, 8.0852]'
# ...Cell[23][1] has text '8' within bounding box '[1.211, 7.9389], [1.4606, 7.9389], [1.4606, 8.0929], [1.211, 8.0852]'
# ...Cell[23][2] has text 'Other income from Schedule 1, line 10 . . . . . . . . . . . . .' within bounding box '[1.4606, 7.9389], [5.7594, 7.9312], [5.7594, 8.0929], [1.4606, 8.0929]'
# ...Cell[23][7] has text '. . . . .' within bounding box '[5.7594, 7.9312], [6.6956, 7.9235], [6.6956, 8.0929], [5.7594, 8.0929]'
# ...Cell[23][8] has text '8' within bounding box '[6.6956, 7.9235], [6.9921, 7.9235], [6.9921, 8.0929], [6.6956, 8.0929]'
# ...Cell[23][9] has text '' within bounding box '[6.9921, 7.9235], [7.9985, 7.9235], [7.9985, 8.0852], [6.9921, 8.0929]'
# ...Cell[24][0] has text 'jointly or Qualifying' within bounding box '[0.3996, 8.0852], [1.211, 8.0852], [1.2032, 8.27], [0.3996, 8.2623]'
# ...Cell[24][1] has text '9' within bounding box '[1.211, 8.0852], [1.4606, 8.0929], [1.4606, 8.27], [1.2032, 8.27]'
# ...Cell[24][2] has text 'Add lines 1z, 2b, 3b, 4b, 5b, 6b, 7, and 8. This is your total income . . . . .' within bounding box '[1.4606, 8.0929], [5.7594, 8.0929], [5.7594, 8.2546], [1.4606, 8.27]'
# ...Cell[24][7] has text '. . . . .' within bounding box '[5.7594, 8.0929], [6.6956, 8.0929], [6.6956, 8.2546], [5.7594, 8.2546]'
# ...Cell[24][8] has text '9' within bounding box '[6.6956, 8.0929], [6.9921, 8.0929], [6.9921, 8.2546], [6.6956, 8.2546]'
# ...Cell[24][9] has text '' within bounding box '[6.9921, 8.0929], [7.9985, 8.0852], [7.9985, 8.2546], [6.9921, 8.2546]'
# ...Cell[25][0] has text 'surviving spouse, $25,900' within bounding box '[0.3996, 8.2623], [1.2032, 8.27], [1.2032, 8.4394], [0.3996, 8.4471]'
# ...Cell[25][1] has text '10' within bounding box '[1.2032, 8.27], [1.4606, 8.27], [1.4606, 8.4394], [1.2032, 8.4394]'
# ...Cell[25][2] has text 'Adjustments to income from Schedule 1, line 26 . . . . . . . . . .' within bounding box '[1.4606, 8.27], [5.7594, 8.2546], [5.7594, 8.4317], [1.4606, 8.4394]'
# ...Cell[25][7] has text '. . . . .' within bounding box '[5.7594, 8.2546], [6.6956, 8.2546], [6.6878, 8.424], [5.7594, 8.4317]'
# ...Cell[25][8] has text '10' within bounding box '[6.6956, 8.2546], [6.9921, 8.2546], [6.9921, 8.424], [6.6878, 8.424]'
# ...Cell[25][9] has text '' within bounding box '[6.9921, 8.2546], [7.9985, 8.2546], [7.9985, 8.424], [6.9921, 8.424]'
# ...Cell[26][0] has text '• Head of' within bounding box '[0.3996, 8.4471], [1.2032, 8.4394], [1.2032, 8.5857], [0.3996, 8.5857]'
# ...Cell[26][1] has text '11' within bounding box '[1.2032, 8.4394], [1.4606, 8.4394], [1.4606, 8.5857], [1.2032, 8.5857]'
# ...Cell[26][2] has text 'Subtract line 10 from line 9. This is your adjusted gross income . . . . .' within bounding box '[1.4606, 8.4394], [5.7594, 8.4317], [5.7594, 8.5934], [1.4606, 8.5857]'
# ...Cell[26][7] has text '. . . . .' within bounding box '[5.7594, 8.4317], [6.6878, 8.424], [6.6878, 8.5857], [5.7594, 8.5934]'
# ...Cell[26][8] has text '11' within bounding box '[6.6878, 8.424], [6.9921, 8.424], [6.9921, 8.5857], [6.6878, 8.5857]'
# ...Cell[26][9] has text '' within bounding box '[6.9921, 8.424], [7.9985, 8.424], [7.9985, 8.5857], [6.9921, 8.5857]'
# ...Cell[27][0] has text 'household, $19,400' within bounding box '[0.3996, 8.5857], [1.2032, 8.5857], [1.1954, 8.7705], [0.3918, 8.7782]'
# ...Cell[27][1] has text '12' within bounding box '[1.2032, 8.5857], [1.4606, 8.5857], [1.4606, 8.7705], [1.1954, 8.7705]'
# ...Cell[27][2] has text 'Standard deduction or itemized deductions (from Schedule A)' within bounding box '[1.4606, 8.5857], [4.8778, 8.5934], [4.8778, 8.7628], [1.4606, 8.7705]'
# ...Cell[27][6] has text '. . . . .' within bounding box '[4.8778, 8.5934], [5.7594, 8.5934], [5.7594, 8.7628], [4.8778, 8.7628]'
# ...Cell[27][7] has text '. . . . .' within bounding box '[5.7594, 8.5934], [6.6878, 8.5857], [6.6878, 8.7628], [5.7594, 8.7628]'
# ...Cell[27][8] has text '12' within bounding box '[6.6878, 8.5857], [6.9921, 8.5857], [6.9999, 8.7551], [6.6878, 8.7628]'
# ...Cell[27][9] has text '' within bounding box '[6.9921, 8.5857], [7.9985, 8.5857], [7.9985, 8.7551], [6.9999, 8.7551]'
# ...Cell[28][0] has text '• If you checked' within bounding box '[0.3918, 8.7782], [1.1954, 8.7705], [1.1954, 8.9168], [0.3918, 8.9091]'
# ...Cell[28][1] has text '13' within bounding box '[1.1954, 8.7705], [1.4606, 8.7705], [1.4606, 8.9168], [1.1954, 8.9168]'
# ...Cell[28][2] has text 'Qualified business income deduction from Form 8995 or Form 8995-A . . . .' within bounding box '[1.4606, 8.7705], [5.7594, 8.7628], [5.7594, 8.9245], [1.4606, 8.9168]'
# ...Cell[28][7] has text '. . . . .' within bounding box '[5.7594, 8.7628], [6.6878, 8.7628], [6.6878, 8.9245], [5.7594, 8.9245]'
# ...Cell[28][8] has text '13' within bounding box '[6.6878, 8.7628], [6.9999, 8.7551], [6.9999, 8.9245], [6.6878, 8.9245]'
# ...Cell[28][9] has text '' within bounding box '[6.9999, 8.7551], [7.9985, 8.7551], [7.9985, 8.9168], [6.9999, 8.9245]'
# ...Cell[29][0] has text 'any box under Standard' within bounding box '[0.3918, 8.9091], [1.1954, 8.9168], [1.1954, 9.0939], [0.3918, 9.0939]'
# ...Cell[29][1] has text '14' within bounding box '[1.1954, 8.9168], [1.4606, 8.9168], [1.4606, 9.0939], [1.1954, 9.0939]'
# ...Cell[29][2] has text 'Add lines 12 and 13 . . . . . . . . . . . . . .' within bounding box '[1.4606, 8.9168], [4.8778, 8.9322], [4.8778, 9.0939], [1.4606, 9.0939]'
# ...Cell[29][6] has text '. . . . . . . . . .' within bounding box '[4.8778, 8.9322], [6.6878, 8.9245], [6.6878, 9.0939], [4.8778, 9.0939]'
# ...Cell[29][8] has text '14' within bounding box '[6.6878, 8.9245], [6.9999, 8.9245], [6.9999, 9.0862], [6.6878, 9.0939]'
# ...Cell[29][9] has text '' within bounding box '[6.9999, 8.9245], [7.9985, 8.9168], [7.9985, 9.0862], [6.9999, 9.0862]'
# ...Cell[30][0] has text 'Deduction, see instructions.' within bounding box '[0.3918, 9.0939], [1.1954, 9.0939], [1.1876, 9.3326], [0.3918, 9.3402]'
# ...Cell[30][1] has text '15' within bounding box '[1.1954, 9.0939], [1.4606, 9.0939], [1.4606, 9.3326], [1.1876, 9.3326]'
# ...Cell[30][2] has text 'Subtract line 14 from line 11. If zero or less, enter -0-. This is your taxable income . . . . .' within bounding box '[1.4606, 9.0939], [6.6878, 9.0939], [6.6878, 9.3094], [1.4606, 9.3326]'
# ...Cell[30][8] has text '15' within bounding box '[6.6878, 9.0939], [6.9999, 9.0862], [6.9999, 9.3017], [6.6878, 9.3094]'
# ...Cell[30][9] has text '' within bounding box '[6.9999, 9.0862], [7.9985, 9.0862], [7.9985, 9.3094], [6.9999, 9.3017]'

# %% [markdown]
# #### Extract all selection marks with their current state in the Form 1040

# %%
# --------------------------
# Code Snippet Source 
# https://github.com/Azure-Samples/cognitive-services-quickstart-code/blob/master/python/ComputerVision/REST/python-disk.md
# --------------------------
for selection_mark in content.selection_marks:
    print("Selection mark is '{}' within bounding box '{}' and has a confidence of {}".format(
        selection_mark.state,
        format_bounding_box(selection_mark.bounding_box),
        selection_mark.confidence
    ))
# Out:
# Selection mark is 'unselected' within bounding box '[1.3278, 0.9375], [1.4389, 0.9375], [1.4389, 1.0486], [1.3278, 1.0486]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[1.9278, 0.9375], [2.0389, 0.9375], [2.0389, 1.0486], [1.9278, 1.0486]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[3.2278, 0.9375], [3.3389, 0.9375], [3.3389, 1.0486], [3.2278, 1.0486]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[5.0278, 0.9375], [5.1389, 0.9375], [5.1389, 1.0486], [5.0278, 1.0486]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[6.5278, 0.9375], [6.6389, 0.9375], [6.6389, 1.0486], [6.5278, 1.0486]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[7.0, 3.0069], [7.1111, 3.0069], [7.1111, 3.118], [7.0, 3.118]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[7.5, 3.0069], [7.6111, 3.0069], [7.6111, 3.118], [7.5, 3.118]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[7.0, 3.3472], [7.1111, 3.3472], [7.1111, 3.4583], [7.0, 3.4583]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[7.5, 3.3472], [7.6111, 3.3472], [7.6111, 3.4583], [7.5, 3.4583]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[2.5278, 3.5278], [2.6389, 3.5278], [2.6389, 3.6389], [2.5278, 3.6389]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[3.9278, 3.5278], [4.0389, 3.5278], [4.0389, 3.6389], [3.9278, 3.6389]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[1.3278, 3.6944], [1.4389, 3.6944], [1.4389, 3.8055], [1.3278, 3.8055]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[1.6278, 3.9375], [1.7389, 3.9375], [1.7389, 4.0486], [1.6278, 4.0486]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[3.6278, 3.9375], [3.7389, 3.9375], [3.7389, 4.0486], [3.6278, 4.0486]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[5.0278, 3.9375], [5.1389, 3.9375], [5.1389, 4.0486], [5.0278, 4.0486]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[7.0278, 3.9375], [7.1389, 3.9375], [7.1389, 4.0486], [7.0278, 4.0486]' and has a confidence of 1.0
# Selection mark is 'selected' within bounding box '[3.9153, 4.1506], [4.022, 4.1506], [4.022, 4.2379], [3.9153, 4.2379]' and has a confidence of 0.223
# Selection mark is 'unselected' within bounding box '[6.2944, 4.4444], [6.4056, 4.4444], [6.4056, 4.5555], [6.2944, 4.5555]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[7.3944, 4.4444], [7.5056, 4.4444], [7.5056, 4.5555], [7.3944, 4.5555]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[6.2944, 4.6111], [6.4056, 4.6111], [6.4056, 4.7222], [6.2944, 4.7222]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[7.3944, 4.6111], [7.5056, 4.6111], [7.5056, 4.7222], [7.3944, 4.7222]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[6.2944, 4.7777], [6.4056, 4.7777], [6.4056, 4.8888], [6.2944, 4.8888]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[7.3944, 4.7777], [7.5056, 4.7777], [7.5056, 4.8888], [7.3944, 4.8888]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[1.1069, 4.9271], [1.218, 4.9271], [1.218, 5.0382], [1.1069, 5.0382]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[6.2944, 4.9444], [6.4056, 4.9444], [6.4056, 5.0555], [6.2944, 5.0555]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[7.3944, 4.9444], [7.5056, 4.9444], [7.5056, 5.0555], [7.3944, 5.0555]' and has a confidence of 1.0
# Selection mark is 'selected' within bounding box '[0.4977, 5.554], [0.5796, 5.554], [0.5796, 5.624], [0.4977, 5.624]' and has a confidence of 0.223
# Selection mark is 'unselected' within bounding box '[1.3983, 5.6511], [1.4681, 5.6511], [1.4681, 5.7202], [1.3983, 5.7202]' and has a confidence of 0.223
# Selection mark is 'unselected' within bounding box '[6.4611, 7.6111], [6.5722, 7.6111], [6.5722, 7.7222], [6.4611, 7.7222]' and has a confidence of 1.0
# Selection mark is 'unselected' within bounding box '[6.4611, 7.7778], [6.5722, 7.7778], [6.5722, 7.8889], [6.4611, 7.8889]' and has a confidence of 1.0
